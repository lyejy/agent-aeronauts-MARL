# %%
import csv
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pytz
from pytz import all_timezones

# %%
folder = "./ASEAN_2018D"
movements_2018_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jan_Mar_JobId2081527.csv", sep = ",", header = 0)
movements_2018_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Apr_Jun_JobId2081525.csv", sep = ",", header = 0)
movements_2018_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jul_Sep_JobId2081528.csv", sep = ",", header = 0)
movements_2018_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Oct_Dec_JobId2081529.csv", sep = ",", header = 0)
movements_2018 = pd.concat([movements_2018_1, movements_2018_2, movements_2018_3, movements_2018_4])

folder = "./ASEAN_2019D"
movements_2019_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jan_Mar_JobId2082476.csv", sep = ",", header = 0)
movements_2019_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Apr_Jun_JobId2081531.csv", sep = ",", header = 0)
movements_2019_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jul_Sep_JobId2081532.csv", sep = ",", header = 0)
movements_2019_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Oct_Dec_JobId2082477.csv", sep = ",", header = 0)
movements_2019 = pd.concat([movements_2019_1, movements_2019_2, movements_2019_3, movements_2019_4])

movements_all = pd.concat([movements_2018, movements_2019])

# %%
def dep_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0
    
def arr_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0

# %%
def dep_or_arr_time(dep, dep_time, arr_time):
    if dep == 1:
        return dep_time
    else:
        return arr_time

# %%
def f(s):
    return "".join(["0"]*(4-len(s))) + s

# %%
def utc(datetime):
    local = pytz.timezone("Asia/Singapore")
    local_dt = local.localize(datetime, is_dst=None)
    return local_dt.astimezone(pytz.utc)

# %%
def day_of_week(s):
    return s.weekday()

# %%
def requested_utc_hour(s):
    return s.hour

def requested_utc_minute(s):
    if s.minute == 0:
        return "00"
    elif s.minute == 5:
        return "05"
    else:
        return s.minute

# %%
movements_Dep_SIN = movements_all.loc[movements_all['Dep Airport Code'] == 'SIN']
movements_Arr_SIN = movements_all.loc[movements_all['Arr Airport Code'] == 'SIN']
movements_SIN = pd.concat([movements_Dep_SIN, movements_Arr_SIN])

# %%
movements_SIN['Dep'] = 0
movements_SIN['Arr'] = 0

movements_SIN['Dep'] = movements_SIN['Dep Airport Code'].apply(dep_value)
movements_SIN['Arr'] = movements_SIN['Arr Airport Code'].apply(arr_value)

# %%
movements_SIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 737967 entries, 678011 to 920449
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Dep Airport Code        737967 non-null  object
#  1   Dep Airport Name        737967 non-null  object
#  2   Arr Airport Code        737967 non-null  object
#  3   Arr Airport Name        737967 non-null  object
#  4   ICAO AL                 735774 non-null  object
#  5   IATA AL                 737967 non-null  object
#  6   Flight No               737967 non-null  int64
#  7   Carrier Code            737967 non-null  object
#  8   Carrier Name            737967 non-null  object
#  9   Dep IATA Country Name   737967 non-null  object
#  10  Arr IATA Country Name   737967 non-null  object
#  11  International/Domestic  737967 non-null  object
#  12  Local Dep Time          737967 non-null  int64
#  13  Local Arr Time          737967 non-null  int64
#  14  General Aircraft Code   737967 non-null  object
#  15  General Aircraft Name   737967 non-null  object
#  16  GCD (m)                 737967 non-null  int64
#  17  Frequency               737967 non-null  int64
#  18  Seats (Total)           737967 non-null  int64
#  19  ASMs                    737967 non-null  int64
#  20  ATMs                    737967 non-null  float64
#  21  ASKs                    737967 non-null  int64
#  22  ATKs                    737967 non-null  float64
#  23  FlyingTime (Minutes)    737967 non-null  int64
#  24  Time series             737967 non-null  object
#  25  Dep                     737967 non-null  int64
#  26  Arr                     737967 non-null  int64
# dtypes: float64(2), int64(11), object(14)
# memory usage: 157.6+ MB

# %%
movements_SIN[['Dep Airport Code', 'Arr Airport Code', 'Local Dep Time', 'Local Arr Time', 'Time series']]
# Out:
#        Dep Airport Code Arr Airport Code  Local Dep Time  Local Arr Time  \
# 678011              SIN              ADD             215             605
# 678012              SIN              ADD             215             605
# 678013              SIN              ADD             215             635
# 678014              SIN              ADD             215             635
# 678015              SIN              ADD             215             635
# ...                 ...              ...             ...             ...
# 920353              KBV              SIN            1010            1255
# 920395              HKT              SIN            1950            2245
# 920404              HKG              SIN            2025              15
# 920430              KUL              SIN            1035            1135
# 920449              KUL              SIN            2045            2200
#
#        Time series
# 678011  2018-03-27
# 678012  2018-03-30
# 678013  2018-01-03
# 678014  2018-01-06
# 678015  2018-01-09
# ...            ...
# 920353  2019-11-28
# 920395  2019-10-04
# 920404  2019-10-10
# 920430  2019-11-06
# 920449  2019-11-06
#
# [737967 rows x 5 columns]

# %%
movements_SIN['Dep_time_format4'] = movements_SIN['Local Dep Time'].astype(str).apply(f)
movements_SIN['Arr_time_format4'] = movements_SIN['Local Arr Time'].astype(str).apply(f)
movements_SIN['Dep_time_TS'] = movements_SIN['Time series'] + '-' + movements_SIN['Dep_time_format4']
movements_SIN['Arr_time_TS'] = movements_SIN['Time series'] + '-' + movements_SIN['Arr_time_format4']
movements_SIN['Dep_TS_datetime_format'] = pd.to_datetime(movements_SIN['Dep_time_TS'], format = '%Y-%m-%d-%H%M')
movements_SIN['Arr_TS_datetime_format'] = pd.to_datetime(movements_SIN['Arr_time_TS'], format = '%Y-%m-%d-%H%M')

# %%
movements_SIN['Dep_time_requested_UTC'] = movements_SIN['Dep_TS_datetime_format'].apply(utc)
movements_SIN['Arr_time_requested_UTC'] = movements_SIN['Arr_TS_datetime_format'].apply(utc)

# %%
movements_SIN['Dep_time_series_DT'] = pd.to_datetime(movements_SIN['Dep_time_requested_UTC']).dt.date
movements_SIN['Arr_time_series_DT'] = pd.to_datetime(movements_SIN['Arr_time_requested_UTC']).dt.date

# %%
# sort by date
movements_SIN.sort_values(by=['Dep_time_series_DT'], inplace=True)

# %%
movements_SIN['Dep_utc_hour'] = movements_SIN['Dep_time_requested_UTC'].apply(requested_utc_hour)
movements_SIN['Arr_utc_hour'] = movements_SIN['Arr_time_requested_UTC'].apply(requested_utc_hour)
movements_SIN['Dep_utc_minute'] = movements_SIN['Dep_time_requested_UTC'].apply(requested_utc_minute)
movements_SIN['Arr_utc_minute'] = movements_SIN['Arr_time_requested_UTC'].apply(requested_utc_minute)
movements_SIN['Dep_utc'] = movements_SIN['Dep_utc_hour'].apply(str) + movements_SIN['Dep_utc_minute'].apply(str)
movements_SIN['Arr_utc'] = movements_SIN['Arr_utc_hour'].apply(str) + movements_SIN['Arr_utc_minute'].apply(str)
movements_SIN['Dep_utc'] = movements_SIN['Dep_utc'].astype(int)
movements_SIN['Arr_utc'] = movements_SIN['Arr_utc'].astype(int)

# %%
time_slots = []
h = 0
m = 0
while h < 2400:
    while m < 60:
        time_slots.append(h + m)
        m = m + 5
    m = 0
    h = h + 100
    #print(i)
time_slots.append(2400)
#print(len(time_slots))
#time_slots

# %%
movements_SIN['Dep time slot'] = pd.cut(movements_SIN['Dep_utc'], time_slots, right=False)
movements_SIN['Arr time slot'] = pd.cut(movements_SIN['Arr_utc'], time_slots, right=False)

# %%
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 617980              PEK            Beijing Capital Intl Apt              SIN
# 293146              DPS                       Denpasar-Bali              SIN
# 688429              SIN                Singapore Changi Apt              CMB
# 729527              SIN                Singapore Changi Apt              DME
# 730555              SIN                Singapore Changi Apt              PER
# ...                 ...                                 ...              ...
# 78535               KUL  Kuala Lumpur International Airport              SIN
# 745905              SIN                Singapore Changi Apt              HND
# 460506              SIN                Singapore Changi Apt              MLE
# 540468              JOG                  Yogyakarta (ID) 00              SIN
# 729097              SIN                Singapore Changi Apt              BKK
#
#                               Arr Airport Name ICAO AL IATA AL  Flight No  \
# 617980                    Singapore Changi Apt     CCA      CA        975
# 293146                    Singapore Changi Apt     AWQ      QZ        502
# 688429                       Bandaranaike Intl     UAE      EK        349
# 729527                   Moscow Domodedovo Apt     SIA      SQ        362
# 730555                                   Perth     SIA      SQ        225
# ...                                        ...     ...     ...        ...
# 78535                     Singapore Changi Apt     MAS      MH        605
# 745905                     Tokyo Intl (Haneda)     ANA      NH        842
# 460506                                    Male     SLK      MI        480
# 540468                    Singapore Changi Apt     SLK      MI        151
# 729097  Bangkok Suvarnabhumi International Apt     THA      TG        414
#
#        Carrier Code                Carrier Name Dep IATA Country Name  ...  \
# 617980           CA                   Air China                 China  ...
# 293146           QZ           Indonesia AirAsia             Indonesia  ...
# 688429           EK                    Emirates             Singapore  ...
# 729527           SQ          Singapore Airlines             Singapore  ...
# 730555           SQ          Singapore Airlines             Singapore  ...
# ...             ...                         ...                   ...  ...
# 78535            MH           Malaysia Airlines              Malaysia  ...
# 745905           NH          All Nippon Airways             Singapore  ...
# 460506           MI                     SilkAir             Singapore  ...
# 540468           MI                     SilkAir             Indonesia  ...
# 729097           TG  Thai Airways International             Singapore  ...
#
#        Dep_time_series_DT Arr_time_series_DT  Dep_utc_hour  Arr_utc_hour  \
# 617980         2017-12-31         2017-12-31            16            22
# 293146         2017-12-31         2018-01-01            23             1
# 688429         2017-12-31         2017-12-31            16            17
# 729527         2017-12-31         2017-12-31            16            22
# 730555         2017-12-31         2017-12-31            16            21
# ...                   ...                ...           ...           ...
# 78535          2019-12-31         2019-12-31             7             8
# 745905         2019-12-31         2019-12-31             2            10
# 460506         2019-12-31         2019-12-31             3             5
# 540468         2019-12-31         2019-12-31             2             5
# 729097         2019-12-31         2019-12-31             7             9
#
#        Dep_utc_minute Arr_utc_minute  Dep_utc  Arr_utc  Dep time slot  \
# 617980             10             30     1610     2230   [1610, 1615)
# 293146             20             55     2320      155   [2320, 2325)
# 688429             30             40     1630     1740   [1630, 1635)
# 729527             15             20     1615     2220   [1615, 1620)
# 730555             10             25     1610     2125   [1610, 1615)
# ...               ...            ...      ...      ...            ...
# 78535              30             35      730      835     [730, 735)
# 745905             50             25      250     1025     [250, 255)
# 460506             15             00      315      500     [315, 320)
# 540468             25             50      225      550     [225, 230)
# 729097             55             15      755      915     [755, 800)
#
#         Arr time slot
# 617980   [2230, 2235)
# 293146     [155, 200)
# 688429   [1740, 1745)
# 729527   [2220, 2225)
# 730555   [2125, 2130)
# ...               ...
# 78535      [835, 840)
# 745905   [1025, 1030)
# 460506     [500, 505)
# 540468     [550, 555)
# 729097     [915, 920)
#
# [737967 rows x 45 columns]

# %%
def timeslot_to_index():
    # convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
    start = 0
    end = 5
    interval = pd.Interval(left=start, right=end, closed='left')

    # eg. (0, 5] -> slot 1
    interval_slot_dict = {} 

    for slot in range(1, 289, 1):
        interval_slot_dict[interval] = slot
        if (end % 100 == 55):
            start = interval.left + 5
            end = interval.right + 45
        elif (start % 100 == 55):
            start = interval.left + 45
            end = interval.right + 5
        else:
            start = interval.left + 5
            end = interval.right + 5

        interval = pd.Interval(left=start, right=end, closed='left')
        
    return interval_slot_dict

# %%
def get_first_week_dates(movements_SIN):
    #first_week = movements_SIN['Time_series_DT'].unique()[0:7]
    first_week = movements_SIN['Dep_time_series_DT'].unique()[0:7]
    return first_week # array with 1st week's dates

# %%
def get_random_dates(movements_SIN, num_dates):
    #all_dates = movements_SIN['Time_series_DT'].unique()
    all_dates = movements_SIN['Dep_time_series_DT'].unique()
    dates = np.random.choice(all_dates, num_dates, replace=False)
    return dates # array with num_dates dates

# %%
def get_day_df(movements_SIN, date):
    #SIN_2019_s_d1 = movements_SIN.loc[movements_SIN['Time_series_DT'] == date]
    SIN_2019_s_d1 = movements_SIN.loc[movements_SIN['Dep_time_series_DT'] == date]
    return SIN_2019_s_d1 # df of a particualr day

# %%
def mov_per_slot(SIN_2019_s_d1, interval_slot_dict):
    timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
    timeslot_movements = timeslot_movements.to_frame()
    timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
    timeslot_movements = timeslot_movements.reset_index()
    
    timeslot_movements['Slot'] = ''
    for index, row in timeslot_movements.iterrows():
        row['Slot'] = interval_slot_dict.get(row['index'])
    
    timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)
    return timeslot_movements

# %%
# 1st selected date in array
interval_slot_dict = timeslot_to_index()
dates = get_random_dates(movements_SIN, 7) # change no. as required eg. 2000
#first_week = get_first_week_dates(movements_SIN)
date = dates[0]
SIN_2019_s_d1 = get_day_df(movements_SIN, date)
#timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
#timeslot_movements

# %%
dates
# Out:
# array([datetime.date(2019, 6, 2), datetime.date(2018, 4, 15),
#        datetime.date(2019, 6, 22), datetime.date(2019, 5, 19),
#        datetime.date(2019, 5, 14), datetime.date(2019, 5, 11),
#        datetime.date(2018, 5, 22)], dtype=object)

# %%
SIN_2019_s_d1
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 119479              CEB                                Cebu              SIN
# 727626              SIN                Singapore Changi Apt              KUL
# 726577              SIN                Singapore Changi Apt              KUL
# 707007              SIN                Singapore Changi Apt              PLM
# 491881              KUL  Kuala Lumpur International Airport              SIN
# ...                 ...                                 ...              ...
# 748653              SIN                Singapore Changi Apt              MEL
# 745364              SIN                Singapore Changi Apt              KUL
# 653369              REP                           Siem Reap              SIN
# 647477              PVG   Shanghai Pudong International Apt              SIN
# 697754              SIN                Singapore Changi Apt              HDY
#
#                           Arr Airport Name ICAO AL IATA AL  Flight No  \
# 119479                Singapore Changi Apt     SLK      MI        567
# 727626  Kuala Lumpur International Airport     MXD      OD        808
# 726577  Kuala Lumpur International Airport     MAS      MH        608
# 707007                           Palembang     TGW      TR        250
# 491881                Singapore Changi Apt     JSA      3K        684
# ...                                    ...     ...     ...        ...
# 748653                   Melbourne Airport     SIA      SQ        207
# 745364  Kuala Lumpur International Airport     MXD      OD        806
# 653369                Singapore Changi Apt     JSA      3K        602
# 647477                Singapore Changi Apt     CES      MU        543
# 697754                             Hat Yai     TGW      TR        634
#
#        Carrier Code            Carrier Name Dep IATA Country Name  ...  \
# 119479           MI                 SilkAir           Philippines  ...
# 727626           OD         Malindo Airways             Singapore  ...
# 726577           MH       Malaysia Airlines             Singapore  ...
# 707007           TR                   Scoot             Singapore  ...
# 491881           3K            Jetstar Asia              Malaysia  ...
# ...             ...                     ...                   ...  ...
# 748653           SQ      Singapore Airlines             Singapore  ...
# 745364           OD         Malindo Airways             Singapore  ...
# 653369           3K            Jetstar Asia              Cambodia  ...
# 647477           MU  China Eastern Airlines                 China  ...
# 697754           TR                   Scoot             Singapore  ...
#
#        Dep_time_series_DT Arr_time_series_DT  Dep_utc_hour  Arr_utc_hour  \
# 119479         2019-06-02         2019-06-02             6            10
# 727626         2019-06-02         2019-06-02             9            10
# 726577         2019-06-02         2019-06-02            10            11
# 707007         2019-06-02         2019-06-02             7             8
# 491881         2019-06-02         2019-06-02             0             2
# ...                   ...                ...           ...           ...
# 748653         2019-06-02         2019-06-03            23             9
# 745364         2019-06-02         2019-06-02            13            14
# 653369         2019-06-02         2019-06-02             7            11
# 647477         2019-06-02         2019-06-02            16            21
# 697754         2019-06-02         2019-06-02             5             6
#
#        Dep_utc_minute Arr_utc_minute  Dep_utc  Arr_utc  Dep time slot  \
# 119479             45             30      645     1030     [645, 650)
# 727626             00             05      900     1005     [900, 905)
# 726577             10             20     1010     1120   [1010, 1015)
# 707007             45             05      745      805     [745, 750)
# 491881             50             00       50      200       [50, 55)
# ...               ...            ...      ...      ...            ...
# 748653             45             10     2345      910   [2345, 2350)
# 745364             30             35     1330     1435   [1330, 1335)
# 653369             55             15      755     1115     [755, 800)
# 647477             05             25     1605     2125   [1605, 1610)
# 697754             35             10      535      610     [535, 540)
#
#         Arr time slot
# 119479   [1030, 1035)
# 727626   [1005, 1010)
# 726577   [1120, 1125)
# 707007     [805, 810)
# 491881     [200, 205)
# ...               ...
# 748653     [910, 915)
# 745364   [1435, 1440)
# 653369   [1115, 1120)
# 647477   [2125, 2130)
# 697754     [610, 615)
#
# [1043 rows x 45 columns]

# %%
SIN_2019_s_d1 = SIN_2019_s_d1.reset_index()

# %%
SIN_2019_s_d1['Dep slot'] = SIN_2019_s_d1.apply(lambda row: interval_slot_dict.get(row['Dep time slot']), axis=1)
SIN_2019_s_d1['Arr slot'] = SIN_2019_s_d1.apply(lambda row: interval_slot_dict.get(row['Arr time slot']), axis=1)
SIN_2019_s_d1['Dep slot'] = SIN_2019_s_d1['Dep slot'].round().astype('Int64')
SIN_2019_s_d1['Arr slot'] = SIN_2019_s_d1['Arr slot'].round().astype('Int64')
SIN_2019_s_d1
# Out:
#        index Dep Airport Code                    Dep Airport Name  \
# 0     119479              CEB                                Cebu
# 1     727626              SIN                Singapore Changi Apt
# 2     726577              SIN                Singapore Changi Apt
# 3     707007              SIN                Singapore Changi Apt
# 4     491881              KUL  Kuala Lumpur International Airport
# ...      ...              ...                                 ...
# 1038  748653              SIN                Singapore Changi Apt
# 1039  745364              SIN                Singapore Changi Apt
# 1040  653369              REP                           Siem Reap
# 1041  647477              PVG   Shanghai Pudong International Apt
# 1042  697754              SIN                Singapore Changi Apt
#
#      Arr Airport Code                    Arr Airport Name ICAO AL IATA AL  \
# 0                 SIN                Singapore Changi Apt     SLK      MI
# 1                 KUL  Kuala Lumpur International Airport     MXD      OD
# 2                 KUL  Kuala Lumpur International Airport     MAS      MH
# 3                 PLM                           Palembang     TGW      TR
# 4                 SIN                Singapore Changi Apt     JSA      3K
# ...               ...                                 ...     ...     ...
# 1038              MEL                   Melbourne Airport     SIA      SQ
# 1039              KUL  Kuala Lumpur International Airport     MXD      OD
# 1040              SIN                Singapore Changi Apt     JSA      3K
# 1041              SIN                Singapore Changi Apt     CES      MU
# 1042              HDY                             Hat Yai     TGW      TR
#
#       Flight No Carrier Code            Carrier Name  ... Dep_utc_hour  \
# 0           567           MI                 SilkAir  ...            6
# 1           808           OD         Malindo Airways  ...            9
# 2           608           MH       Malaysia Airlines  ...           10
# 3           250           TR                   Scoot  ...            7
# 4           684           3K            Jetstar Asia  ...            0
# ...         ...          ...                     ...  ...          ...
# 1038        207           SQ      Singapore Airlines  ...           23
# 1039        806           OD         Malindo Airways  ...           13
# 1040        602           3K            Jetstar Asia  ...            7
# 1041        543           MU  China Eastern Airlines  ...           16
# 1042        634           TR                   Scoot  ...            5
#
#      Arr_utc_hour Dep_utc_minute  Arr_utc_minute  Dep_utc Arr_utc  \
# 0              10             45              30      645    1030
# 1              10             00              05      900    1005
# 2              11             10              20     1010    1120
# 3               8             45              05      745     805
# 4               2             50              00       50     200
# ...           ...            ...             ...      ...     ...
# 1038            9             45              10     2345     910
# 1039           14             30              35     1330    1435
# 1040           11             55              15      755    1115
# 1041           21             05              25     1605    2125
# 1042            6             35              10      535     610
#
#      Dep time slot  Arr time slot  Dep slot  Arr slot
# 0       [645, 650)   [1030, 1035)        82       127
# 1       [900, 905)   [1005, 1010)       109       122
# 2     [1010, 1015)   [1120, 1125)       123       137
# 3       [745, 750)     [805, 810)        94        98
# 4         [50, 55)     [200, 205)        11        25
# ...            ...            ...       ...       ...
# 1038  [2345, 2350)     [910, 915)       286       111
# 1039  [1330, 1335)   [1435, 1440)       163       176
# 1040    [755, 800)   [1115, 1120)        96       136
# 1041  [1605, 1610)   [2125, 2130)       194       258
# 1042    [535, 540)     [610, 615)        68        75
#
# [1043 rows x 48 columns]

# %%
def one_hot_encode_airport(airport, num_airports):
    encoding = np.zeros(num_airports)
    encoding[airport] = 1
    return encoding

def use_scenario(SIN_2019_s_d1, num_airports):
    
    number_of_requests = len(SIN_2019_s_d1.index)
    #ts_72 = get_truncated_normal(mean=72, sd=12, low=0, upp=287).rvs(int(round(number_of_requests/2)))
    #ts_72 = np.round(ts_72)

    #ts_216 = get_truncated_normal(mean=216, sd=12, low=0, upp=287).rvs(int(round(number_of_requests/2)))
    #ts_216 = np.round(ts_216)

    #ts_dep = np.concatenate((ts_72, ts_216))
    #ts_dep = ts_dep.astype(int)
    ts_dep = SIN_2019_s_d1['Dep slot'].to_numpy()
    ts_arr = SIN_2019_s_d1['Arr slot'].to_numpy()
    
    dep_airport = SIN_2019_s_d1['Dep'].to_numpy()
    arr_airport = SIN_2019_s_d1['Arr'].to_numpy() 

    #Generate index for requests:
    #index = np.array(list(range(number_of_requests)))
    index = SIN_2019_s_d1.index.to_numpy()

    #origin_airport = np.empty(shape=(number_of_requests,), dtype='object')
    
    #for i in range(number_of_requests):
        ##Generate origin (0 and 1 are two considered origin airports, 2 represent other airports, encoded in one-hot vector):
        #_org_airport = one_hot_encode_airport(0, num_airports)
        #_org_airport_list = _org_airport.tolist()
        #origin_airport[i] = _org_airport_list
       
    # Define requests_full as dtype object
    # requests_full = np.stack((index, ts_dep, start_date_dep, num_of_weeks, date_seq_dep, origin_airport, destination_airport, fly_time, status_cap_dep, ts_arv, start_date_arv, date_seq_arv, status_cap_arv), axis=1)
    num_entries = len(index)  # Given that 'index' is defined using np.array(list(range(number_of_requests)))
    # Create an empty array of the desired shape with dtype=object
    requests_full = np.empty((num_entries, 4), dtype=object)
   
    data = [ts_dep, ts_arr, dep_airport, arr_airport]
    for i, column_data in enumerate(data):
        requests_full[:, i] = column_data

    return requests_full, number_of_requests

# %%
num_airports = 2
use_scenario(SIN_2019_s_d1, num_airports)
# Out:
# (array([[82, 127, 0, 1],
#         [109, 122, 1, 0],
#         [123, 137, 1, 0],
#         ...,
#         [96, 136, 0, 1],
#         [194, 258, 0, 1],
#         [68, 75, 1, 0]], dtype=object),
#  1043)

# %%
from pulp import *

# %%
num_airports = 2
flight_requests, number_of_requests = use_scenario(SIN_2019_s_d1, num_airports)
#flight_requests = generate_scenario_MILP(requests)
time_slots = 288 # Time slots and their characteristics
capacity_per_slot = 6
max_movements = 6

# %%
# Create a MILP problem
problem = LpProblem(name="Flight_Scheduling", sense=LpMinimize)

# Creating binary decision variables for the departure slots of all flight requests
x = {(req, slot): LpVariable(
        name=f"x_{req}_{slot}", cat="Binary")
     for req in range(number_of_requests)
     for slot in range(time_slots)}

# Creating binary decision variables for the arrival slots of all flight requests
y = {(req, slot): LpVariable(
        name=f"y_{req}_{slot}", cat="Binary")
     for req in range(number_of_requests)
     for slot in range(time_slots)}

# Objective function - minimises the total absolute difference between the requested and allocated time interval
problem += lpSum((x[req, slot] * abs(slot - flight_requests[req][0])) for req in range(number_of_requests) for slot in range(time_slots))

# Constraints -
# ensure that only one slot is assigned to a flight
for req in range(number_of_requests):
    problem += lpSum(x[req, slot] for slot in range(time_slots)) == 1
    problem += lpSum(y[req, slot] for slot in range(time_slots)) == 1
    
# ensure slot interval between arrival and departure flight is equal to flying time
#for req in range(number_of_requests):
#    problem += lpSum(y[req, slot] * slot for slot in range(time_slots)) - lpSum(x[req, slot] * slot for slot in range(time_slots)) == flight_requests[req][1] - flight_requests[req][0]

x_req_belong_airport_0 = []
for req in range(number_of_requests):
    if flight_requests[req][2] == 0:
        x_req_belong_airport_0.append(1)
    else:
        x_req_belong_airport_0.append(0)

y_req_belong_airport_0 = []
for req in range(number_of_requests):
    if flight_requests[req][3] == 0:
        y_req_belong_airport_0.append(1)
    else:
        y_req_belong_airport_0.append(0)

# airport capacity constraints, which limit the number of arrivals and departures at airports
for slot in range(time_slots):
    problem += lpSum((x[req,slot] * x_req_belong_airport_0[req] + y[req,slot] * y_req_belong_airport_0[req]) for req in range(number_of_requests)) <= capacity_per_slot

x_req_belong_airport_1 = []
for req in range(number_of_requests):
    if flight_requests[req][2] == 1:
        x_req_belong_airport_1.append(1)
    else:
        x_req_belong_airport_1.append(0)

y_req_belong_airport_1 = []
for req in range(number_of_requests):
    if flight_requests[req][3] == 1:
        y_req_belong_airport_1.append(1)
    else:
        y_req_belong_airport_1.append(0)

# airport capacity constraints, which limit the number of arrivals and departures at airports
for slot in range(time_slots):
    problem += lpSum((x[req,slot] * x_req_belong_airport_1[req] + y[req,slot] * y_req_belong_airport_1[req]) for req in range(number_of_requests)) <= capacity_per_slot

# %%
import time

start_time = time.time()

# Solve the MILP problem
problem.solve()

# Calculate elapsed time
elapsed_time = time.time() - start_time
print(f"Time taken to solve: {elapsed_time} seconds")

updated_slots = []
max_change = float('-inf')
requests_unchanged = 0

# Iterate through the decision variables and check if they are equal to 1
for req in range(number_of_requests):
    dep_slot = None
    arv_slot = None
    for slot in range(time_slots):
        if not dep_slot and x[req, slot].varValue == 1:
            dep_slot = slot
        if not arv_slot and y[req, slot].varValue == 1:
            arv_slot = slot
        if dep_slot and arv_slot:
            break

    change = abs(flight_requests[req][0] - dep_slot)
    if change > max_change:
        max_change = change
    if not change:
        requests_unchanged += 1
    updated_slots.append((req, dep_slot, arv_slot, change))

# Print the slot changes
for entry in updated_slots:
    print(f"Flight Request {entry[0]}: Departure slot changed from slot {flight_requests[entry[0]][0]} to slot {flight_requests[entry[1]]}")

print("Status:", LpStatus[problem.status])
print(f"{requests_unchanged} flight requests out of {number_of_requests} were not shifted.")
print("Maximum Shift:", max_change)
print("Objective Value:", problem.objective.value())
# Out:
# Time taken to solve: 94.2591164112091 seconds
# Flight Request 0: Departure slot changed from slot 82 to slot [2 66 1 0]
# Flight Request 1: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 2: Departure slot changed from slot 123 to slot [157 171 1 0]
# Flight Request 3: Departure slot changed from slot 94 to slot [18 27 1 0]
# Flight Request 4: Departure slot changed from slot 11 to slot [285 6 1 0]
# Flight Request 5: Departure slot changed from slot 158 to slot [73 105 0 1]
# Flight Request 6: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 7: Departure slot changed from slot 23 to slot [119 137 1 0]
# Flight Request 8: Departure slot changed from slot 197 to slot [89 135 0 1]
# Flight Request 9: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 10: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 11: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 12: Departure slot changed from slot 118 to slot [213 251 1 0]
# Flight Request 13: Departure slot changed from slot 222 to slot [176 254 1 0]
# Flight Request 14: Departure slot changed from slot 273 to slot [143 160 0 1]
# Flight Request 15: Departure slot changed from slot 110 to slot [15 28 1 0]
# Flight Request 16: Departure slot changed from slot 147 to slot [77 92 0 1]
# Flight Request 17: Departure slot changed from slot 144 to slot [96 172 0 1]
# Flight Request 18: Departure slot changed from slot 200 to slot [126 162 0 1]
# Flight Request 19: Departure slot changed from slot 267 to slot [183 249 1 0]
# Flight Request 20: Departure slot changed from slot 29 to slot [159 223 0 1]
# Flight Request 21: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 22: Departure slot changed from slot 97 to slot [209 8 1 0]
# Flight Request 23: Departure slot changed from slot 119 to slot [151 236 0 1]
# Flight Request 24: Departure slot changed from slot 240 to slot [27 40 1 0]
# Flight Request 25: Departure slot changed from slot 98 to slot [5 63 1 0]
# Flight Request 26: Departure slot changed from slot 170 to slot [31 76 1 0]
# Flight Request 27: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 28: Departure slot changed from slot 139 to slot [164 205 0 1]
# Flight Request 29: Departure slot changed from slot 159 to slot [47 113 0 1]
# Flight Request 30: Departure slot changed from slot 90 to slot [73 94 1 0]
# Flight Request 31: Departure slot changed from slot 21 to slot [5 38 0 1]
# Flight Request 32: Departure slot changed from slot 270 to slot [163 199 0 1]
# Flight Request 33: Departure slot changed from slot 74 to slot [150 196 0 1]
# Flight Request 34: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 35: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 36: Departure slot changed from slot 9 to slot [95 113 1 0]
# Flight Request 37: Departure slot changed from slot 190 to slot [127 137 1 0]
# Flight Request 38: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 39: Departure slot changed from slot 83 to slot [22 86 1 0]
# Flight Request 40: Departure slot changed from slot 123 to slot [157 171 1 0]
# Flight Request 41: Departure slot changed from slot 259 to slot [173 188 0 1]
# Flight Request 42: Departure slot changed from slot 279 to slot [171 271 1 0]
# Flight Request 43: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 44: Departure slot changed from slot 24 to slot [240 288 1 0]
# Flight Request 45: Departure slot changed from slot 51 to slot [74 140 0 1]
# Flight Request 46: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 47: Departure slot changed from slot 189 to slot [84 121 0 1]
# Flight Request 48: Departure slot changed from slot 182 to slot [183 283 1 0]
# Flight Request 49: Departure slot changed from slot 1 to slot [109 122 1 0]
# Flight Request 50: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 51: Departure slot changed from slot 74 to slot [150 196 0 1]
# Flight Request 52: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 53: Departure slot changed from slot 54 to slot [191 262 0 1]
# Flight Request 54: Departure slot changed from slot 191 to slot [109 143 0 1]
# Flight Request 55: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 56: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 57: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 58: Departure slot changed from slot 86 to slot [48 139 0 1]
# Flight Request 59: Departure slot changed from slot 272 to slot [37 135 1 0]
# Flight Request 60: Departure slot changed from slot 48 to slot [182 267 0 1]
# Flight Request 61: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 62: Departure slot changed from slot 107 to slot [73 96 1 0]
# Flight Request 63: Departure slot changed from slot 2 to slot [123 137 1 0]
# Flight Request 64: Departure slot changed from slot 67 to slot [194 268 0 1]
# Flight Request 65: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 66: Departure slot changed from slot 125 to slot [138 157 0 1]
# Flight Request 67: Departure slot changed from slot 194 to slot [266 60 0 1]
# Flight Request 68: Departure slot changed from slot 111 to slot [111 176 0 1]
# Flight Request 69: Departure slot changed from slot 17 to slot [144 154 1 0]
# Flight Request 70: Departure slot changed from slot 276 to slot [108 128 0 1]
# Flight Request 71: Departure slot changed from slot 92 to slot [116 133 1 0]
# Flight Request 72: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 73: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 74: Departure slot changed from slot 150 to slot [127 137 1 0]
# Flight Request 75: Departure slot changed from slot 59 to slot [272 33 1 0]
# Flight Request 76: Departure slot changed from slot 98 to slot [5 63 1 0]
# Flight Request 77: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 78: Departure slot changed from slot 37 to slot [190 254 0 1]
# Flight Request 79: Departure slot changed from slot 15 to slot [110 132 1 0]
# Flight Request 80: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 81: Departure slot changed from slot 195 to slot [280 34 1 0]
# Flight Request 82: Departure slot changed from slot 2 to slot [123 137 1 0]
# Flight Request 83: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 84: Departure slot changed from slot 27 to slot [78 111 0 1]
# Flight Request 85: Departure slot changed from slot 84 to slot [27 107 0 1]
# Flight Request 86: Departure slot changed from slot 48 to slot [182 267 0 1]
# Flight Request 87: Departure slot changed from slot 269 to slot [79 111 0 1]
# Flight Request 88: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 89: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 90: Departure slot changed from slot 73 to slot [285 1 1 0]
# Flight Request 91: Departure slot changed from slot 116 to slot [244 271 1 0]
# Flight Request 92: Departure slot changed from slot 116 to slot [244 271 1 0]
# Flight Request 93: Departure slot changed from slot 11 to slot [285 6 1 0]
# Flight Request 94: Departure slot changed from slot 18 to slot [200 258 1 0]
# Flight Request 95: Departure slot changed from slot 131 to slot [273 39 0 1]
# Flight Request 96: Departure slot changed from slot 57 to slot [285 35 0 1]
# Flight Request 97: Departure slot changed from slot 209 to slot [71 114 1 0]
# Flight Request 98: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 99: Departure slot changed from slot 284 to slot [7 54 0 1]
# Flight Request 100: Departure slot changed from slot 48 to slot [182 267 0 1]
# Flight Request 101: Departure slot changed from slot 38 to slot [148 195 0 1]
# Flight Request 102: Departure slot changed from slot 288 to slot [126 175 0 1]
# Flight Request 103: Departure slot changed from slot 82 to slot [2 66 1 0]
# Flight Request 104: Departure slot changed from slot 133 to slot [145 169 1 0]
# Flight Request 105: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 106: Departure slot changed from slot 72 to slot [20 74 0 1]
# Flight Request 107: Departure slot changed from slot 73 to slot [285 1 1 0]
# Flight Request 108: Departure slot changed from slot 132 to slot [204 269 1 0]
# Flight Request 109: Departure slot changed from slot 214 to slot [3 101 1 0]
# Flight Request 110: Departure slot changed from slot 15 to slot [110 132 1 0]
# Flight Request 111: Departure slot changed from slot 111 to slot [111 176 0 1]
# Flight Request 112: Departure slot changed from slot 132 to slot [204 269 1 0]
# Flight Request 113: Departure slot changed from slot 102 to slot [288 76 0 1]
# Flight Request 114: Departure slot changed from slot 162 to slot [81 101 1 0]
# Flight Request 115: Departure slot changed from slot 266 to slot [100 154 0 1]
# Flight Request 116: Departure slot changed from slot 244 to slot [194 269 0 1]
# Flight Request 117: Departure slot changed from slot 207 to slot [83 128 1 0]
# Flight Request 118: Departure slot changed from slot 213 to slot [160 175 0 1]
# Flight Request 119: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 120: Departure slot changed from slot 178 to slot [46 91 1 0]
# Flight Request 121: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 122: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 123: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 124: Departure slot changed from slot 83 to slot [22 86 1 0]
# Flight Request 125: Departure slot changed from slot 138 to slot [208 272 1 0]
# Flight Request 126: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 127: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 128: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 129: Departure slot changed from slot 23 to slot [119 137 1 0]
# Flight Request 130: Departure slot changed from slot 188 to slot [14 28 0 1]
# Flight Request 131: Departure slot changed from slot 273 to slot [143 160 0 1]
# Flight Request 132: Departure slot changed from slot 204 to slot [1 50 1 0]
# Flight Request 133: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 134: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 135: Departure slot changed from slot 191 to slot [109 143 0 1]
# Flight Request 136: Departure slot changed from slot 4 to slot [11 25 0 1]
# Flight Request 137: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 138: Departure slot changed from slot 208 to slot [196 4 0 1]
# Flight Request 139: Departure slot changed from slot 164 to slot [127 181 0 1]
# Flight Request 140: Departure slot changed from slot 174 to slot [92 202 1 0]
# Flight Request 141: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 142: Departure slot changed from slot 85 to slot [84 144 0 1]
# Flight Request 143: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 144: Departure slot changed from slot 96 to slot [57 132 0 1]
# Flight Request 145: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 146: Departure slot changed from slot 267 to slot [183 249 1 0]
# Flight Request 147: Departure slot changed from slot 77 to slot [126 136 1 0]
# Flight Request 148: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 149: Departure slot changed from slot 16 to slot [147 188 1 0]
# Flight Request 150: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 151: Departure slot changed from slot 107 to slot [73 96 1 0]
# Flight Request 152: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 153: Departure slot changed from slot 224 to slot [175 201 1 0]
# Flight Request 154: Departure slot changed from slot 119 to slot [151 236 0 1]
# Flight Request 155: Departure slot changed from slot 114 to slot [162 187 1 0]
# Flight Request 156: Departure slot changed from slot 111 to slot [111 176 0 1]
# Flight Request 157: Departure slot changed from slot 130 to slot [188 276 1 0]
# Flight Request 158: Departure slot changed from slot 73 to slot [285 1 1 0]
# Flight Request 159: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 160: Departure slot changed from slot 152 to slot [22 38 1 0]
# Flight Request 161: Departure slot changed from slot 199 to slot [30 94 0 1]
# Flight Request 162: Departure slot changed from slot 81 to slot [195 271 0 1]
# Flight Request 163: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 164: Departure slot changed from slot 127 to slot [53 139 0 1]
# Flight Request 165: Departure slot changed from slot 139 to slot [164 205 0 1]
# Flight Request 166: Departure slot changed from slot 114 to slot [162 187 1 0]
# Flight Request 167: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 168: Departure slot changed from slot 56 to slot [104 118 1 0]
# Flight Request 169: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 170: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 171: Departure slot changed from slot 212 to slot [121 157 0 1]
# Flight Request 172: Departure slot changed from slot 203 to slot [187 253 0 1]
# Flight Request 173: Departure slot changed from slot 69 to slot [17 45 1 0]
# Flight Request 174: Departure slot changed from slot 92 to slot [116 133 1 0]
# Flight Request 175: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 176: Departure slot changed from slot 212 to slot [121 157 0 1]
# Flight Request 177: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 178: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 179: Departure slot changed from slot 146 to slot [267 13 0 1]
# Flight Request 180: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 181: Departure slot changed from slot 77 to slot [126 136 1 0]
# Flight Request 182: Departure slot changed from slot 183 to slot [35 117 0 1]
# Flight Request 183: Departure slot changed from slot 35 to slot [121 141 1 0]
# Flight Request 184: Departure slot changed from slot 63 to slot [2 51 1 0]
# Flight Request 185: Departure slot changed from slot 168 to slot [56 110 0 1]
# Flight Request 186: Departure slot changed from slot 147 to slot [77 92 0 1]
# Flight Request 187: Departure slot changed from slot 131 to slot [273 39 0 1]
# Flight Request 188: Departure slot changed from slot 14 to slot [273 285 1 0]
# Flight Request 189: Departure slot changed from slot 84 to slot [27 107 0 1]
# Flight Request 190: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 191: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 192: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 193: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 194: Departure slot changed from slot 266 to slot [100 154 0 1]
# Flight Request 195: Departure slot changed from slot 280 to slot [99 115 0 1]
# Flight Request 196: Departure slot changed from slot 90 to slot [73 94 1 0]
# Flight Request 197: Departure slot changed from slot 89 to slot [151 194 0 1]
# Flight Request 198: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 199: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 200: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 201: Departure slot changed from slot 86 to slot [48 139 0 1]
# Flight Request 202: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 203: Departure slot changed from slot 187 to slot [131 145 0 1]
# Flight Request 204: Departure slot changed from slot 1 to slot [109 122 1 0]
# Flight Request 205: Departure slot changed from slot 120 to slot [178 275 0 1]
# Flight Request 206: Departure slot changed from slot 264 to slot [186 268 1 0]
# Flight Request 207: Departure slot changed from slot 83 to slot [22 86 1 0]
# Flight Request 208: Departure slot changed from slot 196 to slot [90 108 1 0]
# Flight Request 209: Departure slot changed from slot 71 to slot [92 108 0 1]
# Flight Request 210: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 211: Departure slot changed from slot 207 to slot [83 128 1 0]
# Flight Request 212: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 213: Departure slot changed from slot 160 to slot [152 184 0 1]
# Flight Request 214: Departure slot changed from slot 3 to slot [94 98 1 0]
# Flight Request 215: Departure slot changed from slot 33 to slot [74 119 1 0]
# Flight Request 216: Departure slot changed from slot 130 to slot [188 276 1 0]
# Flight Request 217: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 218: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 219: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 220: Departure slot changed from slot 58 to slot [86 99 0 1]
# Flight Request 221: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 222: Departure slot changed from slot 176 to slot [212 37 1 0]
# Flight Request 223: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 224: Departure slot changed from slot 175 to slot [99 136 0 1]
# Flight Request 225: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 226: Departure slot changed from slot 56 to slot [104 118 1 0]
# Flight Request 227: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 228: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 229: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 230: Departure slot changed from slot 215 to slot [33 82 0 1]
# Flight Request 231: Departure slot changed from slot 175 to slot [99 136 0 1]
# Flight Request 232: Departure slot changed from slot 70 to slot [276 23 0 1]
# Flight Request 233: Departure slot changed from slot 135 to slot [191 287 0 1]
# Flight Request 234: Departure slot changed from slot 87 to slot [269 278 1 0]
# Flight Request 235: Departure slot changed from slot 181 to slot [77 114 0 1]
# Flight Request 236: Departure slot changed from slot 161 to slot [199 243 1 0]
# Flight Request 237: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 238: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 239: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 240: Departure slot changed from slot 27 to slot [78 111 0 1]
# Flight Request 241: Departure slot changed from slot 191 to slot [109 143 0 1]
# Flight Request 242: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 243: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 244: Departure slot changed from slot 194 to slot [266 60 0 1]
# Flight Request 245: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 246: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 247: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 248: Departure slot changed from slot 150 to slot [127 137 1 0]
# Flight Request 249: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 250: Departure slot changed from slot 81 to slot [195 271 0 1]
# Flight Request 251: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 252: Departure slot changed from slot 107 to slot [73 96 1 0]
# Flight Request 253: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 254: Departure slot changed from slot 176 to slot [212 37 1 0]
# Flight Request 255: Departure slot changed from slot 287 to slot [126 175 0 1]
# Flight Request 256: Departure slot changed from slot 56 to slot [104 118 1 0]
# Flight Request 257: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 258: Departure slot changed from slot 77 to slot [126 136 1 0]
# Flight Request 259: Departure slot changed from slot 173 to slot [69 81 1 0]
# Flight Request 260: Departure slot changed from slot 79 to slot [15 91 0 1]
# Flight Request 261: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 262: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 263: Departure slot changed from slot 268 to slot [178 53 1 0]
# Flight Request 264: Departure slot changed from slot 186 to slot [147 196 1 0]
# Flight Request 265: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 266: Departure slot changed from slot 100 to slot [48 89 1 0]
# Flight Request 267: Departure slot changed from slot 183 to slot [35 117 0 1]
# Flight Request 268: Departure slot changed from slot 178 to slot [46 91 1 0]
# Flight Request 269: Departure slot changed from slot 79 to slot [15 91 0 1]
# Flight Request 270: Departure slot changed from slot 163 to slot [28 72 1 0]
# Flight Request 271: Departure slot changed from slot 286 to slot [46 60 0 1]
# Flight Request 272: Departure slot changed from slot 37 to slot [190 254 0 1]
# Flight Request 273: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 274: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 275: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 276: Departure slot changed from slot 108 to slot [132 184 0 1]
# Flight Request 277: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 278: Departure slot changed from slot 37 to slot [190 254 0 1]
# Flight Request 279: Departure slot changed from slot 171 to slot [212 257 1 0]
# Flight Request 280: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 281: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 282: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 283: Departure slot changed from slot 142 to slot [85 139 1 0]
# Flight Request 284: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 285: Departure slot changed from slot 284 to slot [7 54 0 1]
# Flight Request 286: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 287: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 288: Departure slot changed from slot 1 to slot [109 122 1 0]
# Flight Request 289: Departure slot changed from slot 92 to slot [116 133 1 0]
# Flight Request 290: Departure slot changed from slot 41 to slot [259 283 1 0]
# Flight Request 291: Departure slot changed from slot 203 to slot [187 253 0 1]
# Flight Request 292: Departure slot changed from slot 71 to slot [92 108 0 1]
# Flight Request 293: Departure slot changed from slot 101 to slot [38 112 0 1]
# Flight Request 294: Departure slot changed from slot 103 to slot [82 154 0 1]
# Flight Request 295: Departure slot changed from slot 238 to slot [12 30 1 0]
# Flight Request 296: Departure slot changed from slot 36 to slot [9 23 0 1]
# Flight Request 297: Departure slot changed from slot 27 to slot [78 111 0 1]
# Flight Request 298: Departure slot changed from slot 124 to slot [83 129 0 1]
# Flight Request 299: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 300: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 301: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 302: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 303: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 304: Departure slot changed from slot 65 to slot [7 76 0 1]
# Flight Request 305: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 306: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 307: Departure slot changed from slot 160 to slot [152 184 0 1]
# Flight Request 308: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 309: Departure slot changed from slot 101 to slot [38 112 0 1]
# Flight Request 310: Departure slot changed from slot 93 to slot [11 69 1 0]
# Flight Request 311: Departure slot changed from slot 48 to slot [182 267 0 1]
# Flight Request 312: Departure slot changed from slot 195 to slot [280 34 1 0]
# Flight Request 313: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 314: Departure slot changed from slot 182 to slot [183 283 1 0]
# Flight Request 315: Departure slot changed from slot 133 to slot [145 169 1 0]
# Flight Request 316: Departure slot changed from slot 54 to slot [191 262 0 1]
# Flight Request 317: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 318: Departure slot changed from slot 113 to slot [102 137 0 1]
# Flight Request 319: Departure slot changed from slot 158 to slot [73 105 0 1]
# Flight Request 320: Departure slot changed from slot 117 to slot [207 280 1 0]
# Flight Request 321: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 322: Departure slot changed from slot 4 to slot [11 25 0 1]
# Flight Request 323: Departure slot changed from slot 94 to slot [18 27 1 0]
# Flight Request 324: Departure slot changed from slot 140 to slot [174 191 0 1]
# Flight Request 325: Departure slot changed from slot 105 to slot [145 156 1 0]
# Flight Request 326: Departure slot changed from slot 3 to slot [94 98 1 0]
# Flight Request 327: Departure slot changed from slot 155 to slot [114 190 0 1]
# Flight Request 328: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 329: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 330: Departure slot changed from slot 74 to slot [150 196 0 1]
# Flight Request 331: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 332: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 333: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 334: Departure slot changed from slot 21 to slot [5 38 0 1]
# Flight Request 335: Departure slot changed from slot 100 to slot [48 89 1 0]
# Flight Request 336: Departure slot changed from slot 188 to slot [14 28 0 1]
# Flight Request 337: Departure slot changed from slot 165 to slot [139 155 0 1]
# Flight Request 338: Departure slot changed from slot 166 to slot [114 157 1 0]
# Flight Request 339: Departure slot changed from slot 106 to slot [72 164 1 0]
# Flight Request 340: Departure slot changed from slot 120 to slot [178 275 0 1]
# Flight Request 341: Departure slot changed from slot 169 to slot [99 112 1 0]
# Flight Request 342: Departure slot changed from slot 88 to slot [66 82 0 1]
# Flight Request 343: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 344: Departure slot changed from slot 15 to slot [110 132 1 0]
# Flight Request 345: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 346: Departure slot changed from slot 288 to slot [126 175 0 1]
# Flight Request 347: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 348: Departure slot changed from slot 166 to slot [114 157 1 0]
# Flight Request 349: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 350: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 351: Departure slot changed from slot 150 to slot [127 137 1 0]
# Flight Request 352: Departure slot changed from slot 198 to slot [109 184 0 1]
# Flight Request 353: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 354: Departure slot changed from slot 16 to slot [147 188 1 0]
# Flight Request 355: Departure slot changed from slot 59 to slot [272 33 1 0]
# Flight Request 356: Departure slot changed from slot 168 to slot [56 110 0 1]
# Flight Request 357: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 358: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 359: Departure slot changed from slot 146 to slot [267 13 0 1]
# Flight Request 360: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 361: Departure slot changed from slot 9 to slot [95 113 1 0]
# Flight Request 362: Departure slot changed from slot 96 to slot [57 132 0 1]
# Flight Request 363: Departure slot changed from slot 131 to slot [273 39 0 1]
# Flight Request 364: Departure slot changed from slot 18 to slot [200 258 1 0]
# Flight Request 365: Departure slot changed from slot 214 to slot [3 101 1 0]
# Flight Request 366: Departure slot changed from slot 87 to slot [269 278 1 0]
# Flight Request 367: Departure slot changed from slot 279 to slot [171 271 1 0]
# Flight Request 368: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 369: Departure slot changed from slot 19 to slot [267 77 1 0]
# Flight Request 370: Departure slot changed from slot 103 to slot [82 154 0 1]
# Flight Request 371: Departure slot changed from slot 18 to slot [200 258 1 0]
# Flight Request 372: Departure slot changed from slot 91 to slot [116 149 0 1]
# Flight Request 373: Departure slot changed from slot 189 to slot [84 121 0 1]
# Flight Request 374: Departure slot changed from slot 187 to slot [131 145 0 1]
# Flight Request 375: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 376: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 377: Departure slot changed from slot 260 to slot [79 126 0 1]
# Flight Request 378: Departure slot changed from slot 144 to slot [96 172 0 1]
# Flight Request 379: Departure slot changed from slot 80 to slot [179 197 1 0]
# Flight Request 380: Departure slot changed from slot 187 to slot [131 145 0 1]
# Flight Request 381: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 382: Departure slot changed from slot 63 to slot [2 51 1 0]
# Flight Request 383: Departure slot changed from slot 92 to slot [116 133 1 0]
# Flight Request 384: Departure slot changed from slot 71 to slot [92 108 0 1]
# Flight Request 385: Departure slot changed from slot 32 to slot [270 46 0 1]
# Flight Request 386: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 387: Departure slot changed from slot 118 to slot [213 251 1 0]
# Flight Request 388: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 389: Departure slot changed from slot 197 to slot [89 135 0 1]
# Flight Request 390: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 391: Departure slot changed from slot 162 to slot [81 101 1 0]
# Flight Request 392: Departure slot changed from slot 94 to slot [18 27 1 0]
# Flight Request 393: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 394: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 395: Departure slot changed from slot 122 to slot [151 169 0 1]
# Flight Request 396: Departure slot changed from slot 1 to slot [109 122 1 0]
# Flight Request 397: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 398: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 399: Departure slot changed from slot 265 to slot [157 176 1 0]
# Flight Request 400: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 401: Departure slot changed from slot 88 to slot [66 82 0 1]
# Flight Request 402: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 403: Departure slot changed from slot 256 to slot [56 136 1 0]
# Flight Request 404: Departure slot changed from slot 118 to slot [213 251 1 0]
# Flight Request 405: Departure slot changed from slot 277 to slot [109 176 1 0]
# Flight Request 406: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 407: Departure slot changed from slot 96 to slot [57 132 0 1]
# Flight Request 408: Departure slot changed from slot 71 to slot [92 108 0 1]
# Flight Request 409: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 410: Departure slot changed from slot 26 to slot [170 181 1 0]
# Flight Request 411: Departure slot changed from slot 116 to slot [244 271 1 0]
# Flight Request 412: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 413: Departure slot changed from slot 161 to slot [199 243 1 0]
# Flight Request 414: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 415: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 416: Departure slot changed from slot 149 to slot [16 48 1 0]
# Flight Request 417: Departure slot changed from slot 201 to slot [86 141 1 0]
# Flight Request 418: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 419: Departure slot changed from slot 258 to slot [77 132 0 1]
# Flight Request 420: Departure slot changed from slot 139 to slot [164 205 0 1]
# Flight Request 421: Departure slot changed from slot 87 to slot [269 278 1 0]
# Flight Request 422: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 423: Departure slot changed from slot 213 to slot [160 175 0 1]
# Flight Request 424: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 425: Departure slot changed from slot 149 to slot [16 48 1 0]
# Flight Request 426: Departure slot changed from slot 279 to slot [171 271 1 0]
# Flight Request 427: Departure slot changed from slot 163 to slot [28 72 1 0]
# Flight Request 428: Departure slot changed from slot 36 to slot [9 23 0 1]
# Flight Request 429: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 430: Departure slot changed from slot 160 to slot [152 184 0 1]
# Flight Request 431: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 432: Departure slot changed from slot 19 to slot [267 77 1 0]
# Flight Request 433: Departure slot changed from slot 23 to slot [119 137 1 0]
# Flight Request 434: Departure slot changed from slot 27 to slot [78 111 0 1]
# Flight Request 435: Departure slot changed from slot 97 to slot [209 8 1 0]
# Flight Request 436: Departure slot changed from slot 81 to slot [195 271 0 1]
# Flight Request 437: Departure slot changed from slot 126 to slot [53 139 0 1]
# Flight Request 438: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 439: Departure slot changed from slot 42 to slot [279 24 0 1]
# Flight Request 440: Departure slot changed from slot 60 to slot [48 105 1 0]
# Flight Request 441: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 442: Departure slot changed from slot 17 to slot [144 154 1 0]
# Flight Request 443: Departure slot changed from slot 161 to slot [199 243 1 0]
# Flight Request 444: Departure slot changed from slot 153 to slot [224 4 0 1]
# Flight Request 445: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 446: Departure slot changed from slot 158 to slot [73 105 0 1]
# Flight Request 447: Departure slot changed from slot 125 to slot [138 157 0 1]
# Flight Request 448: Departure slot changed from slot 40 to slot [123 196 0 1]
# Flight Request 449: Departure slot changed from slot 181 to slot [77 114 0 1]
# Flight Request 450: Departure slot changed from slot 189 to slot [84 121 0 1]
# Flight Request 451: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 452: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 453: Departure slot changed from slot 211 to slot [207 272 0 1]
# Flight Request 454: Departure slot changed from slot 279 to slot [171 271 1 0]
# Flight Request 455: Departure slot changed from slot 271 to slot [286 13 1 0]
# Flight Request 456: Departure slot changed from slot 33 to slot [74 119 1 0]
# Flight Request 457: Departure slot changed from slot 203 to slot [187 253 0 1]
# Flight Request 458: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 459: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 460: Departure slot changed from slot 44 to slot [24 48 0 1]
# Flight Request 461: Departure slot changed from slot 141 to slot [28 67 0 1]
# Flight Request 462: Departure slot changed from slot 90 to slot [73 94 1 0]
# Flight Request 463: Departure slot changed from slot 155 to slot [114 190 0 1]
# Flight Request 464: Departure slot changed from slot 222 to slot [176 254 1 0]
# Flight Request 465: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 466: Departure slot changed from slot 194 to slot [266 60 0 1]
# Flight Request 467: Departure slot changed from slot 85 to slot [84 144 0 1]
# Flight Request 468: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 469: Departure slot changed from slot 169 to slot [99 112 1 0]
# Flight Request 470: Departure slot changed from slot 147 to slot [77 92 0 1]
# Flight Request 471: Departure slot changed from slot 24 to slot [240 288 1 0]
# Flight Request 472: Departure slot changed from slot 51 to slot [74 140 0 1]
# Flight Request 473: Departure slot changed from slot 259 to slot [173 188 0 1]
# Flight Request 474: Departure slot changed from slot 280 to slot [99 115 0 1]
# Flight Request 475: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 476: Departure slot changed from slot 155 to slot [114 190 0 1]
# Flight Request 477: Departure slot changed from slot 259 to slot [173 188 0 1]
# Flight Request 478: Departure slot changed from slot 152 to slot [22 38 1 0]
# Flight Request 479: Departure slot changed from slot 183 to slot [35 117 0 1]
# Flight Request 480: Departure slot changed from slot 168 to slot [56 110 0 1]
# Flight Request 481: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 482: Departure slot changed from slot 183 to slot [35 117 0 1]
# Flight Request 483: Departure slot changed from slot 146 to slot [267 13 0 1]
# Flight Request 484: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 485: Departure slot changed from slot 196 to slot [90 108 1 0]
# Flight Request 486: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 487: Departure slot changed from slot 91 to slot [116 149 0 1]
# Flight Request 488: Departure slot changed from slot 13 to slot [222 23 1 0]
# Flight Request 489: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 490: Departure slot changed from slot 199 to slot [30 94 0 1]
# Flight Request 491: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 492: Departure slot changed from slot 41 to slot [259 283 1 0]
# Flight Request 493: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 494: Departure slot changed from slot 214 to slot [3 101 1 0]
# Flight Request 495: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 496: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 497: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 498: Departure slot changed from slot 222 to slot [176 254 1 0]
# Flight Request 499: Departure slot changed from slot 130 to slot [188 276 1 0]
# Flight Request 500: Departure slot changed from slot 202 to slot [148 182 0 1]
# Flight Request 501: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 502: Departure slot changed from slot 15 to slot [110 132 1 0]
# Flight Request 503: Departure slot changed from slot 119 to slot [151 236 0 1]
# Flight Request 504: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 505: Departure slot changed from slot 18 to slot [200 258 1 0]
# Flight Request 506: Departure slot changed from slot 10 to slot [30 43 0 1]
# Flight Request 507: Departure slot changed from slot 288 to slot [126 175 0 1]
# Flight Request 508: Departure slot changed from slot 33 to slot [74 119 1 0]
# Flight Request 509: Departure slot changed from slot 44 to slot [24 48 0 1]
# Flight Request 510: Departure slot changed from slot 40 to slot [123 196 0 1]
# Flight Request 511: Departure slot changed from slot 32 to slot [270 46 0 1]
# Flight Request 512: Departure slot changed from slot 8 to slot [197 265 1 0]
# Flight Request 513: Departure slot changed from slot 167 to slot [5 53 1 0]
# Flight Request 514: Departure slot changed from slot 14 to slot [273 285 1 0]
# Flight Request 515: Departure slot changed from slot 82 to slot [2 66 1 0]
# Flight Request 516: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 517: Departure slot changed from slot 183 to slot [35 117 0 1]
# Flight Request 518: Departure slot changed from slot 138 to slot [208 272 1 0]
# Flight Request 519: Departure slot changed from slot 217 to slot [49 275 0 1]
# Flight Request 520: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 521: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 522: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 523: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 524: Departure slot changed from slot 83 to slot [22 86 1 0]
# Flight Request 525: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 526: Departure slot changed from slot 59 to slot [272 33 1 0]
# Flight Request 527: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 528: Departure slot changed from slot 27 to slot [78 111 0 1]
# Flight Request 529: Departure slot changed from slot 6 to slot [47 63 1 0]
# Flight Request 530: Departure slot changed from slot 64 to slot [67 253 0 1]
# Flight Request 531: Departure slot changed from slot 110 to slot [15 28 1 0]
# Flight Request 532: Departure slot changed from slot 194 to slot [266 60 0 1]
# Flight Request 533: Departure slot changed from slot 93 to slot [11 69 1 0]
# Flight Request 534: Departure slot changed from slot 161 to slot [199 243 1 0]
# Flight Request 535: Departure slot changed from slot 284 to slot [7 54 0 1]
# Flight Request 536: Departure slot changed from slot 287 to slot [126 175 0 1]
# Flight Request 537: Departure slot changed from slot 62 to slot [107 147 1 0]
# Flight Request 538: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 539: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 540: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 541: Departure slot changed from slot 111 to slot [111 176 0 1]
# Flight Request 542: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 543: Departure slot changed from slot 19 to slot [267 77 1 0]
# Flight Request 544: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 545: Departure slot changed from slot 15 to slot [110 132 1 0]
# Flight Request 546: Departure slot changed from slot 4 to slot [11 25 0 1]
# Flight Request 547: Departure slot changed from slot 180 to slot [30 111 0 1]
# Flight Request 548: Departure slot changed from slot 3 to slot [94 98 1 0]
# Flight Request 549: Departure slot changed from slot 140 to slot [174 191 0 1]
# Flight Request 550: Departure slot changed from slot 185 to slot [168 98 0 1]
# Flight Request 551: Departure slot changed from slot 128 to slot [95 121 1 0]
# Flight Request 552: Departure slot changed from slot 113 to slot [102 137 0 1]
# Flight Request 553: Departure slot changed from slot 11 to slot [285 6 1 0]
# Flight Request 554: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 555: Departure slot changed from slot 253 to slot [283 27 0 1]
# Flight Request 556: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 557: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 558: Departure slot changed from slot 175 to slot [99 136 0 1]
# Flight Request 559: Departure slot changed from slot 175 to slot [99 136 0 1]
# Flight Request 560: Departure slot changed from slot 60 to slot [48 105 1 0]
# Flight Request 561: Departure slot changed from slot 159 to slot [47 113 0 1]
# Flight Request 562: Departure slot changed from slot 58 to slot [86 99 0 1]
# Flight Request 563: Departure slot changed from slot 25 to slot [98 135 0 1]
# Flight Request 564: Departure slot changed from slot 181 to slot [77 114 0 1]
# Flight Request 565: Departure slot changed from slot 227 to slot [179 269 1 0]
# Flight Request 566: Departure slot changed from slot 277 to slot [109 176 1 0]
# Flight Request 567: Departure slot changed from slot 188 to slot [14 28 0 1]
# Flight Request 568: Departure slot changed from slot 81 to slot [195 271 0 1]
# Flight Request 569: Departure slot changed from slot 24 to slot [240 288 1 0]
# Flight Request 570: Departure slot changed from slot 285 to slot [284 8 0 1]
# Flight Request 571: Departure slot changed from slot 155 to slot [114 190 0 1]
# Flight Request 572: Departure slot changed from slot 8 to slot [197 265 1 0]
# Flight Request 573: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 574: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 575: Departure slot changed from slot 14 to slot [273 285 1 0]
# Flight Request 576: Departure slot changed from slot 91 to slot [116 149 0 1]
# Flight Request 577: Departure slot changed from slot 159 to slot [47 113 0 1]
# Flight Request 578: Departure slot changed from slot 75 to slot [59 91 0 1]
# Flight Request 579: Departure slot changed from slot 173 to slot [69 81 1 0]
# Flight Request 580: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 581: Departure slot changed from slot 140 to slot [174 191 0 1]
# Flight Request 582: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 583: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 584: Departure slot changed from slot 142 to slot [85 139 1 0]
# Flight Request 585: Departure slot changed from slot 186 to slot [147 196 1 0]
# Flight Request 586: Departure slot changed from slot 26 to slot [170 181 1 0]
# Flight Request 587: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 588: Departure slot changed from slot 287 to slot [126 175 0 1]
# Flight Request 589: Departure slot changed from slot 147 to slot [77 92 0 1]
# Flight Request 590: Departure slot changed from slot 124 to slot [83 129 0 1]
# Flight Request 591: Departure slot changed from slot 100 to slot [48 89 1 0]
# Flight Request 592: Departure slot changed from slot 209 to slot [71 114 1 0]
# Flight Request 593: Departure slot changed from slot 45 to slot [51 76 1 0]
# Flight Request 594: Departure slot changed from slot 81 to slot [195 271 0 1]
# Flight Request 595: Departure slot changed from slot 120 to slot [178 275 0 1]
# Flight Request 596: Departure slot changed from slot 93 to slot [11 69 1 0]
# Flight Request 597: Departure slot changed from slot 207 to slot [83 128 1 0]
# Flight Request 598: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 599: Departure slot changed from slot 129 to slot [23 57 0 1]
# Flight Request 600: Departure slot changed from slot 151 to slot [107 181 1 0]
# Flight Request 601: Departure slot changed from slot 90 to slot [73 94 1 0]
# Flight Request 602: Departure slot changed from slot 40 to slot [123 196 0 1]
# Flight Request 603: Departure slot changed from slot 18 to slot [200 258 1 0]
# Flight Request 604: Departure slot changed from slot 168 to slot [56 110 0 1]
# Flight Request 605: Departure slot changed from slot 59 to slot [272 33 1 0]
# Flight Request 606: Departure slot changed from slot 287 to slot [126 175 0 1]
# Flight Request 607: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 608: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 609: Departure slot changed from slot 198 to slot [109 184 0 1]
# Flight Request 610: Departure slot changed from slot 108 to slot [132 184 0 1]
# Flight Request 611: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 612: Departure slot changed from slot 70 to slot [276 23 0 1]
# Flight Request 613: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 614: Departure slot changed from slot 41 to slot [259 283 1 0]
# Flight Request 615: Departure slot changed from slot 104 to slot [133 137 1 0]
# Flight Request 616: Departure slot changed from slot 117 to slot [207 280 1 0]
# Flight Request 617: Departure slot changed from slot 10 to slot [30 43 0 1]
# ...
# Flight Request 839: Departure slot changed from slot 131 to slot [273 39 0 1]
# Flight Request 840: Departure slot changed from slot 265 to slot [157 176 1 0]
# Flight Request 841: Departure slot changed from slot 144 to slot [96 172 0 1]
# Flight Request 842: Departure slot changed from slot 278 to slot [37 73 0 1]
# Flight Request 843: Departure slot changed from slot 133 to slot [145 169 1 0]
# Flight Request 844: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 845: Departure slot changed from slot 21 to slot [5 38 0 1]
# Flight Request 846: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 847: Departure slot changed from slot 34 to slot [285 9 1 0]
# Flight Request 848: Departure slot changed from slot 38 to slot [148 195 0 1]
# Flight Request 849: Departure slot changed from slot 184 to slot [63 277 0 1]
# Flight Request 850: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 851: Departure slot changed from slot 163 to slot [28 72 1 0]
# Flight Request 852: Departure slot changed from slot 36 to slot [9 23 0 1]
# Flight Request 853: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 854: Departure slot changed from slot 10 to slot [30 43 0 1]
# Flight Request 855: Departure slot changed from slot 108 to slot [132 184 0 1]
# Flight Request 856: Departure slot changed from slot 160 to slot [152 184 0 1]
# Flight Request 857: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 858: Departure slot changed from slot 156 to slot [111 123 0 1]
# Flight Request 859: Departure slot changed from slot 86 to slot [48 139 0 1]
# Flight Request 860: Departure slot changed from slot 17 to slot [144 154 1 0]
# Flight Request 861: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 862: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 863: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 864: Departure slot changed from slot 283 to slot [142 255 1 0]
# Flight Request 865: Departure slot changed from slot 88 to slot [66 82 0 1]
# Flight Request 866: Departure slot changed from slot 169 to slot [99 112 1 0]
# Flight Request 867: Departure slot changed from slot 63 to slot [2 51 1 0]
# Flight Request 868: Departure slot changed from slot 42 to slot [279 24 0 1]
# Flight Request 869: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 870: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 871: Departure slot changed from slot 140 to slot [174 191 0 1]
# Flight Request 872: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 873: Departure slot changed from slot 147 to slot [77 92 0 1]
# Flight Request 874: Departure slot changed from slot 55 to slot [104 181 0 1]
# Flight Request 875: Departure slot changed from slot 182 to slot [183 283 1 0]
# Flight Request 876: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 877: Departure slot changed from slot 26 to slot [170 181 1 0]
# Flight Request 878: Departure slot changed from slot 67 to slot [194 268 0 1]
# Flight Request 879: Departure slot changed from slot 281 to slot [179 238 0 1]
# Flight Request 880: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 881: Departure slot changed from slot 99 to slot [284 38 1 0]
# Flight Request 882: Departure slot changed from slot 223 to slot [285 41 0 1]
# Flight Request 883: Departure slot changed from slot 109 to slot [214 259 0 1]
# Flight Request 884: Departure slot changed from slot 30 to slot [90 102 1 0]
# Flight Request 885: Departure slot changed from slot 287 to slot [126 175 0 1]
# Flight Request 886: Departure slot changed from slot 87 to slot [269 278 1 0]
# Flight Request 887: Departure slot changed from slot 53 to slot [54 64 1 0]
# Flight Request 888: Departure slot changed from slot 262 to slot [151 161 1 0]
# Flight Request 889: Departure slot changed from slot 166 to slot [114 157 1 0]
# Flight Request 890: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 891: Departure slot changed from slot 51 to slot [74 140 0 1]
# Flight Request 892: Departure slot changed from slot 55 to slot [104 181 0 1]
# Flight Request 893: Departure slot changed from slot 45 to slot [51 76 1 0]
# Flight Request 894: Departure slot changed from slot 278 to slot [37 73 0 1]
# Flight Request 895: Departure slot changed from slot 201 to slot [86 141 1 0]
# Flight Request 896: Departure slot changed from slot 88 to slot [66 82 0 1]
# Flight Request 897: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 898: Departure slot changed from slot 55 to slot [104 181 0 1]
# Flight Request 899: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 900: Departure slot changed from slot 136 to slot [4 14 1 0]
# Flight Request 901: Departure slot changed from slot 79 to slot [15 91 0 1]
# Flight Request 902: Departure slot changed from slot 200 to slot [126 162 0 1]
# Flight Request 903: Departure slot changed from slot 138 to slot [208 272 1 0]
# Flight Request 904: Departure slot changed from slot 200 to slot [126 162 0 1]
# Flight Request 905: Departure slot changed from slot 211 to slot [207 272 0 1]
# Flight Request 906: Departure slot changed from slot 205 to slot [120 133 1 0]
# Flight Request 907: Departure slot changed from slot 178 to slot [46 91 1 0]
# Flight Request 908: Departure slot changed from slot 217 to slot [49 275 0 1]
# Flight Request 909: Departure slot changed from slot 32 to slot [270 46 0 1]
# Flight Request 910: Departure slot changed from slot 95 to slot [131 142 1 0]
# Flight Request 911: Departure slot changed from slot 75 to slot [59 91 0 1]
# Flight Request 912: Departure slot changed from slot 203 to slot [187 253 0 1]
# Flight Request 913: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 914: Departure slot changed from slot 138 to slot [208 272 1 0]
# Flight Request 915: Departure slot changed from slot 14 to slot [273 285 1 0]
# Flight Request 916: Departure slot changed from slot 170 to slot [31 76 1 0]
# Flight Request 917: Departure slot changed from slot 90 to slot [73 94 1 0]
# Flight Request 918: Departure slot changed from slot 29 to slot [159 223 0 1]
# Flight Request 919: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 920: Departure slot changed from slot 80 to slot [179 197 1 0]
# Flight Request 921: Departure slot changed from slot 40 to slot [123 196 0 1]
# Flight Request 922: Departure slot changed from slot 94 to slot [18 27 1 0]
# Flight Request 923: Departure slot changed from slot 32 to slot [270 46 0 1]
# Flight Request 924: Departure slot changed from slot 20 to slot [29 39 1 0]
# Flight Request 925: Departure slot changed from slot 72 to slot [20 74 0 1]
# Flight Request 926: Departure slot changed from slot 102 to slot [288 76 0 1]
# Flight Request 927: Departure slot changed from slot 115 to slot [266 18 0 1]
# Flight Request 928: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 929: Departure slot changed from slot 139 to slot [164 205 0 1]
# Flight Request 930: Departure slot changed from slot 93 to slot [11 69 1 0]
# Flight Request 931: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 932: Departure slot changed from slot 52 to slot [184 217 0 1]
# Flight Request 933: Departure slot changed from slot 10 to slot [30 43 0 1]
# Flight Request 934: Departure slot changed from slot 172 to slot [203 2 0 1]
# Flight Request 935: Departure slot changed from slot 107 to slot [73 96 1 0]
# Flight Request 936: Departure slot changed from slot 98 to slot [5 63 1 0]
# Flight Request 937: Departure slot changed from slot 35 to slot [121 141 1 0]
# Flight Request 938: Departure slot changed from slot 288 to slot [126 175 0 1]
# Flight Request 939: Departure slot changed from slot 117 to slot [207 280 1 0]
# Flight Request 940: Departure slot changed from slot 121 to slot [13 34 1 0]
# Flight Request 941: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 942: Departure slot changed from slot 157 to slot [130 142 1 0]
# Flight Request 943: Departure slot changed from slot 265 to slot [157 176 1 0]
# Flight Request 944: Departure slot changed from slot 64 to slot [67 253 0 1]
# Flight Request 945: Departure slot changed from slot 165 to slot [139 155 0 1]
# Flight Request 946: Departure slot changed from slot 180 to slot [30 111 0 1]
# Flight Request 947: Departure slot changed from slot 288 to slot [126 175 0 1]
# Flight Request 948: Departure slot changed from slot 167 to slot [5 53 1 0]
# Flight Request 949: Departure slot changed from slot 12 to slot [118 145 0 1]
# Flight Request 950: Departure slot changed from slot 7 to slot [23 74 1 0]
# Flight Request 951: Departure slot changed from slot 4 to slot [11 25 0 1]
# Flight Request 952: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 953: Departure slot changed from slot 211 to slot [207 272 0 1]
# Flight Request 954: Departure slot changed from slot 55 to slot [104 181 0 1]
# Flight Request 955: Departure slot changed from slot 46 to slot [39 57 0 1]
# Flight Request 956: Departure slot changed from slot 261 to slot [7 20 1 0]
# Flight Request 957: Departure slot changed from slot 9 to slot [95 113 1 0]
# Flight Request 958: Departure slot changed from slot 106 to slot [72 164 1 0]
# Flight Request 959: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 960: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 961: Departure slot changed from slot 24 to slot [240 288 1 0]
# Flight Request 962: Departure slot changed from slot 156 to slot [111 123 0 1]
# Flight Request 963: Departure slot changed from slot 169 to slot [99 112 1 0]
# Flight Request 964: Departure slot changed from slot 34 to slot [285 9 1 0]
# Flight Request 965: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 966: Departure slot changed from slot 1 to slot [109 122 1 0]
# Flight Request 967: Departure slot changed from slot 279 to slot [171 271 1 0]
# Flight Request 968: Departure slot changed from slot 97 to slot [209 8 1 0]
# Flight Request 969: Departure slot changed from slot 176 to slot [212 37 1 0]
# Flight Request 970: Departure slot changed from slot 103 to slot [82 154 0 1]
# Flight Request 971: Departure slot changed from slot 217 to slot [49 275 0 1]
# Flight Request 972: Departure slot changed from slot 78 to slot [37 115 0 1]
# Flight Request 973: Departure slot changed from slot 39 to slot [83 115 0 1]
# Flight Request 974: Departure slot changed from slot 154 to slot [119 166 1 0]
# Flight Request 975: Departure slot changed from slot 103 to slot [82 154 0 1]
# Flight Request 976: Departure slot changed from slot 79 to slot [15 91 0 1]
# Flight Request 977: Departure slot changed from slot 280 to slot [99 115 0 1]
# Flight Request 978: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 979: Departure slot changed from slot 187 to slot [131 145 0 1]
# Flight Request 980: Departure slot changed from slot 143 to slot [28 40 1 0]
# Flight Request 981: Departure slot changed from slot 22 to slot [97 151 1 0]
# Flight Request 982: Departure slot changed from slot 210 to slot [121 170 1 0]
# Flight Request 983: Departure slot changed from slot 2 to slot [123 137 1 0]
# Flight Request 984: Departure slot changed from slot 25 to slot [98 135 0 1]
# Flight Request 985: Departure slot changed from slot 127 to slot [53 269 0 1]
# Flight Request 986: Departure slot changed from slot 202 to slot [148 182 0 1]
# Flight Request 987: Departure slot changed from slot 84 to slot [27 107 0 1]
# Flight Request 988: Departure slot changed from slot 228 to slot [20 57 0 1]
# Flight Request 989: Departure slot changed from slot 65 to slot [7 76 0 1]
# Flight Request 990: Departure slot changed from slot 179 to slot [146 14 0 1]
# Flight Request 991: Departure slot changed from slot 186 to slot [147 196 1 0]
# Flight Request 992: Departure slot changed from slot 220 to slot [58 107 0 1]
# Flight Request 993: Departure slot changed from slot 141 to slot [28 67 0 1]
# Flight Request 994: Departure slot changed from slot 168 to slot [56 110 0 1]
# Flight Request 995: Departure slot changed from slot 266 to slot [100 154 0 1]
# Flight Request 996: Departure slot changed from slot 100 to slot [48 89 1 0]
# Flight Request 997: Departure slot changed from slot 92 to slot [116 133 1 0]
# Flight Request 998: Departure slot changed from slot 148 to slot [30 38 1 0]
# Flight Request 999: Departure slot changed from slot 160 to slot [152 184 0 1]
# Flight Request 1000: Departure slot changed from slot 215 to slot [33 82 0 1]
# Flight Request 1001: Departure slot changed from slot 113 to slot [102 137 0 1]
# Flight Request 1002: Departure slot changed from slot 114 to slot [162 187 1 0]
# Flight Request 1003: Departure slot changed from slot 192 to slot [39 113 0 1]
# Flight Request 1004: Departure slot changed from slot 163 to slot [28 72 1 0]
# Flight Request 1005: Departure slot changed from slot 43 to slot [129 168 0 1]
# Flight Request 1006: Departure slot changed from slot 124 to slot [83 129 0 1]
# Flight Request 1007: Departure slot changed from slot 185 to slot [168 98 0 1]
# Flight Request 1008: Departure slot changed from slot 198 to slot [109 184 0 1]
# Flight Request 1009: Departure slot changed from slot 14 to slot [273 285 1 0]
# Flight Request 1010: Departure slot changed from slot 2 to slot [123 137 1 0]
# Flight Request 1011: Departure slot changed from slot 47 to slot [189 285 0 1]
# Flight Request 1012: Departure slot changed from slot 161 to slot [199 243 1 0]
# Flight Request 1013: Departure slot changed from slot 48 to slot [182 267 0 1]
# Flight Request 1014: Departure slot changed from slot 60 to slot [48 105 1 0]
# Flight Request 1015: Departure slot changed from slot 124 to slot [83 129 0 1]
# Flight Request 1016: Departure slot changed from slot 5 to slot [158 195 0 1]
# Flight Request 1017: Departure slot changed from slot 210 to slot [121 170 1 0]
# Flight Request 1018: Departure slot changed from slot 211 to slot [207 272 0 1]
# Flight Request 1019: Departure slot changed from slot 265 to slot [157 176 1 0]
# Flight Request 1020: Departure slot changed from slot 207 to slot [83 128 1 0]
# Flight Request 1021: Departure slot changed from slot 212 to slot [121 157 0 1]
# Flight Request 1022: Departure slot changed from slot 282 to slot [52 64 1 0]
# Flight Request 1023: Departure slot changed from slot 286 to slot [46 60 0 1]
# Flight Request 1024: Departure slot changed from slot 180 to slot [30 111 0 1]
# Flight Request 1025: Departure slot changed from slot 42 to slot [279 24 0 1]
# Flight Request 1026: Departure slot changed from slot 226 to slot [56 114 0 1]
# Flight Request 1027: Departure slot changed from slot 66 to slot [125 160 0 1]
# Flight Request 1028: Departure slot changed from slot 171 to slot [212 257 1 0]
# Flight Request 1029: Departure slot changed from slot 9 to slot [95 113 1 0]
# Flight Request 1030: Departure slot changed from slot 49 to slot [1 96 1 0]
# Flight Request 1031: Departure slot changed from slot 73 to slot [285 1 1 0]
# Flight Request 1032: Departure slot changed from slot 28 to slot [139 211 0 1]
# Flight Request 1033: Departure slot changed from slot 57 to slot [285 35 0 1]
# Flight Request 1034: Departure slot changed from slot 230 to slot [215 23 1 0]
# Flight Request 1035: Departure slot changed from slot 145 to slot [46 264 0 1]
# Flight Request 1036: Departure slot changed from slot 31 to slot [21 46 1 0]
# Flight Request 1037: Departure slot changed from slot 101 to slot [38 112 0 1]
# Flight Request 1038: Departure slot changed from slot 286 to slot [46 60 0 1]
# Flight Request 1039: Departure slot changed from slot 163 to slot [28 72 1 0]
# Flight Request 1040: Departure slot changed from slot 96 to slot [57 132 0 1]
# Flight Request 1041: Departure slot changed from slot 194 to slot [266 60 0 1]
# Flight Request 1042: Departure slot changed from slot 68 to slot [111 142 1 0]
# Status: Optimal
# 1037 flight requests out of 1043 were not shifted.
# Maximum Shift: 1
# Objective Value: 6.0

# %%
import matplotlib.pyplot as plt

original_slots = [req[0] for req in flight_requests if req[2] == 0]
original_slots.extend(req[1] for req in flight_requests if req[3] == 0)
print(len(original_slots))
# Count occurrences of each slot number
slot_counts = np.bincount(original_slots)

# Create x-axis values (timeslots)
timeslots = np.arange(len(slot_counts))

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.bar(timeslots, slot_counts, align='center', alpha=0.7)
plt.xticks(timeslots)
plt.xlabel('Timeslot')
plt.ylabel('Count')
plt.title('Count of each timeslot at Airport 0 before')
plt.grid(True)
plt.show()
# Out:
# 1043

# %%
new_slots = [entry[1] for entry in updated_slots if flight_requests[entry[0]][2] == 0]
new_slots.extend(entry[2] for entry in updated_slots if flight_requests[entry[0]][3] == 0)

# Count occurrences of each slot number
slot_counts = np.bincount(new_slots)

# Create x-axis values (timeslots)
timeslots = np.arange(len(slot_counts))

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.bar(timeslots, slot_counts, align='center', alpha=0.7)
plt.xticks(timeslots)
plt.xlabel('Timeslot')
plt.ylabel('Count')
plt.title('Count of each timeslot at Airport 0 after')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

original_slots = [req[0] for req in flight_requests if req[2] == 1]
original_slots.extend(req[1] for req in flight_requests if req[3] == 1)
print(len(original_slots))
# Count occurrences of each slot number
slot_counts = np.bincount(original_slots)

# Create x-axis values (timeslots)
timeslots = np.arange(len(slot_counts))

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.bar(timeslots, slot_counts, align='center', alpha=0.7)
plt.xticks(timeslots)
plt.xlabel('Timeslot')
plt.ylabel('Count')
plt.title('Count of each timeslot at Airport 1 before')
plt.grid(True)
plt.show()
# Out:
# 1043

# %%
new_slots = [entry[1] for entry in updated_slots if flight_requests[entry[0]][2] == 1]
new_slots.extend(entry[2] for entry in updated_slots if flight_requests[entry[0]][3] == 1)

# Count occurrences of each slot number
slot_counts = np.bincount(new_slots)

# Create x-axis values (timeslots)
timeslots = np.arange(len(slot_counts))

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.bar(timeslots, slot_counts, align='center', alpha=0.7)
plt.xticks(timeslots)
plt.xlabel('Timeslot')
plt.ylabel('Count')
plt.title('Count of each timeslot at Airport 1 after')
plt.grid(True)
plt.show()

# %%
# To use only for getting more days
interval_slot_dict = timeslot_to_index()
num_airports = 1
scenario_list = []

for date in dates:
    SIN_2019_s_d1 = get_day_df(movements_SIN, date)
    SIN_2019_s_d1 = SIN_2019_s_d1.reset_index()
    
    SIN_2019_s_d1['Slot'] = SIN_2019_s_d1.apply(lambda row: interval_slot_dict.get(row['Time slot']), axis=1)
    SIN_2019_s_d1['Slot'] = SIN_2019_s_d1['Slot'].round().astype('Int64')
    
    scenario = use_scenario(SIN_2019_s_d1, num_airports)
    scenario_list.append(scenario)

# %%
scenario_list
# Out:
# [(array([[0, 106, list([1.0])],
#          [1, 12, list([1.0])],
#          [2, 120, list([1.0])],
#          ...,
#          [922, 124, list([1.0])],
#          [923, 72, list([1.0])],
#          [924, 104, list([1.0])]], dtype=object),
#   925),
#  (array([[0, 137, list([1.0])],
#          [1, 138, list([1.0])],
#          [2, 196, list([1.0])],
#          ...,
#          [864, 176, list([1.0])],
#          [865, 213, list([1.0])],
#          [866, 24, list([1.0])]], dtype=object),
#   867),
#  (array([[0, 119, list([1.0])],
#          [1, 101, list([1.0])],
#          [2, 59, list([1.0])],
#          ...,
#          [836, 17, list([1.0])],
#          [837, 69, list([1.0])],
#          [838, 147, list([1.0])]], dtype=object),
#   839),
#  (array([[0, 87, list([1.0])],
#          [1, 117, list([1.0])],
#          [2, 137, list([1.0])],
#          ...,
#          [965, 35, list([1.0])],
#          [966, 100, list([1.0])],
#          [967, 175, list([1.0])]], dtype=object),
#   968),
#  (array([[0, 130, list([1.0])],
#          [1, 275, list([1.0])],
#          [2, 23, list([1.0])],
#          ...,
#          [1024, 40, list([1.0])],
#          [1025, 147, list([1.0])],
#          [1026, 126, list([1.0])]], dtype=object),
#   1027),
#  (array([[0, 287, list([1.0])],
#          [1, 1, list([1.0])],
#          [2, 176, list([1.0])],
#          ...,
#          [962, 114, list([1.0])],
#          [963, 12, list([1.0])],
#          [964, 31, list([1.0])]], dtype=object),
#   965),
#  (array([[0, 285, list([1.0])],
#          [1, 12, list([1.0])],
#          [2, 267, list([1.0])],
#          ...,
#          [1003, 222, list([1.0])],
#          [1004, 6, list([1.0])],
#          [1005, 87, list([1.0])]], dtype=object),
#   1006)]
