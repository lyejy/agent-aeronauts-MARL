# %%
# !pip install swig
# !pip install gymnasium\[box2d]
# Out:
# Collecting gymnasium[box2d]
#   Obtaining dependency information for gymnasium[box2d] from https://files.pythonhosted.org/packages/a8/4d/3cbfd81ed84db450dbe73a89afcd8bc405273918415649ac6683356afe92/gymnasium-0.29.1-py3-none-any.whl.metadata
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium[box2d]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium[box2d]) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.3 (from gymnasium[box2d])
#   Obtaining dependency information for pygame>=2.1.3 from https://files.pythonhosted.org/packages/b6/1d/64d0cf896f2c5032d1d35f101c21b4ec72ebcda9be3ba37c96ca702d2fcf/pygame-2.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached pygame-2.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: swig==4.* in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium[box2d]) (4.1.1)
# Using cached pygame-2.5.1-cp311-cp311-macosx_11_0_arm64.whl (12.2 MB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-macosx_11_0_arm64.whl size=394391 sha256=bacad746b09202a302efcf709c8a5b8294dfa91e0302e4361d5f7e96a649b2bb
#   Stored in directory: /Users/reginachua/Library/Caches/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame, gymnasium
# Successfully installed box2d-py-2.3.5 gymnasium-0.29.1 pygame-2.5.1

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Obtaining dependency information for stable_baselines3 from https://files.pythonhosted.org/packages/5e/81/7a0fbfc45240ec36cc3fcfe8f135996ef03277e2305d941a6d9186eb14e8/stable_baselines3-2.1.0-py3-none-any.whl.metadata
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (1.24.3)
# Requirement already satisfied: torch>=1.13 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (2.0.1)
# Requirement already satisfied: cloudpickle in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3) (3.9.0)
# Requirement already satisfied: sympy in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3) (1.11.1)
# Requirement already satisfied: networkx in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from pandas->stable_baselines3) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/reginachua/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: stable_baselines3
# Successfully installed stable_baselines3-2.1.0

# %%
# !pip install pyglet
# Out:
# Collecting pyglet
#   Obtaining dependency information for pyglet from https://files.pythonhosted.org/packages/94/a1/475458ccf34d2996abdb6ef29fa8d3fed2e62f72df5f2a7f4b4b076915c7/pyglet-2.0.9-py3-none-any.whl.metadata
#   Downloading pyglet-2.0.9-py3-none-any.whl.metadata (8.4 kB)
# Downloading pyglet-2.0.9-py3-none-any.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.7/854.7 kB 17.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyglet
# Successfully installed pyglet-2.0.9

# %%
# import statements
import gymnasium as gym
from stable_baselines3 import DQN

# %%
env = gym.make('LunarLander-v2')
env.reset()

model = DQN('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=15000, log_interval=4)

episodes = 5

for ep in range(episodes):
	obs = env.reset()
	done = False
	while not done:
		action, _states = model.predict(obs)
		obs, rewards, done, info = env.step(action)
		env.render()
		print(rewards)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -230     |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 17497    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 17699    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 721      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 16462    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 15582    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 14257    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 14741    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 15242    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 15720    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 15824    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 16109    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 16365    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4090     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 16730    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 16889    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 16907    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 16580    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 16542    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 16466    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 16574    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 16502    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 16563    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 16656    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 16716    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 16848    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 16956    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 17005    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 17094    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 16555    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 16685    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 16776    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 16782    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 16803    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 16863    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 16928    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 16936    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 16982    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 17016    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 17030    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 16991    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 16975    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14708    |
# ----------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#      11 done = False
#      12 while not done:
# ---> 13 	action, _states = model.predict(obs)
#      14 	obs, rewards, done, info = env.step(action)
#      15 	env.render()
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:255, in DQN.predict(self, observation, state, episode_start, deterministic)
#     253         action = np.array(self.action_space.sample())
#     254 else:
# --> 255     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     256 return action, state
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/policies.py:346, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     343 # Switch to eval mode (this affects batch norm / dropout)
#     344 self.set_training_mode(False)
# --> 346 observation, vectorized_env = self.obs_to_tensor(observation)
#     348 with th.no_grad():
#     349     actions = self._predict(observation, deterministic=deterministic)
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/policies.py:260, in BaseModel.obs_to_tensor(self, observation)
#     257     observation = maybe_transpose(observation, self.observation_space)
#     259 else:
# --> 260     observation = np.array(observation)
#     262 if not isinstance(observation, dict):
#     263     # Dict obs need to be handled separately
#     264     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
