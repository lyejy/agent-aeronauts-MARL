# %%
# Necessary imports
import gym
from gym import spaces
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import base64, io
import numpy as np
from collections import deque, namedtuple

# For visualization
from IPython.display import HTML
from IPython import display 
import glob

# %%
#Function for normal distribution truncation:

from scipy.stats import truncnorm

def get_truncated_normal(mean, sd, low, upp):
    return truncnorm((low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)

#Function to get observation (still for single env, need to modify for multi-agent env):

def full_obs(_cap_dem_chosen_req, number_of_actions):
    _obs_min_arr = np.full((288+number_of_actions-1, ), 0)
    for i in range(len(_cap_dem_chosen_req)):
        _obs_min_arr[i+int((number_of_actions-1)/2)] = min(_cap_dem_chosen_req[i])
    return _obs_min_arr

#Function to get the one-hot-encoded vectors for departure and arrival airports:

def one_hot_encode_airport(airport, num_airports):
    encoding = np.zeros(num_airports)
    encoding[airport] = 1
    return encoding

# Example usage
num_airports = 2
airport1 = 0
airport2 = 1

encoded_airport1 = one_hot_encode_airport(airport1, num_airports)
encoded_airport2 = one_hot_encode_airport(airport2, num_airports)

print(encoded_airport1)
print(encoded_airport2)

#Generate full info for the arrival sides:

def generate_info_arv(requests):
    ts_arv = np.empty(shape=(len(requests),), dtype='object')
    start_date_arv = np.empty(shape=(len(requests),), dtype='object')
    for i in range(len(requests)):
        ts_arv[i] = requests[i][1] + requests[i][5]/5
        if ts_arv[i] > 287:
            ts_arv[i] = ts_arv[i] - 287
            start_date_arv[i] = requests[i][2] + 1
        else:
            start_date_arv[i] = requests[i][2]
    return ts_arv, start_date_arv

#Generate the multi-agent scenario:

#=======================================================

#Modify the distribution based on historical data later:
def generate_scenario(number_of_requests, num_airports, cap_dict):
    
    #number_of_requests = 15000
    ts_72 = get_truncated_normal(mean=72, sd=12, low=0, upp=287).rvs(int(round(number_of_requests/2)))
    ts_72 = np.round(ts_72)

    ts_216 = get_truncated_normal(mean=216, sd=12, low=0, upp=287).rvs(int(round(number_of_requests/2)))
    ts_216 = np.round(ts_216)

    ts_dep = np.concatenate((ts_72, ts_216))
    ts_dep = ts_dep.astype(int)

    #Generate start date:

    start_date_dep = np.random.randint(low = 0, high=146, size=number_of_requests) #146 because period is 182 days and we consider series which span at least 5 weeks (+35 days)

    #Generate index for requests:

    index = np.array(list(range(number_of_requests)))

    #Generate origin (0 and 1 are two considered origin airports, 2 represent other airports, encoded in one-hot vector):

    #num_airports = 3
    origin_airport = np.empty(shape=(number_of_requests,), dtype='object')
    destination_airport = np.empty(shape=(number_of_requests,), dtype='object')
    for i in range(number_of_requests):
        _org_airport = one_hot_encode_airport(random.randint(0,1), num_airports)
        _org_airport_list = _org_airport.tolist()
        origin_airport[i] = _org_airport_list
        #Generate destination (the destination will be different with the origin):
        _dest_airport = _org_airport.copy()
        while np.array_equal(_dest_airport, _org_airport):
            np.random.shuffle(_dest_airport)
        _dest_airport_list = _dest_airport.tolist()
        destination_airport[i] = _dest_airport_list

    #Generate flying time (assume between airport 0 and 1 is 2 hour, 0 to 2 and 1 to 2 is arbitrary):

    fly_time = np.empty(shape=(number_of_requests,), dtype='object')
    for i in range (number_of_requests):
        if origin_airport[i] == list([1.0, 0.0]) and destination_airport[i] == list([0.0, 1.0]):
            fly_time[i] = 120
        elif origin_airport[i] == list([0.0, 1.0]) and destination_airport[i] == list([1.0, 0.0]):
            fly_time[i] = random.choice([60, 120, 180])

    #Generate status cap:

    status_cap_dep = np.full((number_of_requests,), 0)
    status_cap_arv = np.full((number_of_requests,), 0)
    

    requests = np.stack((index, ts_dep, start_date_dep, origin_airport, destination_airport, fly_time, status_cap_dep), axis=1)

    #Generate full info for the arv side:

    ts_arv, start_date_arv = generate_info_arv(requests)

    #pseudo_belong_dep = np.full((number_of_requests,), 0)
    #pseudo_belong_arv = np.full((number_of_requests,), 0)
    
    # Define requests_full as dtype object
    # requests_full = np.stack((index, ts_dep, start_date_dep, num_of_weeks, date_seq_dep, origin_airport, destination_airport, fly_time, status_cap_dep, ts_arv, start_date_arv, date_seq_arv, status_cap_arv), axis=1)
    num_entries = len(index)  # Given that 'index' is defined using np.array(list(range(number_of_requests)))
    # Create an empty array of the desired shape with dtype=object
    requests_full = np.empty((num_entries, 10), dtype=object)
    # Fill the array
    data = [index, ts_dep, start_date_dep, origin_airport, destination_airport, fly_time, status_cap_dep, ts_arv, start_date_arv, status_cap_arv]
    for i, column_data in enumerate(data):
        requests_full[:, i] = column_data

    # airport_req_dict: A dictionary where each key corresponds to a specific airport's requirements. 
    # The key format is 'req_i', where i is the index of the airport. 
    # The value for each key is a numpy array, with each row representing a request and the columns containing different attributes of that request.
    airport_req_dict, _belong_airport_dict = get_airport_req_dict(requests_full, num_airports)

    pot_dem_dict = get_initial_pot_dem_per_airport(airport_req_dict, num_airports)

    cap_dem_dict = get_cap_dem_dict(num_airports, cap_dict, pot_dem_dict)

    return requests_full, airport_req_dict, _belong_airport_dict, pot_dem_dict, cap_dem_dict

def get_violate_id_set(airport_req_dict, num_airports):
    violate_set = [] #(1: id, 2: airport, 3: dep, 4: arv)
    for i in range(num_airports):
        mask = ((airport_req_dict['req_{}'.format(i)][:, 6] + airport_req_dict['req_{}'.format(i)][:, 9]) >= 1)
        _id_violate_per_airport = airport_req_dict['req_{}'.format(i)][mask, :][:,0]
        violate_set.append(_id_violate_per_airport)
    violate_set = np.concatenate(violate_set, axis=0)
    violate_set = np.unique(violate_set)
    return violate_set

def get_violate_id_set_req_full(requests_full):
    mask = ((requests_full[:, 8] + requests_full[:, 12]) >= 1)
    violate_set_req_full = requests_full[mask, :][:,0]
    return violate_set_req_full

def get_req(violate_set, requests_full):
    _violate_index = random.choice(violate_set)
    chosen_req = requests_full[requests_full[:,0] == _violate_index]
    return chosen_req

def flatten_cap_dem_dict(cap_dem_dict, num_airports):
    cap_dem_dict_flat = {}
    for i in range(num_airports):
        cap_dem_dict_flat['req_{}'.format(i)] = cap_dem_dict['req_{}'.format(i)].flatten()
    return cap_dem_dict_flat

#Get separated req per airport and store in a dict:

def get_airport_req_dict(requests_full, num_airports):
    airport_req_dict = {}
    _belong_airport_dict = {}
    for i in range(num_airports):
        airport_req_dict['req_{}'.format(i)] = np.empty((0, 12)) #This one depends on the number of elements of a final request
        _belong_airport_dict['req_{}'.format(i)] = np.full(num_airports, 0.0, dtype=float)
        _belong_airport_dict['req_{}'.format(i)][i] = float(1.0)
        _belong_airport_dict['req_{}'.format(i)] = _belong_airport_dict['req_{}'.format(i)].tolist()
        
    for i in range(len(requests_full)):
        _found_dep = 0
        _found_arv = 0
        for k in range(num_airports):
            #_found_dep = 0
            #_found_arv = 0
            if requests_full[i][3] == _belong_airport_dict['req_{}'.format(k)]:
                _dep_req = np.append(requests_full[i], 1)
                _dep_req = np.append(_dep_req, 0)
                airport_req_dict['req_{}'.format(k)] = np.vstack((airport_req_dict['req_{}'.format(k)], _dep_req))
                _found_dep = 1
                #airport_req_dict['req_{}'.format(k)] = np.append(airport_req_dict['req_{}'.format(k)], 1)
                #airport_req_dict['req_{}'.format(k)] = np.append(airport_req_dict['req_{}'.format(k)], 0)
                #break
            if requests_full[i][4] == _belong_airport_dict['req_{}'.format(k)]:
                _arv_req = np.append(requests_full[i], 0)
                _arv_req = np.append(_arv_req, 1)
                airport_req_dict['req_{}'.format(k)] = np.vstack((airport_req_dict['req_{}'.format(k)], _arv_req))
                _found_arv = 1
                #airport_req_dict['req_{}'.format(k)] = np.append(airport_req_dict['req_{}'.format(k)], 0)
                #airport_req_dict['req_{}'.format(k)] = np.append(airport_req_dict['req_{}'.format(k)], 1)
                #break
            if _found_dep + _found_arv == 2:
                break
        if _found_dep + _found_arv != 2:
            print("Cannot found both dep and arv at req {}".format(i))
    
    return airport_req_dict, _belong_airport_dict

def generate_deterministic_capacity_dict(num_airports, cap_per_airport_arr): #This function is for 288 slots/ day
    cap_dict = {}
    for i in range(num_airports):
        cap_dict['req_{}'.format(i)] = np.full((288), cap_per_airport_arr[i])
    return cap_dict

def get_initial_pot_dem_per_airport(airport_req_dict, num_airports): #Replace req_df to req_df_update to update pot_dem_df #To be replaced with final_sched
    pot_dem_dict = {}
    #TODO: increase speed
    #10 dep 11 arv, 1 dep ts, 7 arv ts
    for i in range(num_airports):
        pot_dem_dict['req_{}'.format(i)] = np.full((288), 0)
        for k in range(len(airport_req_dict['req_{}'.format(i)])):
            _time_slot = int(airport_req_dict['req_{}'.format(i)][k][1]) * int(airport_req_dict['req_{}'.format(i)][k][10]) + int(airport_req_dict['req_{}'.format(i)][k][7]) * int(airport_req_dict['req_{}'.format(i)][k][11])
            pot_dem_dict['req_{}'.format(i)][_time_slot] += 1
    return pot_dem_dict

def get_cap_dem_dict(num_airports, cap_dict, pot_dem_dict):
    cap_dem_dict = {}
    for i in range(num_airports):
        cap_dem_dict['req_{}'.format(i)] = cap_dict['req_{}'.format(i)] - pot_dem_dict['req_{}'.format(i)]
    return cap_dem_dict

def update_status_capacity(airport_req_dict, num_airports, cap_dem_dict, requests_full):
    #Them cot cap_status o init:
    for i in range(num_airports):
        for k in range(len(airport_req_dict['req_{}'.format(i)])):
            _time_slot = int(airport_req_dict['req_{}'.format(i)][k][1]) * int(airport_req_dict['req_{}'.format(i)][k][10]) + int(airport_req_dict['req_{}'.format(i)][k][7]) * int(airport_req_dict['req_{}'.format(i)][k][11])
            # Ensure that cap_dem_dict['req_{}'.format(i)][_time_slot] is an iterable (e.g., a numpy array or a list)
            cap_dem_values = cap_dem_dict['req_{}'.format(i)][_time_slot]
            
            if isinstance(cap_dem_values, (np.ndarray, list)) and all(x >= 0 for x in cap_dem_values):
                airport_req_dict['req_{}'.format(i)][k][6] = 0
                airport_req_dict['req_{}'.format(i)][k][9] = 0
            else:
                if airport_req_dict['req_{}'.format(i)][k][10] == 1:
                    airport_req_dict['req_{}'.format(i)][k][6] = 1
                    _indices = np.where(requests_full[:, 0] == airport_req_dict['req_{}'.format(i)][k][0])
                    requests_full[_indices, 6] = 1
                else:
                    airport_req_dict['req_{}'.format(i)][k][9] = 1
                    _indices = np.where(requests_full[:, 0] == airport_req_dict['req_{}'.format(i)][k][0])
                    requests_full[_indices, 9] = 1
# Out:
# [1. 0.]
# [0. 1.]

# %%
# Define Neural Network for Q Network
class QNetwork(nn.Module):
    # Initilize parameters to build model
    def __init__(self, state_size, action_size, seed):
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)
    
    # Build a network that maps state to action values
    def forward(self, state):
        x = self.fc1(state)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        return self.fc3(x)

# %%
# Define the hyperparameters
BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 5e-2               # learning rate 
UPDATE_EVERY = 4        # how often to update the network

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Define the agent
class Agent():
    # Initialize the Agent object
    def __init__(self, state_size, action_size, seed):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)
        self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0
    
    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)
        
        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    # Function to return actions for the given state based on the current policy
    def act(self, state, eps=0.):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()

        # change this to just take random action and return the action after mapping
        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    # Function to return actions for test
    def pred(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        # self.qnetwork_local.eval()
        # with torch.no_grad():
        action_values = self.qnetwork_local(state)
        return np.argmax(action_values.cpu().data.numpy())

    # Update the value parameters based on the given batch of experience tuples
    def learn(self, experiences, gamma):

        # Obtain random minibatch of tuples from D
        states, actions, rewards, next_states, dones = experiences

        # Compute and minimize the loss
        # Extract next maximum estimated value from target network
        q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Calculate target value from bellman equation
        q_targets = rewards + gamma * q_targets_next * (1 - dones)
        # Calculate expected value from local network
        q_expected = self.qnetwork_local(states).gather(1, actions)
        
        # Calculate loss
        loss = F.mse_loss(q_expected, q_targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Update the target network
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %%
class TwoAirportSchedEnv(gym.Env):
    def __init__(self, number_of_actions, number_of_requests, num_airports, cap_per_airport_arr):
        super(TwoAirportSchedEnv, self).__init__()
        self.number_of_actions = int(number_of_actions)
        self.number_of_requests = number_of_requests
        self.num_airports = num_airports
        self.cap_per_airport_arr = cap_per_airport_arr
        self.cap_dict = generate_deterministic_capacity_dict(self.num_airports, self.cap_per_airport_arr)
        _exceed_cap = 0         
        while _exceed_cap == 0:
            self.requests_full, self.airport_req_dict, self._belong_airport_dict, self.pot_dem_dict, self.cap_dem_dict = generate_scenario(number_of_requests = self.number_of_requests, num_airports = self.num_airports, cap_dict = self.cap_dict)
            self.cap_dem_dict_flat = flatten_cap_dem_dict(self.cap_dem_dict, self.num_airports)
            for i in range(num_airports):
                _exceed_cap = _exceed_cap + (min(self.cap_dem_dict_flat['req_{}'.format(i)]))

        #to generate action:
        self.action_space = spaces.Discrete(self.number_of_actions)
        self.observation_space = spaces.Box(low= -np.inf, high= np.inf, shape=(7,), dtype=float)
        self.violate_set = self.get_violate_id_set(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
        self.num_step = 0
        
        #to choose the request that will be checked
        self.get_req(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
        
        self.original_requests = self.requests_full
    
    def action_mapping(self, action, number_of_actions):
        mid_point = (number_of_actions - 1) // 2
        return action - mid_point
    
    #added get request to know which is the request we are going to move at this step",
    #Randomly choose a violating request to solve
    def get_req(self, airport_req_dict, num_airports, cap_dem_dict, requests_full):

        if not self.violate_set:
          self.violate_set = self.get_violate_id_set(airport_req_dict, num_airports, cap_dem_dict, requests_full)
          if not self.violate_set:
            self.chosen_req = None 
            return self.chosen_req 

        airport_num, airport_index, request_violate_index = random.choice(self.violate_set)
        valid = self.check_status_capacity(airport_req_dict, cap_dem_dict, requests_full, airport_num, airport_index, request_violate_index)

        while not valid:

          if not self.violate_set:
            self.violate_set = self.get_violate_id_set(airport_req_dict, num_airports, cap_dem_dict, requests_full)
            if not self.violate_set:
              self.chosen_req = None 
              return self.chosen_req 

          airport_num, airport_index, request_violate_index = random.choice(self.violate_set)
          valid = self.check_status_capacity(airport_req_dict, cap_dem_dict, requests_full, airport_num, airport_index, request_violate_index)

        self.chosen_req = self.requests_full[self.requests_full[:,0] == request_violate_index][0]

        return self.chosen_req
    
    #need to check arrival time or change the variable to check_outbound(arv) and chec_outbound(dep)
    def check_outbound(self, action):
        dep_time_slot = self.chosen_req[1]
        arv_time_slot = self.chosen_req[7]

        outbound = False

        new_dep_time_slot = dep_time_slot + action
        new_arv_time_slot = arv_time_slot + action

        if (new_dep_time_slot < 0) or (new_dep_time_slot > 287) or (new_arv_time_slot < 0) or (new_arv_time_slot > 287):
            outbound = True

        return outbound
    
    def dep_or_arv(self):
        pass

    def update_dem(self, dep_airport, arv_airport, time_slot_dep, time_slot_arv, new_time_slot_dep, new_time_slot_arv):
        # Increment demand for the new time slot for both departure and arrival airports
        self.pot_dem_dict['req_{}'.format(dep_airport)][new_time_slot_dep] += 1
        self.pot_dem_dict['req_{}'.format(arv_airport)][new_time_slot_arv] += 1

        # Decrease demand for the initial time slot for both departure and arrival airports
        self.pot_dem_dict['req_{}'.format(dep_airport)][time_slot_dep] -= 1
        self.pot_dem_dict['req_{}'.format(arv_airport)][time_slot_arv] -= 1

    def update_cap_dem(self):
        for airport in range(self.num_airports):
            cap_key = 'req_{}'.format(airport)
            dem_key = 'req_{}'.format(airport)
            if cap_key not in self.cap_dict:
                raise KeyError(f"'{cap_key}' not found in cap_dict. Available keys: {list(self.cap_dict.keys())}")
            self.cap_dem_dict[cap_key] = self.cap_dict[cap_key] - self.pot_dem_dict[dem_key]

    def check_status_capacity(self, airport_req_dict, cap_dem_dict, requests_full, airport_num, airport_index, request_index):

        _time_slot = int(airport_req_dict['req_{}'.format(airport_num)][airport_index][1]) * int(airport_req_dict['req_{}'.format(airport_num)][airport_index][10]) + int(airport_req_dict['req_{}'.format(airport_num)][airport_index][7]) * int(airport_req_dict['req_{}'.format(airport_num)][airport_index][11])

        if (airport_num, airport_index, request_index) in self.violate_set:
            self.violate_set.remove((airport_num, airport_index, request_index))

        cap_dem_values = cap_dem_dict['req_{}'.format(airport_num)][_time_slot]
        if isinstance(cap_dem_values, (np.ndarray, list)) and all(x >= 0 for x in cap_dem_values):
            airport_req_dict['req_{}'.format(airport_num)][airport_index][6] = 0
            airport_req_dict['req_{}'.format(airport_num)][airport_index][9] = 0
            requests_full[request_index, 6] = 0
            requests_full[request_index, 9] = 0

            valid = False
        else:
            if airport_req_dict['req_{}'.format(airport_num)][airport_index][10] == 1:
                airport_req_dict['req_{}'.format(airport_num)][airport_index][6] = 1
                requests_full[request_index, 6] = 1
            else:
                airport_req_dict['req_{}'.format(airport_num)][airport_index][9] = 1
                requests_full[request_index, 9] = 1

            valid = True

        return valid

    def get_airport_index(self, airport_type):
        # Check for airport type
        if airport_type == "departure":
            airport_index = self.chosen_req[3].index(1.0)
        elif airport_type == "arrival":
            airport_index = self.chosen_req[4].index(1.0)
        else:
            raise ValueError(f"Invalid airport_type: {airport_type}. Expected 'departure' or 'arrival'.")

        return airport_index
    
    def update_status_capacity(self, airport_req_dict, num_airports, cap_dem_dict, requests_full):
    #Them cot cap_status o init:
        not_violate_update = set()
        violate_update = set()
        for i in range(num_airports):
            for k in range(len(airport_req_dict['req_{}'.format(i)])):
                _time_slot = int(airport_req_dict['req_{}'.format(i)][k][1]) * int(airport_req_dict['req_{}'.format(i)][k][10]) + int(airport_req_dict['req_{}'.format(i)][k][7]) * int(airport_req_dict['req_{}'.format(i)][k][11])
                cap_dem_values = cap_dem_dict['req_{}'.format(i)][_time_slot]

                # THis if statement line could be a problem, if the cap_dem_values is not an instance of np.ndarray or list, then it won't be accessed
                if isinstance(cap_dem_values, (np.ndarray, list)) and all(x >= 0 for x in cap_dem_values):
                # if all(x >= 0 for x in cap_dem_dict['req_{}'.format(i)][_time_slot]):
                    if airport_req_dict['req_{}'.format(i)][k][6] == 1 or airport_req_dict['req_{}'.format(i)][k][9] == 1:
                        not_violate_update.add(airport_req_dict['req_{}'.format(i)][k][0])
                    airport_req_dict['req_{}'.format(i)][k][6] = 0
                    airport_req_dict['req_{}'.format(i)][k][9] = 0
                else:
                    if airport_req_dict['req_{}'.format(i)][k][6] == 0 and airport_req_dict['req_{}'.format(i)][k][9] == 0:
                        violate_update.add(airport_req_dict['req_{}'.format(i)][k][0])
                    if airport_req_dict['req_{}'.format(i)][k][10] == 1:
                        airport_req_dict['req_{}'.format(i)][k][6] = 1
                        _indices = np.where(requests_full[:, 0] == airport_req_dict['req_{}'.format(i)][k][0])
                        requests_full[_indices, 6] = 1
                    else:
                        airport_req_dict['req_{}'.format(i)][k][9] = 1
                        _indices = np.where(requests_full[:, 0] == airport_req_dict['req_{}'.format(i)][k][0])
                        requests_full[_indices, 9] = 1

        return not_violate_update, violate_update

    def get_violate_id_set(self, airport_req_dict, num_airports, cap_dem_dict, requests_full):
        self.update_status_capacity(airport_req_dict, num_airports, cap_dem_dict, requests_full)
        violate_set = [] #(1: id, 2: airport, 3: dep, 4: arv)
        for i in range(num_airports):
            for k in range(len(airport_req_dict['req_{}'.format(i)])):
                if airport_req_dict['req_{}'.format(i)][k][6] + airport_req_dict['req_{}'.format(i)][k][9] >= 1:
                    violate_set.append((i, k, airport_req_dict['req_{}'.format(i)][k][0]))

        return violate_set
    
    def when_take_action(self, action):   
        _index = self.chosen_req[0]
        time_slot_dep = self.chosen_req[1]
        time_slot_arv = self.chosen_req[7]
        time_slot_arv = int(time_slot_arv)
        _dep_airport = self.chosen_req[3].index(1.0)
        _arv_airport = self.chosen_req[4].index(1.0)
        new_time_slot_dep = time_slot_dep + action
        new_time_slot_arv = time_slot_arv + action
        new_time_slot_arv = int(new_time_slot_arv)

        outbound = self.check_outbound(action)

        if not outbound:
            pass
            
        elif outbound:
            # new_time_slot_dep = random.randint(0, 287)
            # new_time_slot_arv = random.randint(0, 287)
            new_time_slot_dep = time_slot_dep
            new_time_slot_arv = time_slot_arv

        else:
            print('Problem with check outbound!')
            
        # Update the request for both departure and arrival time slots and dates
        self.requests_full[self.requests_full[:, 0] == _index][:, 1] = new_time_slot_dep
        self.requests_full[self.requests_full[:, 0] == _index][:, 7] = new_time_slot_arv

        # Update the airport request dict
        self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 1] = new_time_slot_dep
        self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 7] = new_time_slot_arv
        self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 1] = new_time_slot_dep
        self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 7] = new_time_slot_arv

        # Update demand for the new time slots
        self.update_dem(_dep_airport, _arv_airport, time_slot_dep, time_slot_arv, new_time_slot_dep, new_time_slot_arv)
        
        # Update cap_dem 
        self.update_cap_dem()

        # self.update_status_capacity(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
        if self.cap_dem_dict['req_{}'.format(_dep_airport)][new_time_slot_dep] >= 0:
            self.chosen_req[6] = 0
            self.requests_full[self.requests_full[:, 0] == _index][:, 6] = 0
            self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 6] = 0
            self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 6] = 0
        else:
            self.chosen_req[6] = 1
            self.requests_full[self.requests_full[:, 0] == _index][:, 6] = 1
            self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 6] = 1
            self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 6] = 1

        if self.cap_dem_dict['req_{}'.format(_arv_airport)][new_time_slot_arv] >= 0:
            self.chosen_req[9] = 0
            self.requests_full[self.requests_full[:, 0] == _index][:, 9] = 0
            self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 9] = 0
            self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 9] = 0
        else:
            self.chosen_req[9] = 1
            self.requests_full[self.requests_full[:, 0] == _index][:, 9] = 1
            self.airport_req_dict['req_{}'.format(_dep_airport)][self.airport_req_dict['req_{}'.format(_dep_airport)][:, 0] == _index][:, 9] = 1
            self.airport_req_dict['req_{}'.format(_arv_airport)][self.airport_req_dict['req_{}'.format(_arv_airport)][:, 0] == _index][:, 9] = 1

    def step(self, action): 
        num_actions = self.number_of_actions
        # # Convert the discrete action to your desired action value
        real_action = self.action_mapping(action, num_actions)
        
        # observation concats the following:
        # ts_dep + cap_dem_dep + ts_arv + cap_dem_arv
        self.when_take_action(real_action)
        outbound = self.check_outbound(real_action)

        # Count number of remaining unaccommodated requests
        _unaccom_req = len(self.requests_full[(self.requests_full[:, 6] == 1) | (self.requests_full[:, 9] == 1)])

        # Reward part:
        done = False
        self.num_step += 1
        
        if outbound:
            real_action = 0
            
        if real_action != 0:
            local_reward = 0.1*(-abs(real_action)*0.5)            
            
            if self.chosen_req[6] == 0 and self.chosen_req[9] == 0:
                reward_solved = 10

            else:
                reward_solved = 0

            if _unaccom_req == 0 and self.num_step != self.number_of_requests*5:
                done = True
                self.num_step = 0
                obs = np.zeros(578)
                global_reward = 30

            elif self.num_step == self.number_of_requests*5:
                done = True
                self.num_step = 0
                obs = np.zeros(578)
                global_reward = _unaccom_req * 0.01

            else:
                global_reward = 0
                obs = self._next_observation(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
            reward_time_step = -0.5
        

        else:
            reward_time_step = -0.5
            local_reward = 0
            global_reward = 0
            reward_solved = 0
            obs = self._next_observation(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)

        total_reward = float(local_reward + reward_solved + global_reward + reward_time_step)
    
        return obs, total_reward, done, {}
    
    def _next_observation(self, airport_req_dict, num_airports, cap_dem_dict, requests_full):
        self.get_req(airport_req_dict, num_airports, cap_dem_dict, requests_full)
        _ts_dep = self.chosen_req[1]
        _ts_arv = self.chosen_req[7]
        _dep_airport = self.chosen_req[3].index(1.0)
        _arv_airport = self.chosen_req[4].index(1.0)
        cap_dem_arr_dep = self.cap_dem_dict['req_{}'.format(_dep_airport)]
        cap_dem_arr_arv = self.cap_dem_dict['req_{}'.format(_arv_airport)]

        self.obs = np.append(_ts_dep, cap_dem_arr_dep)
        self.obs = np.append(self.obs, _ts_arv)
        self.obs = np.append(self.obs, cap_dem_arr_arv)
        
        return self.obs

    def reset(self):                
        self.requests_full, self.airport_req_dict, self._belong_airport_dict, self.pot_dem_dict, self.cap_dem_dict = generate_scenario(self.number_of_requests, self.num_airports, cap_dict = self.cap_dict)
        cap_dem_arr_airport1 = self.cap_dem_dict['req_{}'.format(0)]
        cap_dem_arr_airport2 = self.cap_dem_dict['req_{}'.format(1)]
        
        _cap_dem_flat_airport1 = cap_dem_arr_airport1.flatten()
        _cap_dem_flat_airport2 = cap_dem_arr_airport2.flatten()

        while (min(_cap_dem_flat_airport1) >= 0 or min(_cap_dem_flat_airport2) >= 0):
            generate_scenario(self.number_of_requests, self.num_airports, cap_dict = self.cap_dict)
            _cap_dem_flat_airport1 = cap_dem_arr_airport1.flatten()
            _cap_dem_flat_airport2 = cap_dem_arr_airport2.flatten()
        
        update_status_capacity(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
        print('Number of violation for airport1: ', len(_cap_dem_flat_airport1[_cap_dem_flat_airport1 < 0]))
        print('Number of violation for airport2: ', len(_cap_dem_flat_airport2[_cap_dem_flat_airport2 < 0]))

        self.num_step = 0        
        return self._next_observation(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
    
    # Need to validate
    def evaluate_metrics(self):
        _initial_cap_dem_dict = {}
        _initial_pot_dem_dict = get_initial_pot_dem_per_airport(self.airport_req_dict, self.num_airports)
        for airport in range(self.num_airports):
            cap_key = 'req_{}'.format(airport)
            dem_key = 'req_{}'.format(airport)
            _initial_cap_dem_dict[cap_key] = self.cap_dict[cap_key] - _initial_pot_dem_dict[dem_key]

        # Code to print initial number of violation requests for each airport agent
        _initial_cap_dem_airport1 = _initial_cap_dem_dict['req_{}'.format(0)]
        _initial_cap_dem_flat_airport1 = _initial_cap_dem_airport1.flatten()
        _initial_violate_airport1 = len(_initial_cap_dem_flat_airport1[_initial_cap_dem_flat_airport1 < 0])
        print('Initial count of unit violation for airport1 is: ', _initial_violate_airport1)
        _initial_cap_dem_airport2 = _initial_cap_dem_dict['req_{}'.format(1)]
        _initial_cap_dem_flat_airport2 = _initial_cap_dem_airport2.flatten()
        _initial_violate_airport2 = len(_initial_cap_dem_flat_airport2[_initial_cap_dem_flat_airport2 < 0])
        print('Initial count of unit violation for airport2 is: ', _initial_violate_airport2)

        # Code to print final number of violation requests for each airport agent
        cap_dem_arr_airport1 = self.cap_dem_dict['req_{}'.format(0)]
        cap_dem_arr_airport2 = self.cap_dem_dict['req_{}'.format(1)]
        _final_cap_dem_flat_airport1 = cap_dem_arr_airport1.flatten()
        _final_cap_dem_flat_airport2 = cap_dem_arr_airport2.flatten()
        _final_violate_airport1 = len(_final_cap_dem_flat_airport1[_final_cap_dem_flat_airport1 < 0])
        _final_violate_airport2 = len(_final_cap_dem_flat_airport2[_final_cap_dem_flat_airport2 < 0])
        print('Final count of unit violation for airport1 is: ', _final_violate_airport1)
        print('Final count of unit violation for airport2 is: ', _final_violate_airport2)

        # Code to print final schedule delay for each airport agent
        # What this does is it takes the absolute sum of the original time slot for request i - the updated time slot for request i
        # for each request 1
        # This is to see how much the time slots of each request has shifted 
        # Example: for request index 150, ori time slot = 10; updated time slot = 110
        # the delay for this request = |10 - 110| = 100
        _total_sched_delay_dep = sum(abs(self.original_requests[:,1] - self.requests_full[:,1]))
        _total_sched_delay_arv = sum(abs(self.original_requests[:,7] - self.requests_full[:,7]))       
        dep_airport_index = self.get_airport_index("departure")
        arv_airport_index = self.get_airport_index("arrival")
        if dep_airport_index == 0 and arv_airport_index == 1:
            print('Total schedule delay of airport1 is: ', _total_sched_delay_dep)
            print('Total schedule delay of airport2 is: ', _total_sched_delay_arv)
        elif dep_airport_index == 1 and arv_airport_index == 0:
            print('Total schedule delay of airport1 is: ', _total_sched_delay_arv)
            print('Total schedule delay of airport2 is: ', _total_sched_delay_dep)
        else:
            print("Error in airport retrieval for total_sched_delay")

        # Code to print max shift for each airport agent
        # Among all requests, find out what is the biggest abs value of original time slot - updated time slot
        _max_shift_dep = max(abs(self.original_requests[:,1] - self.requests_full[:,1]))
        _max_shift_arv = max(abs(self.original_requests[:,7] - self.requests_full[:,7]))
        if dep_airport_index == 0 and arv_airport_index == 1:
            print('Max shift of airport1: ', _max_shift_dep)
            print('Max shift of airport2: ', _max_shift_arv)
        elif dep_airport_index == 1 and arv_airport_index == 0:
            print('Max shift of airport1: ', _max_shift_arv)
            print('Max shift of airport2: ', _max_shift_dep)
        else:
            print("Error in airport retrieval for max_shift")

        # Code to print number of unaccommodated requests at the end of the episode
        # What this code does is it counts the number of requests that is not fully solved and still has 
        # _unaccom_req_dep = len(self.requests_full[self.requests_full[:,6] == 1])
        # print('Number of unaccommodate departure requests: ', _unaccom_req_dep)
        # _unaccom_req_arv = len(self.requests_full[self.requests_full[:,9] == 1])
        # print('Number of unaccommodate arrival requests: ', _unaccom_req_arv)
        _unaccom_req = len(self.requests_full[(self.requests_full[:, 6] == 1) | (self.requests_full[:, 9] == 1)])
        print('Number of unaccommodated requests: ', _unaccom_req)

        return _initial_violate_airport1, _initial_violate_airport2, _final_violate_airport1, _final_violate_airport2, _total_sched_delay_dep, _total_sched_delay_arv, _max_shift_dep, _max_shift_arv, _unaccom_req

# %%
# Define the Replay Buffer
class ReplayBuffer:
    # Initialize the Replay Buffer
    def __init__(self, action_size, buffer_size, batch_size, seed):
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    # Add a new experience
    def add(self, state, action, reward, next_state, done):
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    # Randomly sample a batch of experiences from memory
    def sample(self):
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
  
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        return len(self.memory)

# %%
# Initialize Two Airport Scheduler environment
num_actions = 3
env = TwoAirportSchedEnv(number_of_actions=num_actions, number_of_requests=1500, num_airports=2, cap_per_airport_arr= [6,6])
# env.seed(0)

# %%
import numpy
numpy.version.version
# Out:
# '1.26.1'

# %%
# Train the model
import time

def dqn(n_episodes=950, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    scores_central_agent = []                 # scores for central_agent
    episode_lengths_central_agent = []        # episode lengths for central_agent
    scores_window_central_agent = deque(maxlen=100)  # last 100 scores for central_agent
    _final_violate_airport1_list = []
    _final_violate_airport2_list = []
    _max_shift_dep_list = []
    _max_shift_arv_list = []
    epsilons = []  # List to store epsilon values for the final episode

    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score_central_agent = 0
        episode_length_central_agent = 0
        start_time = time.time()

        for t in range(max_t):
            central_action = central_agent.act(state, eps)
            next_state, reward, done, _ = env.step(central_action)

            central_agent.step(state, central_action, reward, next_state, done)
            score_central_agent += reward
            episode_length_central_agent += 1
            
            state = next_state
            
            if done:
                break

        epsilons.append(eps)
        scores_window_central_agent.append(score_central_agent)
        scores_central_agent.append(score_central_agent)
        episode_lengths_central_agent.append(episode_length_central_agent)

        _initial_violate_airport1, _initial_violate_airport2, _final_violate_airport1, _final_violate_airport2, _total_sched_delay_dep, _total_sched_delay_arv, _max_shift_dep, _max_shift_arv, _unaccom_req = env.evaluate_metrics()
        _final_violate_airport1_list.append(_final_violate_airport1)
        _final_violate_airport2_list.append(_final_violate_airport2)
        _max_shift_dep_list.append(_max_shift_dep)
        _max_shift_arv_list.append(_max_shift_arv)

        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        
        if i_episode % 10 == 0:
            print('\rEpisode {}\tAverage Score Airport1: {:.2f}\t'.format(i_episode, np.mean(scores_window_central_agent)))

        # Save model parameters every 100 episodes
        if i_episode % 100 == 0:
            torch.save(central_agent.qnetwork_local.state_dict(), 'checkpoint_central_agent.pth')
            
    # Save model parameters at the end of the final episode
    torch.save(central_agent.qnetwork_local.state_dict(), 'final_checkpoint_central_agent.pth')
    
    return scores_central_agent, episode_lengths_central_agent, _final_violate_airport1_list, _final_violate_airport2_list, _max_shift_dep_list, _max_shift_arv_list, epsilons

central_agent = Agent(state_size=578, action_size=num_actions, seed=0)

scores_central_agent, episode_lengths_central_agent, _final_violate_airport1_list, _final_violate_airport2_list, _max_shift_dep_list, _max_shift_arv_list, epsilons = dqn()
# Out:
# Number of violation for airport1:  99
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  96
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23425.0
# Total schedule delay of airport2 is:  20145
# Max shift of airport1:  69.0
# Max shift of airport2:  63
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  20227
# Total schedule delay of airport2 is:  20434.0
# Max shift of airport1:  71
# Max shift of airport2:  247.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  94
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23663.0
# Total schedule delay of airport2 is:  20763
# Max shift of airport1:  72.0
# Max shift of airport2:  51
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20297
# Total schedule delay of airport2 is:  23283.0
# Max shift of airport1:  53
# Max shift of airport2:  74.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23095.0
# Total schedule delay of airport2 is:  20317
# Max shift of airport1:  72.0
# Max shift of airport2:  60
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  91
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  91
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23531.0
# Total schedule delay of airport2 is:  20038
# Max shift of airport1:  256.0
# Max shift of airport2:  55
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  95
# Number of violation for airport2:  96
# Initial count of unit violation for airport1 is:  95
# Initial count of unit violation for airport2 is:  96
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  19823
# Total schedule delay of airport2 is:  22569.0
# Max shift of airport1:  52
# Max shift of airport2:  61.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23006.0
# Total schedule delay of airport2 is:  19850
# Max shift of airport1:  78.0
# Max shift of airport2:  66
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  107
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20121
# Total schedule delay of airport2 is:  23229.0
# Max shift of airport1:  55
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20406
# Total schedule delay of airport2 is:  23330.0
# Max shift of airport1:  54
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Episode 10	Average Score Airport1: -532.39
# Number of violation for airport1:  98
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  22877.0
# Total schedule delay of airport2 is:  19530
# Max shift of airport1:  228.0
# Max shift of airport2:  57
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23049.0
# Total schedule delay of airport2 is:  19777
# Max shift of airport1:  63.0
# Max shift of airport2:  62
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19968
# Total schedule delay of airport2 is:  23354.0
# Max shift of airport1:  55
# Max shift of airport2:  59.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  23502.0
# Total schedule delay of airport2 is:  19849
# Max shift of airport1:  237.0
# Max shift of airport2:  67
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  106
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  23508.0
# Total schedule delay of airport2 is:  20316
# Max shift of airport1:  68.0
# Max shift of airport2:  65
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  106
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  106
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  19980
# Total schedule delay of airport2 is:  23108.0
# Max shift of airport1:  63
# Max shift of airport2:  63.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  95
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  23411.0
# Total schedule delay of airport2 is:  20577
# Max shift of airport1:  68.0
# Max shift of airport2:  58
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  19914
# Total schedule delay of airport2 is:  22928.0
# Max shift of airport1:  52
# Max shift of airport2:  61.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  20321
# Total schedule delay of airport2 is:  23142.0
# Max shift of airport1:  53
# Max shift of airport2:  226.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23328.0
# Total schedule delay of airport2 is:  20167
# Max shift of airport1:  242.0
# Max shift of airport2:  55
# Number of unaccommodated requests:  1500
# Episode 20	Average Score Airport1: -531.76
# Number of violation for airport1:  101
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20135
# Total schedule delay of airport2 is:  23221.0
# Max shift of airport1:  67
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  96
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  96
# Final count of unit violation for airport1 is:  95
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20527
# Total schedule delay of airport2 is:  23857.0
# Max shift of airport1:  61
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  96
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  96
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  20377
# Total schedule delay of airport2 is:  23495.0
# Max shift of airport1:  70
# Max shift of airport2:  70.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20173
# Total schedule delay of airport2 is:  23419.0
# Max shift of airport1:  54
# Max shift of airport2:  66.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  96
# Number of violation for airport2:  107
# Initial count of unit violation for airport1 is:  96
# Initial count of unit violation for airport2 is:  107
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  19700
# Total schedule delay of airport2 is:  22586.0
# Max shift of airport1:  57
# Max shift of airport2:  69.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20281
# Total schedule delay of airport2 is:  23091.0
# Max shift of airport1:  55
# Max shift of airport2:  61.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20380
# Total schedule delay of airport2 is:  24006.0
# Max shift of airport1:  53
# Max shift of airport2:  246.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  107
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  107
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20050
# Total schedule delay of airport2 is:  23338.0
# Max shift of airport1:  57
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  95
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20330
# Total schedule delay of airport2 is:  23680.0
# Max shift of airport1:  62
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23346.0
# Total schedule delay of airport2 is:  20043
# Max shift of airport1:  214.0
# Max shift of airport2:  57
# Number of unaccommodated requests:  1500
# Episode 30	Average Score Airport1: -531.03
# Number of violation for airport1:  93
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  93
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  94
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  20542
# Total schedule delay of airport2 is:  23935.0
# Max shift of airport1:  69
# Max shift of airport2:  254.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20400
# Total schedule delay of airport2 is:  23370.0
# Max shift of airport1:  59
# Max shift of airport2:  64.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  20250
# Total schedule delay of airport2 is:  23088.0
# Max shift of airport1:  60
# Max shift of airport2:  63.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19903
# Total schedule delay of airport2 is:  22753.0
# Max shift of airport1:  59
# Max shift of airport2:  61.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23031.0
# Total schedule delay of airport2 is:  19899
# Max shift of airport1:  82.0
# Max shift of airport2:  62
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  96
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  96
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19899
# Total schedule delay of airport2 is:  22711.0
# Max shift of airport1:  54
# Max shift of airport2:  59.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20249
# Total schedule delay of airport2 is:  23184.0
# Max shift of airport1:  57
# Max shift of airport2:  254.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  107
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  22428.0
# Total schedule delay of airport2 is:  19894
# Max shift of airport1:  65.0
# Max shift of airport2:  60
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  95
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  19708
# Total schedule delay of airport2 is:  22879.0
# Max shift of airport1:  61
# Max shift of airport2:  224.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  19819
# Total schedule delay of airport2 is:  22905.0
# Max shift of airport1:  62
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Episode 40	Average Score Airport1: -530.37
# Number of violation for airport1:  103
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20507
# Total schedule delay of airport2 is:  23319.0
# Max shift of airport1:  56
# Max shift of airport2:  63.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  23537.0
# Total schedule delay of airport2 is:  20424
# Max shift of airport1:  228.0
# Max shift of airport2:  57
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  96
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  20557
# Total schedule delay of airport2 is:  23257.0
# Max shift of airport1:  61
# Max shift of airport2:  63.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  105
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  105
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23225.0
# Total schedule delay of airport2 is:  20503
# Max shift of airport1:  66.0
# Max shift of airport2:  58
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  22552.0
# Total schedule delay of airport2 is:  19646
# Max shift of airport1:  68.0
# Max shift of airport2:  60
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  20015
# Total schedule delay of airport2 is:  23421.0
# Max shift of airport1:  55
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23439.0
# Total schedule delay of airport2 is:  20301
# Max shift of airport1:  70.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23330.0
# Total schedule delay of airport2 is:  20234
# Max shift of airport1:  67.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  95
# Total schedule delay of airport1 is:  19980
# Total schedule delay of airport2 is:  23344.0
# Max shift of airport1:  63
# Max shift of airport2:  66.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23209.0
# Total schedule delay of airport2 is:  20211
# Max shift of airport1:  64.0
# Max shift of airport2:  54
# Number of unaccommodated requests:  1500
# Episode 50	Average Score Airport1: -529.78
# Number of violation for airport1:  101
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19980
# Total schedule delay of airport2 is:  23437.0
# Max shift of airport1:  60
# Max shift of airport2:  254.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  22544.0
# Total schedule delay of airport2 is:  19428
# Max shift of airport1:  72.0
# Max shift of airport2:  56
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  20085
# Total schedule delay of airport2 is:  23483.0
# Max shift of airport1:  54
# Max shift of airport2:  70.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20531
# Total schedule delay of airport2 is:  23949.0
# Max shift of airport1:  53
# Max shift of airport2:  253.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  19762
# Total schedule delay of airport2 is:  22596.0
# Max shift of airport1:  60
# Max shift of airport2:  68.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  106
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  106
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23560.0
# Total schedule delay of airport2 is:  20534
# Max shift of airport1:  60.0
# Max shift of airport2:  49
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  106
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  106
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23126.0
# Total schedule delay of airport2 is:  20088
# Max shift of airport1:  62.0
# Max shift of airport2:  58
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19464
# Total schedule delay of airport2 is:  22384.0
# Max shift of airport1:  57
# Max shift of airport2:  77.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  23904.0
# Total schedule delay of airport2 is:  20294
# Max shift of airport1:  64.0
# Max shift of airport2:  52
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  107
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  107
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  19698
# Total schedule delay of airport2 is:  22924.0
# Max shift of airport1:  57
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Episode 60	Average Score Airport1: -529.27
# Number of violation for airport1:  98
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23182.0
# Total schedule delay of airport2 is:  20028
# Max shift of airport1:  66.0
# Max shift of airport2:  58
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20237
# Total schedule delay of airport2 is:  23753.0
# Max shift of airport1:  57
# Max shift of airport2:  60.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  20045
# Total schedule delay of airport2 is:  23035.0
# Max shift of airport1:  50
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  93
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23831.0
# Total schedule delay of airport2 is:  20585
# Max shift of airport1:  73.0
# Max shift of airport2:  73
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  24029.0
# Total schedule delay of airport2 is:  20640
# Max shift of airport1:  263.0
# Max shift of airport2:  61
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20744
# Total schedule delay of airport2 is:  24100.0
# Max shift of airport1:  54
# Max shift of airport2:  70.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  23063.0
# Total schedule delay of airport2 is:  19839
# Max shift of airport1:  68.0
# Max shift of airport2:  57
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  96
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  96
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23904.0
# Total schedule delay of airport2 is:  20400
# Max shift of airport1:  72.0
# Max shift of airport2:  70
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  95
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  95
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  94
# Total schedule delay of airport1 is:  20429
# Total schedule delay of airport2 is:  23551.0
# Max shift of airport1:  54
# Max shift of airport2:  58.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20827
# Total schedule delay of airport2 is:  23495.0
# Max shift of airport1:  61
# Max shift of airport2:  73.0
# Number of unaccommodated requests:  1500
# Episode 70	Average Score Airport1: -528.67
# Number of violation for airport1:  94
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  94
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  20243
# Total schedule delay of airport2 is:  23505.0
# Max shift of airport1:  52
# Max shift of airport2:  66.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20424
# Total schedule delay of airport2 is:  23002.0
# Max shift of airport1:  65
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  109
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  20162
# Total schedule delay of airport2 is:  23307.0
# Max shift of airport1:  59
# Max shift of airport2:  244.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23143.0
# Total schedule delay of airport2 is:  19787
# Max shift of airport1:  60.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20560
# Total schedule delay of airport2 is:  23232.0
# Max shift of airport1:  60
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  98
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  98
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  93
# Total schedule delay of airport1 is:  19714
# Total schedule delay of airport2 is:  22598.0
# Max shift of airport1:  57
# Max shift of airport2:  79.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  20224
# Total schedule delay of airport2 is:  23104.0
# Max shift of airport1:  58
# Max shift of airport2:  71.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  107
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20338
# Total schedule delay of airport2 is:  23376.0
# Max shift of airport1:  56
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  107
# Final count of unit violation for airport2 is:  105
# Total schedule delay of airport1 is:  23244.0
# Total schedule delay of airport2 is:  20182
# Max shift of airport1:  65.0
# Max shift of airport2:  56
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  106
# Total schedule delay of airport1 is:  20135
# Total schedule delay of airport2 is:  23139.0
# Max shift of airport1:  61
# Max shift of airport2:  64.0
# Number of unaccommodated requests:  1500
# Episode 80	Average Score Airport1: -528.21
# Number of violation for airport1:  98
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  22983.0
# Total schedule delay of airport2 is:  19668
# Max shift of airport1:  230.0
# Max shift of airport2:  68
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  107
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  107
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  106
# Total schedule delay of airport1 is:  20270
# Total schedule delay of airport2 is:  23382.0
# Max shift of airport1:  66
# Max shift of airport2:  66.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  23120.0
# Total schedule delay of airport2 is:  19872
# Max shift of airport1:  71.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  23975.0
# Total schedule delay of airport2 is:  20917
# Max shift of airport1:  67.0
# Max shift of airport2:  52
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23866.0
# Total schedule delay of airport2 is:  20676
# Max shift of airport1:  67.0
# Max shift of airport2:  55
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  19753
# Total schedule delay of airport2 is:  22699.0
# Max shift of airport1:  58
# Max shift of airport2:  64.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  96
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  96
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  19917
# Total schedule delay of airport2 is:  23003.0
# Max shift of airport1:  63
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  95
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  95
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  23211.0
# Total schedule delay of airport2 is:  19827
# Max shift of airport1:  241.0
# Max shift of airport2:  50
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20241
# Total schedule delay of airport2 is:  23555.0
# Max shift of airport1:  63
# Max shift of airport2:  75.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20594
# Total schedule delay of airport2 is:  23266.0
# Max shift of airport1:  62
# Max shift of airport2:  74.0
# Number of unaccommodated requests:  1500
# Episode 90	Average Score Airport1: -527.68
# Number of violation for airport1:  104
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23658.0
# Total schedule delay of airport2 is:  20268
# Max shift of airport1:  73.0
# Max shift of airport2:  55
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  20746
# Total schedule delay of airport2 is:  23672.0
# Max shift of airport1:  66
# Max shift of airport2:  72.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  96
# Final count of unit violation for airport2 is:  105
# Total schedule delay of airport1 is:  20119
# Total schedule delay of airport2 is:  22755.0
# Max shift of airport1:  62
# Max shift of airport2:  71.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  106
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  106
# Final count of unit violation for airport1 is:  108
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  20394
# Total schedule delay of airport2 is:  23336.0
# Max shift of airport1:  66
# Max shift of airport2:  68.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23535.0
# Total schedule delay of airport2 is:  20191
# Max shift of airport1:  59.0
# Max shift of airport2:  54
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  107
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  107
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  106
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  22875.0
# Total schedule delay of airport2 is:  20111
# Max shift of airport1:  58.0
# Max shift of airport2:  61
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20177
# Total schedule delay of airport2 is:  23097.0
# Max shift of airport1:  62
# Max shift of airport2:  73.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20274
# Total schedule delay of airport2 is:  24019.0
# Max shift of airport1:  58
# Max shift of airport2:  236.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  106
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  106
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20274
# Total schedule delay of airport2 is:  23450.0
# Max shift of airport1:  53
# Max shift of airport2:  63.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  97
# Total schedule delay of airport1 is:  20290
# Total schedule delay of airport2 is:  23724.0
# Max shift of airport1:  56
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Episode 100	Average Score Airport1: -527.13
# Number of violation for airport1:  101
# ...
# Max shift of airport1:  56
# Max shift of airport2:  254.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  97
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  97
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  108
# Total schedule delay of airport1 is:  23538.0
# Total schedule delay of airport2 is:  20114
# Max shift of airport1:  67.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  96
# Number of violation for airport2:  111
# Initial count of unit violation for airport1 is:  96
# Initial count of unit violation for airport2 is:  111
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  109
# Total schedule delay of airport1 is:  23375.0
# Total schedule delay of airport2 is:  20005
# Max shift of airport1:  66.0
# Max shift of airport2:  53
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  22917.0
# Total schedule delay of airport2 is:  19671
# Max shift of airport1:  66.0
# Max shift of airport2:  59
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  22906.0
# Total schedule delay of airport2 is:  20072
# Max shift of airport1:  63.0
# Max shift of airport2:  63
# Number of unaccommodated requests:  1500
# Episode 150	Average Score Airport1: -522.06
# Number of violation for airport1:  103
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20706
# Total schedule delay of airport2 is:  24220.0
# Max shift of airport1:  60
# Max shift of airport2:  72.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23041.0
# Total schedule delay of airport2 is:  20079
# Max shift of airport1:  75.0
# Max shift of airport2:  63
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  105
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  105
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20388
# Total schedule delay of airport2 is:  23847.0
# Max shift of airport1:  56
# Max shift of airport2:  265.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  24030.0
# Total schedule delay of airport2 is:  20622
# Max shift of airport1:  67.0
# Max shift of airport2:  61
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  20489
# Total schedule delay of airport2 is:  23681.0
# Max shift of airport1:  58
# Max shift of airport2:  67.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  102
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  22947.0
# Total schedule delay of airport2 is:  19661
# Max shift of airport1:  74.0
# Max shift of airport2:  53
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  94
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  94
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  22801.0
# Total schedule delay of airport2 is:  19783
# Max shift of airport1:  68.0
# Max shift of airport2:  62
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  94
# Total schedule delay of airport1 is:  20262
# Total schedule delay of airport2 is:  23221.0
# Max shift of airport1:  61
# Max shift of airport2:  226.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  96
# Total schedule delay of airport1 is:  24279.0
# Total schedule delay of airport2 is:  20985
# Max shift of airport1:  68.0
# Max shift of airport2:  68
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  20554
# Total schedule delay of airport2 is:  24026.0
# Max shift of airport1:  62
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Episode 160	Average Score Airport1: -521.06
# Number of violation for airport1:  100
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  96
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  20666
# Total schedule delay of airport2 is:  23084.0
# Max shift of airport1:  55
# Max shift of airport2:  71.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  98
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  98
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  103
# Total schedule delay of airport1 is:  20072
# Total schedule delay of airport2 is:  22686.0
# Max shift of airport1:  58
# Max shift of airport2:  68.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20377
# Total schedule delay of airport2 is:  23938.0
# Max shift of airport1:  57
# Max shift of airport2:  250.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  101
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  101
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  105
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23023.0
# Total schedule delay of airport2 is:  20557
# Max shift of airport1:  67.0
# Max shift of airport2:  60
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  100
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  20472
# Total schedule delay of airport2 is:  23624.0
# Max shift of airport1:  63
# Max shift of airport2:  65.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  99
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  99
# Final count of unit violation for airport1 is:  109
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20144
# Total schedule delay of airport2 is:  23375.0
# Max shift of airport1:  55
# Max shift of airport2:  225.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  108
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  24036.0
# Total schedule delay of airport2 is:  20979
# Max shift of airport1:  248.0
# Max shift of airport2:  62
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  104
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  104
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  103
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  23859.0
# Total schedule delay of airport2 is:  20326
# Max shift of airport1:  236.0
# Max shift of airport2:  70
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  96
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  96
# Final count of unit violation for airport1 is:  100
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  20110
# Total schedule delay of airport2 is:  23306.0
# Max shift of airport1:  56
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  102
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  102
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  106
# Total schedule delay of airport1 is:  22413.0
# Total schedule delay of airport2 is:  20077
# Max shift of airport1:  63.0
# Max shift of airport2:  63
# Number of unaccommodated requests:  1500
# Episode 170	Average Score Airport1: -520.22
# Number of violation for airport1:  100
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  100
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  102
# Total schedule delay of airport1 is:  20044
# Total schedule delay of airport2 is:  23572.0
# Max shift of airport1:  54
# Max shift of airport2:  62.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  103
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  103
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  95
# Total schedule delay of airport1 is:  23421.0
# Total schedule delay of airport2 is:  19825
# Max shift of airport1:  70.0
# Max shift of airport2:  58
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  106
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  106
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  104
# Final count of unit violation for airport2 is:  99
# Total schedule delay of airport1 is:  23707.0
# Total schedule delay of airport2 is:  20621
# Max shift of airport1:  64.0
# Max shift of airport2:  54
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  104
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  104
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  19944
# Total schedule delay of airport2 is:  22888.0
# Max shift of airport1:  60
# Max shift of airport2:  66.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  99
# Number of violation for airport2:  101
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  101
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  101
# Total schedule delay of airport1 is:  22888.0
# Total schedule delay of airport2 is:  20034
# Max shift of airport1:  68.0
# Max shift of airport2:  57
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  98
# Total schedule delay of airport1 is:  23512.0
# Total schedule delay of airport2 is:  20190
# Max shift of airport1:  63.0
# Max shift of airport2:  63
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  103
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  103
# Final count of unit violation for airport1 is:  97
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  20040
# Total schedule delay of airport2 is:  23497.0
# Max shift of airport1:  49
# Max shift of airport2:  218.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  100
# Initial count of unit violation for airport1 is:  102
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  101
# Final count of unit violation for airport2 is:  104
# Total schedule delay of airport1 is:  19866
# Total schedule delay of airport2 is:  22972.0
# Max shift of airport1:  61
# Max shift of airport2:  61.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  95
# Number of violation for airport2:  97
# Initial count of unit violation for airport1 is:  95
# Initial count of unit violation for airport2 is:  97
# Final count of unit violation for airport1 is:  98
# Final count of unit violation for airport2 is:  95
# Total schedule delay of airport1 is:  20183
# Total schedule delay of airport2 is:  22737.0
# Max shift of airport1:  81
# Max shift of airport2:  93.0
# Number of unaccommodated requests:  1500
# Number of violation for airport1:  102
# Number of violation for airport2:  101

# %%
plt.figure(figsize=(10, 6))
plt.plot(scores_central_agent, label='Central Agent')
plt.title("Central Agent Against Reward Score")
plt.xlabel("Episode #")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot epsilon values for the final episode
plt.figure(figsize=(10, 6))
plt.plot(epsilons, label='Epsilon')
plt.title("Epsilon Decay Across Episodes")
plt.xlabel("Episode #")
plt.ylabel("Epsilon")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot episode lengths for both agents
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot episode lengths for Agent1
plt.plot(range(1, len(episode_lengths_agent1) + 1), episode_lengths_agent1, marker='o', linestyle='-', color='blue', label='Agent1')

# Plot episode lengths for Agent2
plt.plot(range(1, len(episode_lengths_agent2) + 1), episode_lengths_agent2, marker='o', linestyle='-', color='red', label='Agent2')

plt.xlabel('Episode Number')
plt.ylabel('Episode Length (Timesteps)')
plt.title('Episode Length vs. Episode Number')

plt.legend()
plt.grid(True)
plt.show()

# %%
import gym

env = TwoAirportSchedEnv(number_of_actions=num_actions, number_of_requests=1500, num_airports=2, cap_per_airport_arr= [6,6])

central_agent = Agent(state_size=578, action_size=num_actions, seed=0)

# Load the saved weights into the models
central_agent.qnetwork_local.load_state_dict(torch.load('checkpoint_central_agent.pth'))

def evaluate_agent(n_episodes=200):
    _final_violate_airport1_list = []
    _final_violate_airport2_list = []
        
    for _ in range(n_episodes):
        state = env.reset()
        counter = 0
        
        while True:
            # Using greedy policy (no exploration)
            central_action = central_agent.pred(state) 
            next_state, reward, done, _ = env.step(central_action)

            print('Central action: ', central_action)
    
            if done or counter == 1000:
                env.evaluate_metrics()
                print("\n---------------------------------------------------------\n")
                state = env.reset()
                break
                
            counter += 1
            
evaluate_agent()
# Out:
# Number of violation for airport1:  99
# Number of violation for airport2:  100
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Initial count of unit violation for airport1 is:  99
# Initial count of unit violation for airport2 is:  100
# Final count of unit violation for airport1 is:  99
# Final count of unit violation for airport2 is:  100
# Total schedule delay of airport1 is:  23373.0
# Total schedule delay of airport2 is:  19949
# Max shift of airport1:  65.0
# Max shift of airport2:  54
# Number of unaccommodated requests:  1500
#
# ---------------------------------------------------------
#
# Number of violation for airport1:  98
# Number of violation for airport2:  97
# Number of violation for airport1:  101
# Number of violation for airport2:  100
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# Central action:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 33
#      29                 break
#      31             counter += 1
# ---> 33 evaluate_agent()
#
# Cell In[12], line 21, in evaluate_agent(n_episodes)
#      18 while True:
#      19     # Using greedy policy (no exploration)
#      20     central_action = central_agent.pred(state)
# ---> 21     next_state, reward, done, _ = env.step(central_action)
#      23     print('Central action: ', central_action)
#      25     if done or counter == 1000:
#
# Cell In[7], line 222, in TwoAirportSchedEnv.step(self, action)
#     218 real_action = self.action_mapping(action, num_actions)
#     220 # observation concats the following:
#     221 # ts_dep + cap_dem_dep + ts_arv + cap_dem_arv
# --> 222 self.when_take_action(real_action)
#     223 outbound = self.check_outbound(real_action)
#     225 # Count number of remaining unaccommodated requests
#
# Cell In[7], line 213, in TwoAirportSchedEnv.when_take_action(self, action)
#     210 # Update cap_dem
#     211 self.update_cap_dem()
# --> 213 self.update_status_capacity(self.airport_req_dict, self.num_airports, self.cap_dem_dict, self.requests_full)
#
# Cell In[7], line 154, in TwoAirportSchedEnv.update_status_capacity(self, airport_req_dict, num_airports, cap_dem_dict, requests_full)
#     152 if airport_req_dict['req_{}'.format(i)][k][10] == 1:
#     153     airport_req_dict['req_{}'.format(i)][k][6] = 1
# --> 154     _indices = np.where(requests_full[:, 0] == airport_req_dict['req_{}'.format(i)][k][0])
#     155     requests_full[_indices, 6] = 1
#     156 else:
#
# File ~/jupyterlab-venv-tf-py311/lib/python3.11/site-packages/numpy/core/multiarray.py:346, in where(condition, x, y)
#     256     """
#     257     inner(a, b, /)
#     258
#    (...)
#     341
#     342     """
#     343     return (a, b)
# --> 346 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     347 def where(condition, x=None, y=None):
#     348     """
#     349     where(condition, [x, y], /)
#     350
#    (...)
#     416            [ 0,  3, -1]])
#     417     """
#     418     return (condition, x, y)
#
# KeyboardInterrupt:
