# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder = "./ASEAN_2019D"
movements_2019_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jan_Mar_JobId2082476.csv", sep = ",", header = 0)
movements_2019_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Apr_Jun_JobId2081531.csv", sep = ",", header = 0)
movements_2019_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jul_Sep_JobId2081532.csv", sep = ",", header = 0)
movements_2019_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Oct_Dec_JobId2082477.csv", sep = ",", header = 0)
movements_2019 = pd.concat([movements_2019_1, movements_2019_2, movements_2019_3, movements_2019_4])

# %%
movements_2019
# Out:
#        Dep Airport Code                        Dep Airport Name  \
# 0                   CEB                                    Cebu
# 1                   MNL   Manila Ninoy Aquino International Apt
# 2                   TMC                               Tambolaka
# 3                   SIN                    Singapore Changi Apt
# 4                   LUW                                   Luwuk
# ...                 ...                                     ...
# 920482              BKK  Bangkok Suvarnabhumi International Apt
# 920483              MNL   Manila Ninoy Aquino International Apt
# 920484              CEB                                    Cebu
# 920485              RGN                                  Yangon
# 920486              KCH                                 Kuching
#
#        Arr Airport Code                     Arr Airport Name ICAO AL IATA AL  \
# 0                   KUL   Kuala Lumpur International Airport     EZD      Z2
# 1                   BCD                              Bacolod     CEB      5J
# 2                   DPS                        Denpasar-Bali     WON      IW
# 3                   KUA                              Kuantan     TGW      TR
# 4                   PLW                                 Palu     WON      IW
# ...                 ...                                  ...     ...     ...
# 920482              HKT                               Phuket     TVJ      VZ
# 920483              ICN  Seoul Incheon International Airport     KAL      KE
# 920484              CRK                    Angeles/Mabalacat     EZD      Z2
# 920485              KUL   Kuala Lumpur International Airport     MAS      MH
# 920486              KUL   Kuala Lumpur International Airport     AXM      AK
#
#         Flight No Carrier Code              Carrier Name  \
# 0            7112           Z2  Philippines AirAsia Inc.
# 1             485           5J          Cebu Pacific Air
# 2            1833           IW                 Wings Air
# 3             470           TR                     Scoot
# 4            1147           IW                 Wings Air
# ...           ...          ...                       ...
# 920482        302           VZ          Thai Vietjet Air
# 920483        624           KE                Korean Air
# 920484        908           Z2  Philippines AirAsia Inc.
# 920485        743           MH         Malaysia Airlines
# 920486       5205           AK                   AirAsia
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                Philippines  ...  Airbus A318/319/320/321    1613          1
# 1                Philippines  ...  Airbus A318/319/320/321     290          1
# 2                  Indonesia  ...              ATR42/ATR72     281          1
# 3                  Singapore  ...  Airbus A318/319/320/321     175          1
# 4                  Indonesia  ...              ATR42/ATR72     198          1
# ...                      ...  ...                      ...     ...        ...
# 920482              Thailand  ...  Airbus A318/319/320/321     419          1
# 920483           Philippines  ...     Boeing 777 Passenger    1620          1
# 920484           Philippines  ...  Airbus A318/319/320/321     408          1
# 920485               Myanmar  ...     Boeing 737 Passenger    1048          1
# 920486              Malaysia  ...  Airbus A318/319/320/321     602          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                 180  290340   4516.4  467280   7268.8                   230
# 1                 180   52200   2726.0   84060   4389.8                    90
# 2                  70   19670   1405.0   31640   2260.0                    80
# 3                 144   25200    122.5   40608    197.4                    70
# 4                  70   13860    990.0   22330   1595.0                    70
# ...               ...     ...      ...     ...      ...                   ...
# 920482            180   75420   3938.6  121320   6335.6                    90
# 920483            338  547560  49086.0  881166  78992.1                   240
# 920484            180   73440   1142.4  118260   1839.6                    85
# 920485            160  167680  18654.4  269920  30028.6                   165
# 920486            180  108360   5658.8  174420   9108.6                   110
#
#         Time series
# 0        2019-01-12
# 1        2019-03-15
# 2        2019-03-26
# 3        2019-01-27
# 4        2019-01-20
# ...             ...
# 920482   2019-12-06
# 920483   2019-11-16
# 920484   2019-10-25
# 920485   2019-10-03
# 920486   2019-10-13
#
# [3564713 rows x 25 columns]

# %%
movements_all = movements_2019.copy()
movements_all
# Out:
#        Dep Airport Code                        Dep Airport Name  \
# 0                   CEB                                    Cebu
# 1                   MNL   Manila Ninoy Aquino International Apt
# 2                   TMC                               Tambolaka
# 3                   SIN                    Singapore Changi Apt
# 4                   LUW                                   Luwuk
# ...                 ...                                     ...
# 920482              BKK  Bangkok Suvarnabhumi International Apt
# 920483              MNL   Manila Ninoy Aquino International Apt
# 920484              CEB                                    Cebu
# 920485              RGN                                  Yangon
# 920486              KCH                                 Kuching
#
#        Arr Airport Code                     Arr Airport Name ICAO AL IATA AL  \
# 0                   KUL   Kuala Lumpur International Airport     EZD      Z2
# 1                   BCD                              Bacolod     CEB      5J
# 2                   DPS                        Denpasar-Bali     WON      IW
# 3                   KUA                              Kuantan     TGW      TR
# 4                   PLW                                 Palu     WON      IW
# ...                 ...                                  ...     ...     ...
# 920482              HKT                               Phuket     TVJ      VZ
# 920483              ICN  Seoul Incheon International Airport     KAL      KE
# 920484              CRK                    Angeles/Mabalacat     EZD      Z2
# 920485              KUL   Kuala Lumpur International Airport     MAS      MH
# 920486              KUL   Kuala Lumpur International Airport     AXM      AK
#
#         Flight No Carrier Code              Carrier Name  \
# 0            7112           Z2  Philippines AirAsia Inc.
# 1             485           5J          Cebu Pacific Air
# 2            1833           IW                 Wings Air
# 3             470           TR                     Scoot
# 4            1147           IW                 Wings Air
# ...           ...          ...                       ...
# 920482        302           VZ          Thai Vietjet Air
# 920483        624           KE                Korean Air
# 920484        908           Z2  Philippines AirAsia Inc.
# 920485        743           MH         Malaysia Airlines
# 920486       5205           AK                   AirAsia
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                Philippines  ...  Airbus A318/319/320/321    1613          1
# 1                Philippines  ...  Airbus A318/319/320/321     290          1
# 2                  Indonesia  ...              ATR42/ATR72     281          1
# 3                  Singapore  ...  Airbus A318/319/320/321     175          1
# 4                  Indonesia  ...              ATR42/ATR72     198          1
# ...                      ...  ...                      ...     ...        ...
# 920482              Thailand  ...  Airbus A318/319/320/321     419          1
# 920483           Philippines  ...     Boeing 777 Passenger    1620          1
# 920484           Philippines  ...  Airbus A318/319/320/321     408          1
# 920485               Myanmar  ...     Boeing 737 Passenger    1048          1
# 920486              Malaysia  ...  Airbus A318/319/320/321     602          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                 180  290340   4516.4  467280   7268.8                   230
# 1                 180   52200   2726.0   84060   4389.8                    90
# 2                  70   19670   1405.0   31640   2260.0                    80
# 3                 144   25200    122.5   40608    197.4                    70
# 4                  70   13860    990.0   22330   1595.0                    70
# ...               ...     ...      ...     ...      ...                   ...
# 920482            180   75420   3938.6  121320   6335.6                    90
# 920483            338  547560  49086.0  881166  78992.1                   240
# 920484            180   73440   1142.4  118260   1839.6                    85
# 920485            160  167680  18654.4  269920  30028.6                   165
# 920486            180  108360   5658.8  174420   9108.6                   110
#
#         Time series
# 0        2019-01-12
# 1        2019-03-15
# 2        2019-03-26
# 3        2019-01-27
# 4        2019-01-20
# ...             ...
# 920482   2019-12-06
# 920483   2019-11-16
# 920484   2019-10-25
# 920485   2019-10-03
# 920486   2019-10-13
#
# [3564713 rows x 25 columns]

# %%
movements_Dep_SIN = movements_all.loc[movements_all['Dep Airport Code'] == 'SIN']
movements_Arr_SIN = movements_all.loc[movements_all['Arr Airport Code'] == 'SIN']
movements_SIN = pd.concat([movements_Dep_SIN,movements_Arr_SIN])
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 3                   SIN                Singapore Changi Apt              KUA
# 16                  SIN                Singapore Changi Apt              BKK
# 36                  SIN                Singapore Changi Apt              DEL
# 60                  SIN                Singapore Changi Apt              DPS
# 90                  SIN                Singapore Changi Apt              LHR
# ...                 ...                                 ...              ...
# 920353              KBV                               Krabi              SIN
# 920395              HKT                              Phuket              SIN
# 920404              HKG         Hong Kong International Apt              SIN
# 920430              KUL  Kuala Lumpur International Airport              SIN
# 920449              KUL  Kuala Lumpur International Airport              SIN
#
#                               Arr Airport Name ICAO AL IATA AL  Flight No  \
# 3                                      Kuantan     TGW      TR        470
# 16      Bangkok Suvarnabhumi International Apt     JSA      3K        513
# 36                                       Delhi     SIA      SQ        406
# 60                               Denpasar-Bali     JST      JQ        117
# 90                         London Heathrow Apt     BAW      BA         16
# ...                                        ...     ...     ...        ...
# 920353                    Singapore Changi Apt     AIQ      FD        330
# 920395                    Singapore Changi Apt     TGW      TR        653
# 920404                    Singapore Changi Apt     CPA      CX        715
# 920430                    Singapore Changi Apt     AXM      AK        707
# 920449                    Singapore Changi Apt     AXM      AK        721
#
#        Carrier Code            Carrier Name  Dep IATA Country Name  ...  \
# 3                TR                   Scoot              Singapore  ...
# 16               3K            Jetstar Asia              Singapore  ...
# 36               SQ      Singapore Airlines              Singapore  ...
# 60               JQ         Jetstar Airways              Singapore  ...
# 90               BA         British Airways              Singapore  ...
# ...             ...                     ...                    ...  ...
# 920353           FD            Thai AirAsia               Thailand  ...
# 920395           TR                   Scoot               Thailand  ...
# 920404           CX  Cathay Pacific Airways  Hong Kong (sar) China  ...
# 920430           AK                 AirAsia               Malaysia  ...
# 920449           AK                 AirAsia               Malaysia  ...
#
#           General Aircraft Name GCD (m)  Frequency  Seats (Total)     ASMs  \
# 3       Airbus A318/319/320/321     175          1            144    25200
# 16      Airbus A318/319/320/321     880          1            180   158400
# 36        Airbus A380 Passenger    2582          1            441  1138662
# 60      Airbus A318/319/320/321    1037          1            180   186660
# 90         Boeing 777 Passenger    6758          1            297  2007126
# ...                         ...     ...        ...            ...      ...
# 920353  Airbus A318/319/320/321     578          1            180   104040
# 920395  Airbus A318/319/320/321     608          1            180   109440
# 920404     Boeing 777 Passenger    1592          1            368   585856
# 920430  Airbus A318/319/320/321     184          1            180    33120
# 920449  Airbus A318/319/320/321     184          1            180    33120
#
#             ATMs     ASKs      ATKs  FlyingTime (Minutes)  Time series
# 3          122.5    40608     197.4                    70   2019-01-27
# 16        8184.0   254880   13168.8                   150   2019-03-07
# 36       31500.4  1832355   50691.0                   360   2019-03-16
# 60        9747.8   300420   15688.6                   160   2019-01-06
# 90      148676.0  3230172  239272.0                   840   2019-01-04
# ...          ...      ...       ...                   ...          ...
# 920353    5433.2   167400    8742.0                   105   2019-11-28
# 920395     425.6   176040     684.6                   115   2019-10-04
# 920404   32954.4   942816   53033.4                   230   2019-10-10
# 920430    1729.6    53280    2782.4                    60   2019-11-06
# 920449    1729.6    53280    2782.4                    75   2019-11-06
#
# [368136 rows x 25 columns]

# %%
# sort by date
movements_SIN.sort_values(by=['Time series'], inplace=True)
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 199803              SIN                Singapore Changi Apt              MNL
# 840502              KUL  Kuala Lumpur International Airport              SIN
# 762909              CEB                                Cebu              SIN
# 717599              KUL  Kuala Lumpur International Airport              SIN
# 471031              SIN                Singapore Changi Apt              RGN
# ...                 ...                                 ...              ...
# 313161              CKG                           Chongqing              SIN
# 297211              SIN                Singapore Changi Apt              SYD
# 839021              SYD          Sydney Kingsford Smith Apt              SIN
# 198488              SIN                Singapore Changi Apt              CJB
# 426015              HND                 Tokyo Intl (Haneda)              SIN
#
#                              Arr Airport Name ICAO AL IATA AL  Flight No  \
# 199803  Manila Ninoy Aquino International Apt     PAL      PR        508
# 840502                   Singapore Changi Apt     MXD      OD        803
# 762909                   Singapore Changi Apt     SLK      MI        559
# 717599                   Singapore Changi Apt     JSA      3K        670
# 471031                                 Yangon     SLK      MI        533
# ...                                       ...     ...     ...        ...
# 313161                   Singapore Changi Apt     CQN      OQ       2095
# 297211             Sydney Kingsford Smith Apt     SIA      SQ        288
# 839021                   Singapore Changi Apt     SIA      SQ        212
# 198488                             Coimbatore     TGW      TR        540
# 426015                   Singapore Changi Apt     SIA      SQ        635
#
#        Carrier Code         Carrier Name Dep IATA Country Name  ...  \
# 199803           PR  Philippine Airlines             Singapore  ...
# 840502           OD      Malindo Airways              Malaysia  ...
# 762909           MI              SilkAir           Philippines  ...
# 717599           3K         Jetstar Asia              Malaysia  ...
# 471031           MI              SilkAir             Singapore  ...
# ...             ...                  ...                   ...  ...
# 313161           OQ   Chongqing Airlines                 China  ...
# 297211           SQ   Singapore Airlines             Singapore  ...
# 839021           SQ   Singapore Airlines             Australia  ...
# 198488           TR                Scoot             Singapore  ...
# 426015           SQ   Singapore Airlines                 Japan  ...
#
#           General Aircraft Name GCD (m)  Frequency  Seats (Total)     ASMs  \
# 199803              Airbus A330    1475          1            309   455775
# 840502     Boeing 737 Passenger     184          1            180    33120
# 762909     Boeing 737 Passenger    1504          1            162   243648
# 717599  Airbus A318/319/320/321     184          1            180    33120
# 471031     Boeing 737 Passenger    1199          1            162   194238
# ...                         ...     ...        ...            ...      ...
# 313161  Airbus A318/319/320/321    1966          1            152   298832
# 297211     Boeing 777 Passenger    3908          1            264  1031712
# 839021     Boeing 777 Passenger    3908          1            264  1031712
# 198488  Airbus A318/319/320/321    1964          1            180   353520
# 426015     Boeing 777 Passenger    3291          1            264   868824
#
#             ATMs     ASKs      ATKs  FlyingTime (Minutes)  Time series
# 199803   14750.0   733566   23740.0                   245   2019-01-01
# 840502    3146.4    53280    5061.6                    60   2019-01-01
# 762909   26771.2   392040   43076.0                   235   2019-01-01
# 717599    1711.2    53280    2752.8                    65   2019-01-01
# 471031   21342.2   312660   34354.0                   175   2019-01-01
# ...          ...      ...       ...                   ...          ...
# 313161   18480.4   480928   29741.6                   290   2019-12-31
# 297211  101998.8  1660296  164142.9                   470   2019-12-31
# 839021  101998.8  1660296  164142.9                   490   2019-12-31
# 198488    1374.8   568980    2212.7                   265   2019-12-31
# 426015   85895.1  1398144  138225.6                   455   2019-12-31
#
# [368136 rows x 25 columns]

# %%
def dep_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0
    
def arr_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0

# %%
movements_SIN['Dep'] = 0
movements_SIN['Arr'] = 0

movements_SIN['Dep'] = movements_SIN['Dep Airport Code'].apply(dep_value)
movements_SIN['Arr'] = movements_SIN['Arr Airport Code'].apply(arr_value)

# %%
def dep_or_arr_time(dep, dep_time, arr_time):
    if dep == 1:
        return dep_time
    else:
        return arr_time

# %%
movements_SIN['Time_requested'] = movements_SIN[['Dep', 'Local Dep Time', 'Local Arr Time']].apply(lambda x: dep_or_arr_time(*x), axis=1)

# %%
movements_SIN = movements_SIN.drop(['Dep Airport Code', 'Arr Airport Code'], 1)

# %%
def f(s):
    return "".join(["0"]*(4-len(s))) + s

f('0')
# Out:
# '0000'

# %%
movements_SIN['Time_requested_format4'] = movements_SIN['Time_requested'].astype(str).apply(f)
movements_SIN['Time_requested_TS'] = movements_SIN['Time series'] + '-' + movements_SIN['Time_requested_format4']
movements_SIN['TS_datetime_format'] = pd.to_datetime(movements_SIN['Time_requested_TS'], format = '%Y-%m-%d-%H%M')

# %%
from pytz import all_timezones
import pytz

def utc(datetime):
    local = pytz.timezone("Asia/Singapore")
    local_dt = local.localize(datetime, is_dst=None)
    return local_dt.astimezone(pytz.utc)

# %%
movements_SIN['Time_requested_UTC'] = movements_SIN['TS_datetime_format'].apply(utc)

# %%
def day_of_week(s):
    return s.weekday()

# %%
movements_SIN['day_of_week'] = movements_SIN['Time_requested_UTC'].apply(day_of_week)
movements_SIN['Time_series_DT'] = pd.to_datetime(movements_SIN['Time series'], format = '%Y-%m-%d')

# %%
movements_SIN['Time_series_DT'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
movements_SIN['Time_series_DT'].max()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
SIN_2019_s = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2019,10,27)]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_series_DT'] > pd.Timestamp(2019,3,30)]

SIN_2019_w = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2020,3,29)]
SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]

# %%
def requested_utc_hour(s):
    return s.hour

def requested_utc_minute(s):
    return s.minute

# %%
# For all flights to and from SIN in 2019
SIN_2019 = movements_SIN
SIN_2019_df = SIN_2019.copy()

SIN_2019_df['requested_utc_hour'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_hour)
SIN_2019_df['requested_utc_minute'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_minute)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc_hour'].apply(str) + SIN_2019_df['requested_utc_minute'].apply(str)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc'].astype(int)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name  \
# 199803                Singapore Changi Apt
# 840502  Kuala Lumpur International Airport
# 762909                                Cebu
# 717599  Kuala Lumpur International Airport
# 471031                Singapore Changi Apt
# ...                                    ...
# 313161                           Chongqing
# 297211                Singapore Changi Apt
# 839021          Sydney Kingsford Smith Apt
# 198488                Singapore Changi Apt
# 426015                 Tokyo Intl (Haneda)
#
#                              Arr Airport Name ICAO AL IATA AL  Flight No  \
# 199803  Manila Ninoy Aquino International Apt     PAL      PR        508
# 840502                   Singapore Changi Apt     MXD      OD        803
# 762909                   Singapore Changi Apt     SLK      MI        559
# 717599                   Singapore Changi Apt     JSA      3K        670
# 471031                                 Yangon     SLK      MI        533
# ...                                       ...     ...     ...        ...
# 313161                   Singapore Changi Apt     CQN      OQ       2095
# 297211             Sydney Kingsford Smith Apt     SIA      SQ        288
# 839021                   Singapore Changi Apt     SIA      SQ        212
# 198488                             Coimbatore     TGW      TR        540
# 426015                   Singapore Changi Apt     SIA      SQ        635
#
#        Carrier Code         Carrier Name Dep IATA Country Name  \
# 199803           PR  Philippine Airlines             Singapore
# 840502           OD      Malindo Airways              Malaysia
# 762909           MI              SilkAir           Philippines
# 717599           3K         Jetstar Asia              Malaysia
# 471031           MI              SilkAir             Singapore
# ...             ...                  ...                   ...
# 313161           OQ   Chongqing Airlines                 China
# 297211           SQ   Singapore Airlines             Singapore
# 839021           SQ   Singapore Airlines             Australia
# 198488           TR                Scoot             Singapore
# 426015           SQ   Singapore Airlines                 Japan
#
#        Arr IATA Country Name International/Domestic  ...  Time_requested  \
# 199803           Philippines          International  ...            1450
# 840502             Singapore          International  ...            1130
# 762909             Singapore          International  ...            1855
# 717599             Singapore          International  ...            2140
# 471031               Myanmar          International  ...            1015
# ...                      ...                    ...  ...             ...
# 313161             Singapore          International  ...            1315
# 297211             Australia          International  ...             935
# 839021             Singapore          International  ...            1415
# 198488                 India          International  ...            2050
# 426015             Singapore          International  ...             525
#
#         Time_requested_format4 Time_requested_TS  TS_datetime_format  \
# 199803                    1450   2019-01-01-1450 2019-01-01 14:50:00
# 840502                    1130   2019-01-01-1130 2019-01-01 11:30:00
# 762909                    1855   2019-01-01-1855 2019-01-01 18:55:00
# 717599                    2140   2019-01-01-2140 2019-01-01 21:40:00
# 471031                    1015   2019-01-01-1015 2019-01-01 10:15:00
# ...                        ...               ...                 ...
# 313161                    1315   2019-12-31-1315 2019-12-31 13:15:00
# 297211                    0935   2019-12-31-0935 2019-12-31 09:35:00
# 839021                    1415   2019-12-31-1415 2019-12-31 14:15:00
# 198488                    2050   2019-12-31-2050 2019-12-31 20:50:00
# 426015                    0525   2019-12-31-0525 2019-12-31 05:25:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 199803 2019-01-01 06:50:00+00:00            1      2019-01-01
# 840502 2019-01-01 03:30:00+00:00            1      2019-01-01
# 762909 2019-01-01 10:55:00+00:00            1      2019-01-01
# 717599 2019-01-01 13:40:00+00:00            1      2019-01-01
# 471031 2019-01-01 02:15:00+00:00            1      2019-01-01
# ...                          ...          ...             ...
# 313161 2019-12-31 05:15:00+00:00            1      2019-12-31
# 297211 2019-12-31 01:35:00+00:00            1      2019-12-31
# 839021 2019-12-31 06:15:00+00:00            1      2019-12-31
# 198488 2019-12-31 12:50:00+00:00            1      2019-12-31
# 426015 2019-12-30 21:25:00+00:00            0      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc
# 199803                   6                    50            650
# 840502                   3                    30            330
# 762909                  10                    55           1055
# 717599                  13                    40           1340
# 471031                   2                    15            215
# ...                    ...                   ...            ...
# 313161                   5                    15            515
# 297211                   1                    35            135
# 839021                   6                    15            615
# 198488                  12                    50           1250
# 426015                  21                    25           2125
#
# [368136 rows x 35 columns]

# %%
time_slots = []
h = 0
m = 0
while h < 2400:
    while m < 60:
        time_slots.append(h + m)
        m = m + 5
    m = 0
    h = h + 100
    #print(i)
time_slots.append(2400)
print(len(time_slots))
time_slots
# Out:
# 289
# [0,
#  5,
#  10,
#  15,
#  20,
#  25,
#  30,
#  35,
#  40,
#  45,
#  50,
#  55,
#  100,
#  105,
#  110,
#  115,
#  120,
#  125,
#  130,
#  135,
#  140,
#  145,
#  150,
#  155,
#  200,
#  205,
#  210,
#  215,
#  220,
#  225,
#  230,
#  235,
#  240,
#  245,
#  250,
#  255,
#  300,
#  305,
#  310,
#  315,
#  320,
#  325,
#  330,
#  335,
#  340,
#  345,
#  350,
#  355,
#  400,
#  405,
#  410,
#  415,
#  420,
#  425,
#  430,
#  435,
#  440,
#  445,
#  450,
#  455,
#  500,
#  505,
#  510,
#  515,
#  520,
#  525,
#  530,
#  535,
#  540,
#  545,
#  550,
#  555,
#  600,
#  605,
#  610,
#  615,
#  620,
#  625,
#  630,
#  635,
#  640,
#  645,
#  650,
#  655,
#  700,
#  705,
#  710,
#  715,
#  720,
#  725,
#  730,
#  735,
#  740,
#  745,
#  750,
#  755,
#  800,
#  805,
#  810,
#  815,
#  820,
#  825,
#  830,
#  835,
#  840,
#  845,
#  850,
#  855,
#  900,
#  905,
#  910,
#  915,
#  920,
#  925,
#  930,
#  935,
#  940,
#  945,
#  950,
#  955,
#  1000,
#  1005,
#  1010,
#  1015,
#  1020,
#  1025,
#  1030,
#  1035,
#  1040,
#  1045,
#  1050,
#  1055,
#  1100,
#  1105,
#  1110,
#  1115,
#  1120,
#  1125,
#  1130,
#  1135,
#  1140,
#  1145,
#  1150,
#  1155,
#  1200,
#  1205,
#  1210,
#  1215,
#  1220,
#  1225,
#  1230,
#  1235,
#  1240,
#  1245,
#  1250,
#  1255,
#  1300,
#  1305,
#  1310,
#  1315,
#  1320,
#  1325,
#  1330,
#  1335,
#  1340,
#  1345,
#  1350,
#  1355,
#  1400,
#  1405,
#  1410,
#  1415,
#  1420,
#  1425,
#  1430,
#  1435,
#  1440,
#  1445,
#  1450,
#  1455,
#  1500,
#  1505,
#  1510,
#  1515,
#  1520,
#  1525,
#  1530,
#  1535,
#  1540,
#  1545,
#  1550,
#  1555,
#  1600,
#  1605,
#  1610,
#  1615,
#  1620,
#  1625,
#  1630,
#  1635,
#  1640,
#  1645,
#  1650,
#  1655,
#  1700,
#  1705,
#  1710,
#  1715,
#  1720,
#  1725,
#  1730,
#  1735,
#  1740,
#  1745,
#  1750,
#  1755,
#  1800,
#  1805,
#  1810,
#  1815,
#  1820,
#  1825,
#  1830,
#  1835,
#  1840,
#  1845,
#  1850,
#  1855,
#  1900,
#  1905,
#  1910,
#  1915,
#  1920,
#  1925,
#  1930,
#  1935,
#  1940,
#  1945,
#  1950,
#  1955,
#  2000,
#  2005,
#  2010,
#  2015,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2100,
#  2105,
#  2110,
#  2115,
#  2120,
#  2125,
#  2130,
#  2135,
#  2140,
#  2145,
#  2150,
#  2155,
#  2200,
#  2205,
#  2210,
#  2215,
#  2220,
#  2225,
#  2230,
#  2235,
#  2240,
#  2245,
#  2250,
#  2255,
#  2300,
#  2305,
#  2310,
#  2315,
#  2320,
#  2325,
#  2330,
#  2335,
#  2340,
#  2345,
#  2350,
#  2355,
#  2400]

# %%
SIN_2019_df['Time slot'] = pd.cut(SIN_2019_df['requested_utc'], time_slots)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name  \
# 199803                Singapore Changi Apt
# 840502  Kuala Lumpur International Airport
# 762909                                Cebu
# 717599  Kuala Lumpur International Airport
# 471031                Singapore Changi Apt
# ...                                    ...
# 313161                           Chongqing
# 297211                Singapore Changi Apt
# 839021          Sydney Kingsford Smith Apt
# 198488                Singapore Changi Apt
# 426015                 Tokyo Intl (Haneda)
#
#                              Arr Airport Name ICAO AL IATA AL  Flight No  \
# 199803  Manila Ninoy Aquino International Apt     PAL      PR        508
# 840502                   Singapore Changi Apt     MXD      OD        803
# 762909                   Singapore Changi Apt     SLK      MI        559
# 717599                   Singapore Changi Apt     JSA      3K        670
# 471031                                 Yangon     SLK      MI        533
# ...                                       ...     ...     ...        ...
# 313161                   Singapore Changi Apt     CQN      OQ       2095
# 297211             Sydney Kingsford Smith Apt     SIA      SQ        288
# 839021                   Singapore Changi Apt     SIA      SQ        212
# 198488                             Coimbatore     TGW      TR        540
# 426015                   Singapore Changi Apt     SIA      SQ        635
#
#        Carrier Code         Carrier Name Dep IATA Country Name  \
# 199803           PR  Philippine Airlines             Singapore
# 840502           OD      Malindo Airways              Malaysia
# 762909           MI              SilkAir           Philippines
# 717599           3K         Jetstar Asia              Malaysia
# 471031           MI              SilkAir             Singapore
# ...             ...                  ...                   ...
# 313161           OQ   Chongqing Airlines                 China
# 297211           SQ   Singapore Airlines             Singapore
# 839021           SQ   Singapore Airlines             Australia
# 198488           TR                Scoot             Singapore
# 426015           SQ   Singapore Airlines                 Japan
#
#        Arr IATA Country Name International/Domestic  ...  \
# 199803           Philippines          International  ...
# 840502             Singapore          International  ...
# 762909             Singapore          International  ...
# 717599             Singapore          International  ...
# 471031               Myanmar          International  ...
# ...                      ...                    ...  ...
# 313161             Singapore          International  ...
# 297211             Australia          International  ...
# 839021             Singapore          International  ...
# 198488                 India          International  ...
# 426015             Singapore          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 199803                    1450    2019-01-01-1450 2019-01-01 14:50:00
# 840502                    1130    2019-01-01-1130 2019-01-01 11:30:00
# 762909                    1855    2019-01-01-1855 2019-01-01 18:55:00
# 717599                    2140    2019-01-01-2140 2019-01-01 21:40:00
# 471031                    1015    2019-01-01-1015 2019-01-01 10:15:00
# ...                        ...                ...                 ...
# 313161                    1315    2019-12-31-1315 2019-12-31 13:15:00
# 297211                    0935    2019-12-31-0935 2019-12-31 09:35:00
# 839021                    1415    2019-12-31-1415 2019-12-31 14:15:00
# 198488                    2050    2019-12-31-2050 2019-12-31 20:50:00
# 426015                    0525    2019-12-31-0525 2019-12-31 05:25:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 199803 2019-01-01 06:50:00+00:00            1      2019-01-01
# 840502 2019-01-01 03:30:00+00:00            1      2019-01-01
# 762909 2019-01-01 10:55:00+00:00            1      2019-01-01
# 717599 2019-01-01 13:40:00+00:00            1      2019-01-01
# 471031 2019-01-01 02:15:00+00:00            1      2019-01-01
# ...                          ...          ...             ...
# 313161 2019-12-31 05:15:00+00:00            1      2019-12-31
# 297211 2019-12-31 01:35:00+00:00            1      2019-12-31
# 839021 2019-12-31 06:15:00+00:00            1      2019-12-31
# 198488 2019-12-31 12:50:00+00:00            1      2019-12-31
# 426015 2019-12-30 21:25:00+00:00            0      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 199803                   6                    50            650    (645, 650]
# 840502                   3                    30            330    (325, 330]
# 762909                  10                    55           1055  (1050, 1055]
# 717599                  13                    40           1340  (1335, 1340]
# 471031                   2                    15            215    (210, 215]
# ...                    ...                   ...            ...           ...
# 313161                   5                    15            515    (510, 515]
# 297211                   1                    35            135    (130, 135]
# 839021                   6                    15            615    (610, 615]
# 198488                  12                    50           1250  (1245, 1250]
# 426015                  21                    25           2125  (2120, 2125]
#
# [368136 rows x 36 columns]

# %%
SIN_2019_s = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2019,10,27)]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_series_DT'] > pd.Timestamp(2019,3,30)]

# %%
SIN_2019_s
# Out:
#                                Dep Airport Name      Arr Airport Name ICAO AL  \
# 622853              Hong Kong International Apt  Singapore Changi Apt     CPA
# 561088                            Kota Kinabalu  Singapore Changi Apt     SLK
# 653794                     Singapore Changi Apt   London Heathrow Apt     SIA
# 699458                                Bengaluru  Singapore Changi Apt     SLK
# 785511                               Kochi (IN)  Singapore Changi Apt     SLK
# ...                                         ...                   ...     ...
# 188193                     Singapore Changi Apt             Bengaluru     SIA
# 601015                            San Francisco  Singapore Changi Apt     UAL
# 479114  Taipei Taiwan Taoyuan International Apt  Singapore Changi Apt     TGW
# 714072                                    Hanoi  Singapore Changi Apt     VJC
# 904810                      Dubai International  Singapore Changi Apt     UAE
#
#        IATA AL  Flight No Carrier Code            Carrier Name  \
# 622853      CX        735           CX  Cathay Pacific Airways
# 561088      MI        395           MI                 SilkAir
# 653794      SQ        322           SQ      Singapore Airlines
# 699458      MI        423           MI                 SilkAir
# 785511      MI        467           MI                 SilkAir
# ...        ...        ...          ...                     ...
# 188193      SQ        504           SQ      Singapore Airlines
# 601015      UA         29           UA         United Airlines
# 479114      TR        875           TR                   Scoot
# 714072      VJ        915           VJ                 Vietjet
# 904810      EK        404           EK                Emirates
#
#         Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 622853  Hong Kong (sar) China             Singapore          International
# 561088               Malaysia             Singapore          International
# 653794              Singapore        United Kingdom          International
# 699458                  India             Singapore          International
# 785511                  India             Singapore          International
# ...                       ...                   ...                    ...
# 188193              Singapore                 India          International
# 601015                    USA             Singapore          International
# 479114         Chinese Taipei             Singapore          International
# 714072               Viet Nam             Singapore          International
# 904810   United Arab Emirates             Singapore          International
#
#         ...  Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 622853  ...                    1825    2019-03-31-1825 2019-03-31 18:25:00
# 561088  ...                    2200    2019-03-31-2200 2019-03-31 22:00:00
# 653794  ...                    2330    2019-03-31-2330 2019-03-31 23:30:00
# 699458  ...                    1930    2019-03-31-1930 2019-03-31 19:30:00
# 785511  ...                    0555    2019-03-31-0555 2019-03-31 05:55:00
# ...     ...                     ...                ...                 ...
# 188193  ...                    2220    2019-10-26-2220 2019-10-26 22:20:00
# 601015  ...                    2015    2019-10-26-2015 2019-10-26 20:15:00
# 479114  ...                    0450    2019-10-26-0450 2019-10-26 04:50:00
# 714072  ...                    1355    2019-10-26-1355 2019-10-26 13:55:00
# 904810  ...                    1405    2019-10-26-1405 2019-10-26 14:05:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 622853 2019-03-31 10:25:00+00:00            6      2019-03-31
# 561088 2019-03-31 14:00:00+00:00            6      2019-03-31
# 653794 2019-03-31 15:30:00+00:00            6      2019-03-31
# 699458 2019-03-31 11:30:00+00:00            6      2019-03-31
# 785511 2019-03-30 21:55:00+00:00            5      2019-03-31
# ...                          ...          ...             ...
# 188193 2019-10-26 14:20:00+00:00            5      2019-10-26
# 601015 2019-10-26 12:15:00+00:00            5      2019-10-26
# 479114 2019-10-25 20:50:00+00:00            4      2019-10-26
# 714072 2019-10-26 05:55:00+00:00            5      2019-10-26
# 904810 2019-10-26 06:05:00+00:00            5      2019-10-26
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 622853                  10                    25           1025  (1020, 1025]
# 561088                  14                     0            140    (135, 140]
# 653794                  15                    30           1530  (1525, 1530]
# 699458                  11                    30           1130  (1125, 1130]
# 785511                  21                    55           2155  (2150, 2155]
# ...                    ...                   ...            ...           ...
# 188193                  14                    20           1420  (1415, 1420]
# 601015                  12                    15           1215  (1210, 1215]
# 479114                  20                    50           2050  (2045, 2050]
# 714072                   5                    55            555    (550, 555]
# 904810                   6                     5             65     (55, 100]
#
# [208998 rows x 36 columns]

# %%
SIN_2019_s['Time_series_DT'].unique()[0:7]
# Out:
# array(['2019-03-31T00:00:00.000000000', '2019-04-01T00:00:00.000000000',
#        '2019-04-02T00:00:00.000000000', '2019-04-03T00:00:00.000000000',
#        '2019-04-04T00:00:00.000000000', '2019-04-05T00:00:00.000000000',
#        '2019-04-06T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# start here
first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
date = first_week[0]
SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
SIN_2019_s_d1
# Out:
#                    Dep Airport Name            Arr Airport Name ICAO AL  \
# 622853  Hong Kong International Apt        Singapore Changi Apt     CPA
# 561088                Kota Kinabalu        Singapore Changi Apt     SLK
# 653794         Singapore Changi Apt         London Heathrow Apt     SIA
# 699458                    Bengaluru        Singapore Changi Apt     SLK
# 785511                   Kochi (IN)        Singapore Changi Apt     SLK
# ...                             ...                         ...     ...
# 183749         Singapore Changi Apt                     Da Nang     SLK
# 45902          Singapore Changi Apt                   Chongqing     SLK
# 370973               Zurich Airport        Singapore Changi Apt     SWR
# 188122         Singapore Changi Apt  Jakarta Soekarno-Hatta Apt     GIA
# 393530                   Kochi (IN)        Singapore Changi Apt     SLK
#
#        IATA AL  Flight No Carrier Code            Carrier Name  \
# 622853      CX        735           CX  Cathay Pacific Airways
# 561088      MI        395           MI                 SilkAir
# 653794      SQ        322           SQ      Singapore Airlines
# 699458      MI        423           MI                 SilkAir
# 785511      MI        467           MI                 SilkAir
# ...        ...        ...          ...                     ...
# 183749      MI        632           MI                 SilkAir
# 45902       MI        972           MI                 SilkAir
# 370973      LX        176           LX                   SWISS
# 188122      GA        837           GA        Garuda Indonesia
# 393530      MI        463           MI                 SilkAir
#
#         Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 622853  Hong Kong (sar) China             Singapore          International
# 561088               Malaysia             Singapore          International
# 653794              Singapore        United Kingdom          International
# 699458                  India             Singapore          International
# 785511                  India             Singapore          International
# ...                       ...                   ...                    ...
# 183749              Singapore              Viet Nam          International
# 45902               Singapore                 China          International
# 370973            Switzerland             Singapore          International
# 188122              Singapore             Indonesia          International
# 393530                  India             Singapore          International
#
#         ...  Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 622853  ...                    1825    2019-03-31-1825 2019-03-31 18:25:00
# 561088  ...                    2200    2019-03-31-2200 2019-03-31 22:00:00
# 653794  ...                    2330    2019-03-31-2330 2019-03-31 23:30:00
# 699458  ...                    1930    2019-03-31-1930 2019-03-31 19:30:00
# 785511  ...                    0555    2019-03-31-0555 2019-03-31 05:55:00
# ...     ...                     ...                ...                 ...
# 183749  ...                    0900    2019-03-31-0900 2019-03-31 09:00:00
# 45902   ...                    0700    2019-03-31-0700 2019-03-31 07:00:00
# 370973  ...                    1655    2019-03-31-1655 2019-03-31 16:55:00
# 188122  ...                    1845    2019-03-31-1845 2019-03-31 18:45:00
# 393530  ...                    0425    2019-03-31-0425 2019-03-31 04:25:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 622853 2019-03-31 10:25:00+00:00            6      2019-03-31
# 561088 2019-03-31 14:00:00+00:00            6      2019-03-31
# 653794 2019-03-31 15:30:00+00:00            6      2019-03-31
# 699458 2019-03-31 11:30:00+00:00            6      2019-03-31
# 785511 2019-03-30 21:55:00+00:00            5      2019-03-31
# ...                          ...          ...             ...
# 183749 2019-03-31 01:00:00+00:00            6      2019-03-31
# 45902  2019-03-30 23:00:00+00:00            5      2019-03-31
# 370973 2019-03-31 08:55:00+00:00            6      2019-03-31
# 188122 2019-03-31 10:45:00+00:00            6      2019-03-31
# 393530 2019-03-30 20:25:00+00:00            5      2019-03-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 622853                  10                    25           1025  (1020, 1025]
# 561088                  14                     0            140    (135, 140]
# 653794                  15                    30           1530  (1525, 1530]
# 699458                  11                    30           1130  (1125, 1130]
# 785511                  21                    55           2155  (2150, 2155]
# ...                    ...                   ...            ...           ...
# 183749                   1                     0             10       (5, 10]
# 45902                   23                     0            230    (225, 230]
# 370973                   8                    55            855    (850, 855]
# 188122                  10                    45           1045  (1040, 1045]
# 393530                  20                    25           2025  (2020, 2025]
#
# [1067 rows x 36 columns]

# %%
timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
timeslot_movements = timeslot_movements.to_frame()
timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
timeslot_movements = timeslot_movements.reset_index()
timeslot_movements
# Out:
#             index  Movements
# 0       (55, 100]         50
# 1        (25, 30]         15
# 2         (5, 10]         11
# 3    (1110, 1115]         11
# 4      (115, 120]         10
# ..            ...        ...
# 284  (2045, 2050]          0
# 285    (300, 305]          0
# 286    (255, 300]          0
# 287    (600, 605]          0
# 288  (1200, 1205]          0
#
# [289 rows x 2 columns]

# %%
# convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
start = 0
end = 5
interval = pd.Interval(left=start, right=end, closed='right')

# eg. (0, 5] -> slot 1
interval_slot_dict = {} 

for slot in range(1, 289, 1):
    interval_slot_dict[interval] = slot
    if (end % 100 == 55):
        start = interval.left + 5
        end = interval.right + 45
    elif (start % 100 == 55):
        start = interval.left + 45
        end = interval.right + 5
    else:
        start = interval.left + 5
        end = interval.right + 5
    
    interval = pd.Interval(left=start, right=end, closed='right')

# %%
timeslot_movements['Slot'] = ''
for index, row in timeslot_movements.iterrows():
    row['Slot'] = interval_slot_dict.get(row['index'])
    
timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)

# %%
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1        (25, 30]         15    6.0
# 2         (5, 10]         11    2.0
# 3    (1110, 1115]         11  135.0
# 4      (115, 120]         10   16.0
# ..            ...        ...    ...
# 284  (2045, 2050]          0  250.0
# 285    (300, 305]          0   37.0
# 286    (255, 300]          0   36.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
x = timeslot_movements['Slot']
y = timeslot_movements['Movements'] 

plt.figure(figsize=(10,6))
plt.bar(x, y, width=3.0) 
 
plt.xlabel('Timeslot') 
plt.ylabel('No. of movements') 

plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

plt.show()

# %%
def timeslot_to_index():
    # convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
    start = 0
    end = 5
    interval = pd.Interval(left=start, right=end, closed='right')

    # eg. (0, 5] -> slot 1
    interval_slot_dict = {} 

    for slot in range(1, 289, 1):
        interval_slot_dict[interval] = slot
        if (end % 100 == 55):
            start = interval.left + 5
            end = interval.right + 45
        elif (start % 100 == 55):
            start = interval.left + 45
            end = interval.right + 5
        else:
            start = interval.left + 5
            end = interval.right + 5
    
        interval = pd.Interval(left=start, right=end, closed='right')
        
    return interval_slot_dict

# %%
def get_first_week_dates(SIN_2019_s):
    first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
    return first_week # array with 1st week's dates

# %%
def get_first_week_df(SIN_2019_s, date): # date = first_week[0]
    # date = first_week[0]
    SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
    return SIN_2019_s_d1 # df of a particualr day of the 1st week

# %%
def mov_per_slot(SIN_2019_s_d1, interval_slot_dict):
    timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
    timeslot_movements = timeslot_movements.to_frame()
    timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
    timeslot_movements = timeslot_movements.reset_index()
    
    timeslot_movements['Slot'] = ''
    for index, row in timeslot_movements.iterrows():
        row['Slot'] = interval_slot_dict.get(row['index'])
    
    timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)
    return timeslot_movements

# %%
def get_date_plot(timeslot_movements, date):
    x = timeslot_movements['Slot']
    y = timeslot_movements['Movements'] 

    plt.figure(figsize=(10,6))
    plt.bar(x, y, width=3.0) 
 
    plt.xlabel('Timeslot') 
    plt.ylabel('No. of movements') 

    plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

    plt.show()

# %%
# 1st day - 2019 summer
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[0]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1        (25, 30]         15    6.0
# 2         (5, 10]         11    2.0
# 3    (1110, 1115]         11  135.0
# 4      (115, 120]         10   16.0
# ..            ...        ...    ...
# 284  (2045, 2050]          0  250.0
# 285    (300, 305]          0   37.0
# 286    (255, 300]          0   36.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[1]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1         (5, 10]         12    2.0
# 2      (140, 145]         12   21.0
# 3        (10, 15]         12    3.0
# 4      (225, 230]         12   30.0
# ..            ...        ...    ...
# 284    (655, 700]          0   84.0
# 285    (700, 705]          0   85.0
# 286  (1805, 1810]          0  218.0
# 287  (1800, 1805]          0  217.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[2]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         49   12.0
# 1         (5, 10]         11    2.0
# 2        (25, 30]         11    6.0
# 3        (15, 20]         10    4.0
# 4      (155, 200]         10   24.0
# ..            ...        ...    ...
# 284  (1805, 1810]          0  218.0
# 285  (1800, 1805]          0  217.0
# 286    (555, 600]          0   72.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[3]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1        (25, 30]         12    6.0
# 2      (225, 230]         11   30.0
# 3         (5, 10]         11    2.0
# 4      (140, 145]         11   21.0
# ..            ...        ...    ...
# 284  (1800, 1805]          0  217.0
# 285  (1755, 1800]          0  216.0
# 286    (555, 600]          0   72.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[4]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1         (5, 10]         13    2.0
# 2        (25, 30]         12    6.0
# 3        (10, 15]         11    3.0
# 4        (15, 20]         11    4.0
# ..            ...        ...    ...
# 284    (455, 500]          0   60.0
# 285    (500, 505]          0   61.0
# 286  (1905, 1910]          0  230.0
# 287  (1900, 1905]          0  229.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[5]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         48   12.0
# 1        (25, 30]         15    6.0
# 2      (225, 230]         12   30.0
# 3      (140, 145]         11   21.0
# 4         (5, 10]         11    2.0
# ..            ...        ...    ...
# 284    (600, 605]          0   73.0
# 285  (1835, 1840]          0  224.0
# 286    (655, 700]          0   84.0
# 287    (700, 705]          0   85.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[6]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1         (5, 10]         13    2.0
# 2        (25, 30]         11    6.0
# 3        (15, 20]         11    4.0
# 4      (155, 200]         10   24.0
# ..            ...        ...    ...
# 284  (1805, 1810]          0  218.0
# 285  (1800, 1805]          0  217.0
# 286    (655, 700]          0   84.0
# 287    (700, 705]          0   85.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
SIN_2019_w = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2020,3,29)]
SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]
SIN_2019_w
# Out:
#                               Dep Airport Name            Arr Airport Name  \
# 33107   Bangkok Suvarnabhumi International Apt        Singapore Changi Apt
# 247562                    Singapore Changi Apt                    Surabaya
# 59671         Hyderabad Rajiv Gandhi Intl Arpt        Singapore Changi Apt
# 430678                    Singapore Changi Apt               Denpasar-Bali
# 346280                                 Chengdu        Singapore Changi Apt
# ...                                        ...                         ...
# 313161                               Chongqing        Singapore Changi Apt
# 297211                    Singapore Changi Apt  Sydney Kingsford Smith Apt
# 839021              Sydney Kingsford Smith Apt        Singapore Changi Apt
# 198488                    Singapore Changi Apt                  Coimbatore
# 426015                     Tokyo Intl (Haneda)        Singapore Changi Apt
#
#        ICAO AL IATA AL  Flight No Carrier Code        Carrier Name  \
# 33107      SIA      SQ        981           SQ  Singapore Airlines
# 247562     SIA      SQ        930           SQ  Singapore Airlines
# 59671      TGW      TR        575           TR               Scoot
# 430678     TGW      TR        288           TR               Scoot
# 346280     SLK      MI        937           MI             SilkAir
# ...        ...     ...        ...          ...                 ...
# 313161     CQN      OQ       2095           OQ  Chongqing Airlines
# 297211     SIA      SQ        288           SQ  Singapore Airlines
# 839021     SIA      SQ        212           SQ  Singapore Airlines
# 198488     TGW      TR        540           TR               Scoot
# 426015     SIA      SQ        635           SQ  Singapore Airlines
#
#        Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 33107               Thailand             Singapore          International
# 247562             Singapore             Indonesia          International
# 59671                  India             Singapore          International
# 430678             Singapore             Indonesia          International
# 346280                 China             Singapore          International
# ...                      ...                   ...                    ...
# 313161                 China             Singapore          International
# 297211             Singapore             Australia          International
# 839021             Australia             Singapore          International
# 198488             Singapore                 India          International
# 426015                 Japan             Singapore          International
#
#         ...  Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 33107   ...                    0040    2019-10-27-0040 2019-10-27 00:40:00
# 247562  ...                    0750    2019-10-27-0750 2019-10-27 07:50:00
# 59671   ...                    0850    2019-10-27-0850 2019-10-27 08:50:00
# 430678  ...                    1520    2019-10-27-1520 2019-10-27 15:20:00
# 346280  ...                    0410    2019-10-27-0410 2019-10-27 04:10:00
# ...     ...                     ...                ...                 ...
# 313161  ...                    1315    2019-12-31-1315 2019-12-31 13:15:00
# 297211  ...                    0935    2019-12-31-0935 2019-12-31 09:35:00
# 839021  ...                    1415    2019-12-31-1415 2019-12-31 14:15:00
# 198488  ...                    2050    2019-12-31-2050 2019-12-31 20:50:00
# 426015  ...                    0525    2019-12-31-0525 2019-12-31 05:25:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 33107  2019-10-26 16:40:00+00:00            5      2019-10-27
# 247562 2019-10-26 23:50:00+00:00            5      2019-10-27
# 59671  2019-10-27 00:50:00+00:00            6      2019-10-27
# 430678 2019-10-27 07:20:00+00:00            6      2019-10-27
# 346280 2019-10-26 20:10:00+00:00            5      2019-10-27
# ...                          ...          ...             ...
# 313161 2019-12-31 05:15:00+00:00            1      2019-12-31
# 297211 2019-12-31 01:35:00+00:00            1      2019-12-31
# 839021 2019-12-31 06:15:00+00:00            1      2019-12-31
# 198488 2019-12-31 12:50:00+00:00            1      2019-12-31
# 426015 2019-12-30 21:25:00+00:00            0      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 33107                   16                    40           1640  (1635, 1640]
# 247562                  23                    50           2350  (2345, 2350]
# 59671                    0                    50             50      (45, 50]
# 430678                   7                    20            720    (715, 720]
# 346280                  20                    10           2010  (2005, 2010]
# ...                    ...                   ...            ...           ...
# 313161                   5                    15            515    (510, 515]
# 297211                   1                    35            135    (130, 135]
# 839021                   6                    15            615    (610, 615]
# 198488                  12                    50           1250  (1245, 1250]
# 426015                  21                    25           2125  (2120, 2125]
#
# [67142 rows x 36 columns]

# %%
# 1st day - 2019 winter
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[0]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1      (125, 130]         14   18.0
# 2        (50, 55]         13   11.0
# 3      (105, 110]         13   14.0
# 4    (1550, 1555]         12  191.0
# ..            ...        ...    ...
# 284  (1755, 1800]          0  216.0
# 285    (555, 600]          0   72.0
# 286    (600, 605]          0   73.0
# 287  (1730, 1735]          0  211.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[1]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1      (155, 200]         16   24.0
# 2        (15, 20]         14    4.0
# 3        (25, 30]         14    6.0
# 4      (105, 110]         13   14.0
# ..            ...        ...    ...
# 284  (1830, 1835]          0  223.0
# 285  (1810, 1815]          0  219.0
# 286  (1805, 1810]          0  218.0
# 287  (1800, 1805]          0  217.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[2]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         43   12.0
# 1      (155, 200]         16   24.0
# 2        (50, 55]         14   11.0
# 3        (25, 30]         13    6.0
# 4      (125, 130]         13   18.0
# ..            ...        ...    ...
# 284  (1905, 1910]          0  230.0
# 285  (1900, 1905]          0  229.0
# 286  (1855, 1900]          0  228.0
# 287  (1850, 1855]          0  227.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[3]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         40   12.0
# 1      (125, 130]         16   18.0
# 2      (155, 200]         14   24.0
# 3        (15, 20]         14    4.0
# 4      (105, 110]         14   14.0
# ..            ...        ...    ...
# 284  (1920, 1925]          0  233.0
# 285  (1905, 1910]          0  230.0
# 286  (1900, 1905]          0  229.0
# 287    (555, 600]          0   72.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[4]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         46   12.0
# 1      (155, 200]         16   24.0
# 2        (25, 30]         16    6.0
# 3        (50, 55]         14   11.0
# 4        (15, 20]         13    4.0
# ..            ...        ...    ...
# 284    (400, 405]          0   49.0
# 285  (1745, 1750]          0  214.0
# 286  (1455, 1500]          0  180.0
# 287    (900, 905]          0  109.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[5]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         44   12.0
# 1      (155, 200]         17   24.0
# 2      (125, 130]         15   18.0
# 3        (25, 30]         14    6.0
# 4        (15, 20]         13    4.0
# ..            ...        ...    ...
# 284  (1855, 1900]          0  228.0
# 285  (1850, 1855]          0  227.0
# 286    (755, 800]          0   96.0
# 287    (800, 805]          0   97.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_w)
date = first_week[6]
SIN_2019_w_1d = get_first_week_df(SIN_2019_w, date)
timeslot_movements = mov_per_slot(SIN_2019_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         44   12.0
# 1      (155, 200]         14   24.0
# 2        (25, 30]         14    6.0
# 3      (125, 130]         13   18.0
# 4        (50, 55]         13   11.0
# ..            ...        ...    ...
# 284  (1935, 1940]          0  236.0
# 285  (1930, 1935]          0  235.0
# 286  (1920, 1925]          0  233.0
# 287   (955, 1000]          0  120.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)
