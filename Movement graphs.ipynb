# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder = "./ASEAN_2018D"
movements_2018_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jan_Mar_JobId2081527.csv", sep = ",", header = 0)
movements_2018_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Apr_Jun_JobId2081525.csv", sep = ",", header = 0)
movements_2018_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jul_Sep_JobId2081528.csv", sep = ",", header = 0)
movements_2018_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Oct_Dec_JobId2081529.csv", sep = ",", header = 0)
movements_2018 = pd.concat([movements_2018_1, movements_2018_2, movements_2018_3, movements_2018_4])

# %%
movements_2018
# Out:
#        Dep Airport Code Dep Airport Name Arr Airport Code Arr Airport Name  \
# 0                   ABU          Atambua              KOE           Kupang
# 1                   ABU          Atambua              KOE           Kupang
# 2                   ABU          Atambua              KOE           Kupang
# 3                   ABU          Atambua              KOE           Kupang
# 4                   ABU          Atambua              KOE           Kupang
# ...                 ...              ...              ...              ...
# 899779              ZYI    Zunyi (CN) 00              LGK         Langkawi
# 899780              ZYI    Zunyi (CN) 00              LGK         Langkawi
# 899781              ZYI    Zunyi (CN) 00              LGK         Langkawi
# 899782              ZYI    Zunyi (CN) 00              REP        Siem Reap
# 899783              ZYI    Zunyi (CN) 00              REP        Siem Reap
#
#        ICAO AL IATA AL  Flight No Carrier Code     Carrier Name  \
# 0          WON      IW       1932           IW        Wings Air
# 1          WON      IW       1932           IW        Wings Air
# 2          WON      IW       1932           IW        Wings Air
# 3          WON      IW       1932           IW        Wings Air
# 4          WON      IW       1932           IW        Wings Air
# ...        ...     ...        ...          ...              ...
# 899779     MXD      OD       8683           OD  Malindo Airways
# 899780     MXD      OD       8683           OD  Malindo Airways
# 899781     MXD      OD       8683           OD  Malindo Airways
# 899782     MKR      LQ        933           LQ  Lanmei Airlines
# 899783     MKR      LQ        933           LQ  Lanmei Airlines
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                  Indonesia  ...              ATR42/ATR72     113          1
# 1                  Indonesia  ...              ATR42/ATR72     113          1
# 2                  Indonesia  ...              ATR42/ATR72     113          1
# 3                  Indonesia  ...              ATR42/ATR72     113          1
# 4                  Indonesia  ...              ATR42/ATR72     113          1
# ...                      ...  ...                      ...     ...        ...
# 899779                 China  ...     Boeing 737 Passenger    1562          1
# 899780                 China  ...     Boeing 737 Passenger    1562          1
# 899781                 China  ...     Boeing 737 Passenger    1562          1
# 899782                 China  ...  Airbus A318/319/320/321    1018          1
# 899783                 China  ...  Airbus A318/319/320/321    1018          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                  70    7910    565.0   12740    910.0                    45
# 1                  70    7910    565.0   12740    910.0                    45
# 2                  70    7910    565.0   12740    910.0                    45
# 3                  70    7910    565.0   12740    910.0                    45
# 4                  70    7910    565.0   12740    910.0                    45
# ...               ...     ...      ...     ...      ...                   ...
# 899779             72  112464  27803.6  181008  44749.2                   240
# 899780             72  112464  27803.6  181008  44749.2                   240
# 899781             72  112464  27803.6  181008  44749.2                   240
# 899782            214  217852   4682.8  350532   7534.8                   210
# 899783            150  152700   6820.6  245700  10974.6                   210
#
#         Time series
# 0        2018-01-02
# 1        2018-01-22
# 2        2018-01-25
# 3        2018-01-28
# 4        2018-01-31
# ...             ...
# 899779   2018-11-08
# 899780   2018-11-17
# 899781   2018-12-10
# 899782   2018-11-01
# 899783   2018-11-27
#
# [3550579 rows x 25 columns]

# %%
folder = "./ASEAN_2019D"
movements_2019_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jan_Mar_JobId2082476.csv", sep = ",", header = 0)
movements_2019_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Apr_Jun_JobId2081531.csv", sep = ",", header = 0)
movements_2019_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jul_Sep_JobId2081532.csv", sep = ",", header = 0)
movements_2019_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Oct_Dec_JobId2082477.csv", sep = ",", header = 0)
movements_2019 = pd.concat([movements_2019_1, movements_2019_2, movements_2019_3, movements_2019_4])

# %%
movements_2019
# Out:
#        Dep Airport Code                        Dep Airport Name  \
# 0                   CEB                                    Cebu
# 1                   MNL   Manila Ninoy Aquino International Apt
# 2                   TMC                               Tambolaka
# 3                   SIN                    Singapore Changi Apt
# 4                   LUW                                   Luwuk
# ...                 ...                                     ...
# 920482              BKK  Bangkok Suvarnabhumi International Apt
# 920483              MNL   Manila Ninoy Aquino International Apt
# 920484              CEB                                    Cebu
# 920485              RGN                                  Yangon
# 920486              KCH                                 Kuching
#
#        Arr Airport Code                     Arr Airport Name ICAO AL IATA AL  \
# 0                   KUL   Kuala Lumpur International Airport     EZD      Z2
# 1                   BCD                              Bacolod     CEB      5J
# 2                   DPS                        Denpasar-Bali     WON      IW
# 3                   KUA                              Kuantan     TGW      TR
# 4                   PLW                                 Palu     WON      IW
# ...                 ...                                  ...     ...     ...
# 920482              HKT                               Phuket     TVJ      VZ
# 920483              ICN  Seoul Incheon International Airport     KAL      KE
# 920484              CRK                    Angeles/Mabalacat     EZD      Z2
# 920485              KUL   Kuala Lumpur International Airport     MAS      MH
# 920486              KUL   Kuala Lumpur International Airport     AXM      AK
#
#         Flight No Carrier Code              Carrier Name  \
# 0            7112           Z2  Philippines AirAsia Inc.
# 1             485           5J          Cebu Pacific Air
# 2            1833           IW                 Wings Air
# 3             470           TR                     Scoot
# 4            1147           IW                 Wings Air
# ...           ...          ...                       ...
# 920482        302           VZ          Thai Vietjet Air
# 920483        624           KE                Korean Air
# 920484        908           Z2  Philippines AirAsia Inc.
# 920485        743           MH         Malaysia Airlines
# 920486       5205           AK                   AirAsia
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                Philippines  ...  Airbus A318/319/320/321    1613          1
# 1                Philippines  ...  Airbus A318/319/320/321     290          1
# 2                  Indonesia  ...              ATR42/ATR72     281          1
# 3                  Singapore  ...  Airbus A318/319/320/321     175          1
# 4                  Indonesia  ...              ATR42/ATR72     198          1
# ...                      ...  ...                      ...     ...        ...
# 920482              Thailand  ...  Airbus A318/319/320/321     419          1
# 920483           Philippines  ...     Boeing 777 Passenger    1620          1
# 920484           Philippines  ...  Airbus A318/319/320/321     408          1
# 920485               Myanmar  ...     Boeing 737 Passenger    1048          1
# 920486              Malaysia  ...  Airbus A318/319/320/321     602          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                 180  290340   4516.4  467280   7268.8                   230
# 1                 180   52200   2726.0   84060   4389.8                    90
# 2                  70   19670   1405.0   31640   2260.0                    80
# 3                 144   25200    122.5   40608    197.4                    70
# 4                  70   13860    990.0   22330   1595.0                    70
# ...               ...     ...      ...     ...      ...                   ...
# 920482            180   75420   3938.6  121320   6335.6                    90
# 920483            338  547560  49086.0  881166  78992.1                   240
# 920484            180   73440   1142.4  118260   1839.6                    85
# 920485            160  167680  18654.4  269920  30028.6                   165
# 920486            180  108360   5658.8  174420   9108.6                   110
#
#         Time series
# 0        2019-01-12
# 1        2019-03-15
# 2        2019-03-26
# 3        2019-01-27
# 4        2019-01-20
# ...             ...
# 920482   2019-12-06
# 920483   2019-11-16
# 920484   2019-10-25
# 920485   2019-10-03
# 920486   2019-10-13
#
# [3564713 rows x 25 columns]

# %%
movements_all = pd.concat([movements_2018, movements_2019])
movements_all
# Out:
#        Dep Airport Code                        Dep Airport Name  \
# 0                   ABU                                 Atambua
# 1                   ABU                                 Atambua
# 2                   ABU                                 Atambua
# 3                   ABU                                 Atambua
# 4                   ABU                                 Atambua
# ...                 ...                                     ...
# 920482              BKK  Bangkok Suvarnabhumi International Apt
# 920483              MNL   Manila Ninoy Aquino International Apt
# 920484              CEB                                    Cebu
# 920485              RGN                                  Yangon
# 920486              KCH                                 Kuching
#
#        Arr Airport Code                     Arr Airport Name ICAO AL IATA AL  \
# 0                   KOE                               Kupang     WON      IW
# 1                   KOE                               Kupang     WON      IW
# 2                   KOE                               Kupang     WON      IW
# 3                   KOE                               Kupang     WON      IW
# 4                   KOE                               Kupang     WON      IW
# ...                 ...                                  ...     ...     ...
# 920482              HKT                               Phuket     TVJ      VZ
# 920483              ICN  Seoul Incheon International Airport     KAL      KE
# 920484              CRK                    Angeles/Mabalacat     EZD      Z2
# 920485              KUL   Kuala Lumpur International Airport     MAS      MH
# 920486              KUL   Kuala Lumpur International Airport     AXM      AK
#
#         Flight No Carrier Code              Carrier Name  \
# 0            1932           IW                 Wings Air
# 1            1932           IW                 Wings Air
# 2            1932           IW                 Wings Air
# 3            1932           IW                 Wings Air
# 4            1932           IW                 Wings Air
# ...           ...          ...                       ...
# 920482        302           VZ          Thai Vietjet Air
# 920483        624           KE                Korean Air
# 920484        908           Z2  Philippines AirAsia Inc.
# 920485        743           MH         Malaysia Airlines
# 920486       5205           AK                   AirAsia
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                  Indonesia  ...              ATR42/ATR72     113          1
# 1                  Indonesia  ...              ATR42/ATR72     113          1
# 2                  Indonesia  ...              ATR42/ATR72     113          1
# 3                  Indonesia  ...              ATR42/ATR72     113          1
# 4                  Indonesia  ...              ATR42/ATR72     113          1
# ...                      ...  ...                      ...     ...        ...
# 920482              Thailand  ...  Airbus A318/319/320/321     419          1
# 920483           Philippines  ...     Boeing 777 Passenger    1620          1
# 920484           Philippines  ...  Airbus A318/319/320/321     408          1
# 920485               Myanmar  ...     Boeing 737 Passenger    1048          1
# 920486              Malaysia  ...  Airbus A318/319/320/321     602          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                  70    7910    565.0   12740    910.0                    45
# 1                  70    7910    565.0   12740    910.0                    45
# 2                  70    7910    565.0   12740    910.0                    45
# 3                  70    7910    565.0   12740    910.0                    45
# 4                  70    7910    565.0   12740    910.0                    45
# ...               ...     ...      ...     ...      ...                   ...
# 920482            180   75420   3938.6  121320   6335.6                    90
# 920483            338  547560  49086.0  881166  78992.1                   240
# 920484            180   73440   1142.4  118260   1839.6                    85
# 920485            160  167680  18654.4  269920  30028.6                   165
# 920486            180  108360   5658.8  174420   9108.6                   110
#
#         Time series
# 0        2018-01-02
# 1        2018-01-22
# 2        2018-01-25
# 3        2018-01-28
# 4        2018-01-31
# ...             ...
# 920482   2019-12-06
# 920483   2019-11-16
# 920484   2019-10-25
# 920485   2019-10-03
# 920486   2019-10-13
#
# [7115292 rows x 25 columns]

# %%
movements_Dep_SIN = movements_all.loc[movements_all['Dep Airport Code'] == 'SIN']
movements_Arr_SIN = movements_all.loc[movements_all['Arr Airport Code'] == 'SIN']
movements_SIN = pd.concat([movements_Dep_SIN,movements_Arr_SIN])
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 678011              SIN                Singapore Changi Apt              ADD
# 678012              SIN                Singapore Changi Apt              ADD
# 678013              SIN                Singapore Changi Apt              ADD
# 678014              SIN                Singapore Changi Apt              ADD
# 678015              SIN                Singapore Changi Apt              ADD
# ...                 ...                                 ...              ...
# 920353              KBV                               Krabi              SIN
# 920395              HKT                              Phuket              SIN
# 920404              HKG         Hong Kong International Apt              SIN
# 920430              KUL  Kuala Lumpur International Airport              SIN
# 920449              KUL  Kuala Lumpur International Airport              SIN
#
#             Arr Airport Name ICAO AL IATA AL  Flight No Carrier Code  \
# 678011           Addis Ababa     ETH      ET        639           ET
# 678012           Addis Ababa     ETH      ET        639           ET
# 678013           Addis Ababa     ETH      ET        639           ET
# 678014           Addis Ababa     ETH      ET        639           ET
# 678015           Addis Ababa     ETH      ET        639           ET
# ...                      ...     ...     ...        ...          ...
# 920353  Singapore Changi Apt     AIQ      FD        330           FD
# 920395  Singapore Changi Apt     TGW      TR        653           TR
# 920404  Singapore Changi Apt     CPA      CX        715           CX
# 920430  Singapore Changi Apt     AXM      AK        707           AK
# 920449  Singapore Changi Apt     AXM      AK        721           AK
#
#                   Carrier Name  Dep IATA Country Name  ...  \
# 678011      Ethiopian Airlines              Singapore  ...
# 678012      Ethiopian Airlines              Singapore  ...
# 678013      Ethiopian Airlines              Singapore  ...
# 678014      Ethiopian Airlines              Singapore  ...
# 678015      Ethiopian Airlines              Singapore  ...
# ...                        ...                    ...  ...
# 920353            Thai AirAsia               Thailand  ...
# 920395                   Scoot               Thailand  ...
# 920404  Cathay Pacific Airways  Hong Kong (sar) China  ...
# 920430                 AirAsia               Malaysia  ...
# 920449                 AirAsia               Malaysia  ...
#
#           General Aircraft Name GCD (m)  Frequency  Seats (Total)     ASMs  \
# 678011               Boeing 787    4509          1            270  1217430
# 678012               Boeing 787    4509          1            270  1217430
# 678013               Boeing 787    4509          1            270  1217430
# 678014               Boeing 787    4509          1            270  1217430
# 678015               Boeing 787    4509          1            270  1217430
# ...                         ...     ...        ...            ...      ...
# 920353  Airbus A318/319/320/321     578          1            180   104040
# 920395  Airbus A318/319/320/321     608          1            180   109440
# 920404     Boeing 777 Passenger    1592          1            368   585856
# 920430  Airbus A318/319/320/321     184          1            180    33120
# 920449  Airbus A318/319/320/321     184          1            180    33120
#
#             ATMs     ASKs      ATKs  FlyingTime (Minutes)  Time series
# 678011  181261.8  1959390  291731.4                   530   2018-03-27
# 678012  181261.8  1959390  291731.4                   530   2018-03-30
# 678013  181261.8  1959390  291731.4                   560   2018-01-03
# 678014  181261.8  1959390  291731.4                   560   2018-01-06
# 678015  181261.8  1959390  291731.4                   560   2018-01-09
# ...          ...      ...       ...                   ...          ...
# 920353    5433.2   167400    8742.0                   105   2019-11-28
# 920395     425.6   176040     684.6                   115   2019-10-04
# 920404   32954.4   942816   53033.4                   230   2019-10-10
# 920430    1729.6    53280    2782.4                    60   2019-11-06
# 920449    1729.6    53280    2782.4                    75   2019-11-06
#
# [737967 rows x 25 columns]

# %%
# sort by date
movements_SIN.sort_values(by=['Time series'], inplace=True)
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 525256              MAA                             Chennai              SIN
# 802228              SYD          Sydney Kingsford Smith Apt              SIN
# 172063              CGK          Jakarta Soekarno-Hatta Apt              SIN
# 396677              IXM                             Madurai              SIN
# 734410              SIN                Singapore Changi Apt              SGN
# ...                 ...                                 ...              ...
# 352449              SIN                Singapore Changi Apt              DPS
# 547008              DPS                       Denpasar-Bali              SIN
# 593185              LAX       Los Angeles International Apt              SIN
# 676792              KUL  Kuala Lumpur International Airport              SIN
# 322111              MEL                   Melbourne Airport              SIN
#
#             Arr Airport Name ICAO AL IATA AL  Flight No Carrier Code  \
# 525256  Singapore Changi Apt     IGO      6E         51           6E
# 802228  Singapore Changi Apt     BAW      BA         16           BA
# 172063  Singapore Changi Apt     BTK      ID       7155           ID
# 396677  Singapore Changi Apt     AXB      IX        684           IX
# 734410      Ho Chi Minh City     VJC      VJ        814           VJ
# ...                      ...     ...     ...        ...          ...
# 352449         Denpasar-Bali     JSA      3K        243           3K
# 547008  Singapore Changi Apt     SIA      SQ        939           SQ
# 593185  Singapore Changi Apt     SIA      SQ         37           SQ
# 676792  Singapore Changi Apt     SLK      MI        341           MI
# 322111  Singapore Changi Apt     QFA      QF         35           QF
#
#               Carrier Name Dep IATA Country Name  ...  \
# 525256              IndiGo                 India  ...
# 802228     British Airways             Australia  ...
# 172063           Batik Air             Indonesia  ...
# 396677   Air India Express                 India  ...
# 734410             Vietjet             Singapore  ...
# ...                    ...                   ...  ...
# 352449        Jetstar Asia             Singapore  ...
# 547008  Singapore Airlines             Indonesia  ...
# 593185  Singapore Airlines                   USA  ...
# 676792             SilkAir              Malaysia  ...
# 322111      Qantas Airways             Australia  ...
#
#           General Aircraft Name GCD (m)  Frequency  Seats (Total)     ASMs  \
# 525256  Airbus A318/319/320/321    1816          1            180   326880
# 802228     Boeing 777 Passenger    3908          1            297  1160676
# 172063  Airbus A318/319/320/321     547          1            150    82050
# 396677     Boeing 737 Passenger    1872          1            186   348192
# 734410  Airbus A318/319/320/321     678          1            220   149160
# ...                         ...     ...        ...            ...      ...
# 352449  Airbus A318/319/320/321    1037          1            180   186660
# 547008              Airbus A330    1037          1            285   295545
# 593185              Airbus A350    8759          1            161  1410199
# 676792  Airbus A318/319/320/321     184          1            128    23552
# 322111    Airbus A380 Passenger    3746          1            484  1813064
#
#             ATMs     ASKs      ATKs  FlyingTime (Minutes)  Time series
# 525256   17070.4   526140   27476.2                   265   2018-01-01
# 802228   85976.0  1867833  138358.0                   480   2018-01-01
# 172063       0.0   132000       0.0                   105   2018-01-01
# 396677   33321.6   560418   53631.4                   270   2018-01-01
# 734410    3118.8   240020    5018.6                   125   2018-01-01
# ...          ...      ...       ...                   ...          ...
# 352449    9747.8   300420   15688.6                   170   2019-12-31
# 547008   17006.8   475665   27371.6                   170   2019-12-31
# 593185  175180.0  2269456  281920.0                  1070   2019-12-31
# 676792     423.2    37888     680.8                    65   2019-12-31
# 322111   57313.8  2918036   92243.7                   475   2019-12-31
#
# [737967 rows x 25 columns]

# %%
def dep_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0
    
def arr_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0

# %%
movements_SIN['Dep'] = 0
movements_SIN['Arr'] = 0

movements_SIN['Dep'] = movements_SIN['Dep Airport Code'].apply(dep_value)
movements_SIN['Arr'] = movements_SIN['Arr Airport Code'].apply(arr_value)

# %%
def dep_or_arr_time(dep, dep_time, arr_time):
    if dep == 1:
        return dep_time
    else:
        return arr_time

# %%
movements_SIN['Time_requested'] = movements_SIN[['Dep', 'Local Dep Time', 'Local Arr Time']].apply(lambda x: dep_or_arr_time(*x), axis=1)

# %%
movements_SIN = movements_SIN.drop(['Dep Airport Code', 'Arr Airport Code'], 1)

# %%
def f(s):
    return "".join(["0"]*(4-len(s))) + s

f('0')
# Out:
# '0000'

# %%
movements_SIN['Time_requested_format4'] = movements_SIN['Time_requested'].astype(str).apply(f)
movements_SIN['Time_requested_TS'] = movements_SIN['Time series'] + '-' + movements_SIN['Time_requested_format4']
movements_SIN['TS_datetime_format'] = pd.to_datetime(movements_SIN['Time_requested_TS'], format = '%Y-%m-%d-%H%M')

# %%
from pytz import all_timezones
import pytz

def utc(datetime):
    local = pytz.timezone("Asia/Singapore")
    local_dt = local.localize(datetime, is_dst=None)
    return local_dt.astimezone(pytz.utc)

# %%
movements_SIN['Time_requested_UTC'] = movements_SIN['TS_datetime_format'].apply(utc)

# %%
def day_of_week(s):
    return s.weekday()

# %%
movements_SIN['day_of_week'] = movements_SIN['Time_requested_UTC'].apply(day_of_week)
movements_SIN['Time_series_DT'] = pd.to_datetime(movements_SIN['Time series'], format = '%Y-%m-%d')

# %%
movements_SIN
# Out:
#                           Dep Airport Name      Arr Airport Name ICAO AL  \
# 525256                             Chennai  Singapore Changi Apt     IGO
# 802228          Sydney Kingsford Smith Apt  Singapore Changi Apt     BAW
# 172063          Jakarta Soekarno-Hatta Apt  Singapore Changi Apt     BTK
# 396677                             Madurai  Singapore Changi Apt     AXB
# 734410                Singapore Changi Apt      Ho Chi Minh City     VJC
# ...                                    ...                   ...     ...
# 352449                Singapore Changi Apt         Denpasar-Bali     JSA
# 547008                       Denpasar-Bali  Singapore Changi Apt     SIA
# 593185       Los Angeles International Apt  Singapore Changi Apt     SIA
# 676792  Kuala Lumpur International Airport  Singapore Changi Apt     SLK
# 322111                   Melbourne Airport  Singapore Changi Apt     QFA
#
#        IATA AL  Flight No Carrier Code        Carrier Name  \
# 525256      6E         51           6E              IndiGo
# 802228      BA         16           BA     British Airways
# 172063      ID       7155           ID           Batik Air
# 396677      IX        684           IX   Air India Express
# 734410      VJ        814           VJ             Vietjet
# ...        ...        ...          ...                 ...
# 352449      3K        243           3K        Jetstar Asia
# 547008      SQ        939           SQ  Singapore Airlines
# 593185      SQ         37           SQ  Singapore Airlines
# 676792      MI        341           MI             SilkAir
# 322111      QF         35           QF      Qantas Airways
#
#        Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 525256                 India             Singapore          International
# 802228             Australia             Singapore          International
# 172063             Indonesia             Singapore          International
# 396677                 India             Singapore          International
# 734410             Singapore              Viet Nam          International
# ...                      ...                   ...                    ...
# 352449             Singapore             Indonesia          International
# 547008             Indonesia             Singapore          International
# 593185                   USA             Singapore          International
# 676792              Malaysia             Singapore          International
# 322111             Australia             Singapore          International
#
#         ...  Time series  Dep Arr Time_requested  Time_requested_format4  \
# 525256  ...   2018-01-01    0   1           1240                    1240
# 802228  ...   2018-01-01    0   1           2130                    2130
# 172063  ...   2018-01-01    0   1           1545                    1545
# 396677  ...   2018-01-01    0   1            615                    0615
# 734410  ...   2018-01-01    1   0           1655                    1655
# ...     ...          ...  ...  ..            ...                     ...
# 352449  ...   2019-12-31    1   0            705                    0705
# 547008  ...   2019-12-31    0   1           1455                    1455
# 593185  ...   2019-12-31    0   1            815                    0815
# 676792  ...   2019-12-31    0   1           2250                    2250
# 322111  ...   2019-12-31    0   1           1705                    1705
#
#         Time_requested_TS  TS_datetime_format        Time_requested_UTC  \
# 525256    2018-01-01-1240 2018-01-01 12:40:00 2018-01-01 04:40:00+00:00
# 802228    2018-01-01-2130 2018-01-01 21:30:00 2018-01-01 13:30:00+00:00
# 172063    2018-01-01-1545 2018-01-01 15:45:00 2018-01-01 07:45:00+00:00
# 396677    2018-01-01-0615 2018-01-01 06:15:00 2017-12-31 22:15:00+00:00
# 734410    2018-01-01-1655 2018-01-01 16:55:00 2018-01-01 08:55:00+00:00
# ...                   ...                 ...                       ...
# 352449    2019-12-31-0705 2019-12-31 07:05:00 2019-12-30 23:05:00+00:00
# 547008    2019-12-31-1455 2019-12-31 14:55:00 2019-12-31 06:55:00+00:00
# 593185    2019-12-31-0815 2019-12-31 08:15:00 2019-12-31 00:15:00+00:00
# 676792    2019-12-31-2250 2019-12-31 22:50:00 2019-12-31 14:50:00+00:00
# 322111    2019-12-31-1705 2019-12-31 17:05:00 2019-12-31 09:05:00+00:00
#
#         day_of_week  Time_series_DT
# 525256            0      2018-01-01
# 802228            0      2018-01-01
# 172063            0      2018-01-01
# 396677            6      2018-01-01
# 734410            0      2018-01-01
# ...             ...             ...
# 352449            0      2019-12-31
# 547008            1      2019-12-31
# 593185            1      2019-12-31
# 676792            1      2019-12-31
# 322111            1      2019-12-31
#
# [737967 rows x 32 columns]

# %%
movements_SIN['Time_requested_UTC'].min()
# Out:
# Timestamp('2017-12-31 16:05:00+0000', tz='UTC')

# %%
movements_SIN['Time_requested_UTC'].max()
# Out:
# Timestamp('2019-12-31 15:55:00+0000', tz='UTC')

# %%
#movements_SIN['Time_series_DT'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#movements_SIN['Time_series_DT'].max()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
SIN_2018_s = movements_SIN[movements_SIN['Time_requested_UTC'] < pd.Timestamp('2018-10-28', tz='UTC')]
SIN_2018_s = SIN_2018_s[SIN_2018_s['Time_requested_UTC'] > pd.Timestamp('2018-3-31', tz='UTC')]

SIN_2018_w = movements_SIN[movements_SIN['Time_requested_UTC'] < pd.Timestamp('2019-3-31', tz='UTC')]
SIN_2018_w = SIN_2018_w[SIN_2018_w['Time_requested_UTC'] > pd.Timestamp('2018-10-27', tz='UTC')]

SIN_2019_s = movements_SIN[movements_SIN['Time_requested_UTC'] < pd.Timestamp('2019-10-27', tz='UTC')]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_requested_UTC'] > pd.Timestamp('2019-3-30', tz='UTC')]

#SIN_2019_w = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2020,3,29)]
#SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]

# %%
def requested_utc_hour(s):
    return s.hour

def requested_utc_minute(s):
    return s.minute

# %%
movements_SIN
# Out:
#                           Dep Airport Name      Arr Airport Name ICAO AL  \
# 525256                             Chennai  Singapore Changi Apt     IGO
# 802228          Sydney Kingsford Smith Apt  Singapore Changi Apt     BAW
# 172063          Jakarta Soekarno-Hatta Apt  Singapore Changi Apt     BTK
# 396677                             Madurai  Singapore Changi Apt     AXB
# 734410                Singapore Changi Apt      Ho Chi Minh City     VJC
# ...                                    ...                   ...     ...
# 352449                Singapore Changi Apt         Denpasar-Bali     JSA
# 547008                       Denpasar-Bali  Singapore Changi Apt     SIA
# 593185       Los Angeles International Apt  Singapore Changi Apt     SIA
# 676792  Kuala Lumpur International Airport  Singapore Changi Apt     SLK
# 322111                   Melbourne Airport  Singapore Changi Apt     QFA
#
#        IATA AL  Flight No Carrier Code        Carrier Name  \
# 525256      6E         51           6E              IndiGo
# 802228      BA         16           BA     British Airways
# 172063      ID       7155           ID           Batik Air
# 396677      IX        684           IX   Air India Express
# 734410      VJ        814           VJ             Vietjet
# ...        ...        ...          ...                 ...
# 352449      3K        243           3K        Jetstar Asia
# 547008      SQ        939           SQ  Singapore Airlines
# 593185      SQ         37           SQ  Singapore Airlines
# 676792      MI        341           MI             SilkAir
# 322111      QF         35           QF      Qantas Airways
#
#        Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 525256                 India             Singapore          International
# 802228             Australia             Singapore          International
# 172063             Indonesia             Singapore          International
# 396677                 India             Singapore          International
# 734410             Singapore              Viet Nam          International
# ...                      ...                   ...                    ...
# 352449             Singapore             Indonesia          International
# 547008             Indonesia             Singapore          International
# 593185                   USA             Singapore          International
# 676792              Malaysia             Singapore          International
# 322111             Australia             Singapore          International
#
#         ...  Time series  Dep Arr Time_requested  Time_requested_format4  \
# 525256  ...   2018-01-01    0   1           1240                    1240
# 802228  ...   2018-01-01    0   1           2130                    2130
# 172063  ...   2018-01-01    0   1           1545                    1545
# 396677  ...   2018-01-01    0   1            615                    0615
# 734410  ...   2018-01-01    1   0           1655                    1655
# ...     ...          ...  ...  ..            ...                     ...
# 352449  ...   2019-12-31    1   0            705                    0705
# 547008  ...   2019-12-31    0   1           1455                    1455
# 593185  ...   2019-12-31    0   1            815                    0815
# 676792  ...   2019-12-31    0   1           2250                    2250
# 322111  ...   2019-12-31    0   1           1705                    1705
#
#         Time_requested_TS  TS_datetime_format        Time_requested_UTC  \
# 525256    2018-01-01-1240 2018-01-01 12:40:00 2018-01-01 04:40:00+00:00
# 802228    2018-01-01-2130 2018-01-01 21:30:00 2018-01-01 13:30:00+00:00
# 172063    2018-01-01-1545 2018-01-01 15:45:00 2018-01-01 07:45:00+00:00
# 396677    2018-01-01-0615 2018-01-01 06:15:00 2017-12-31 22:15:00+00:00
# 734410    2018-01-01-1655 2018-01-01 16:55:00 2018-01-01 08:55:00+00:00
# ...                   ...                 ...                       ...
# 352449    2019-12-31-0705 2019-12-31 07:05:00 2019-12-30 23:05:00+00:00
# 547008    2019-12-31-1455 2019-12-31 14:55:00 2019-12-31 06:55:00+00:00
# 593185    2019-12-31-0815 2019-12-31 08:15:00 2019-12-31 00:15:00+00:00
# 676792    2019-12-31-2250 2019-12-31 22:50:00 2019-12-31 14:50:00+00:00
# 322111    2019-12-31-1705 2019-12-31 17:05:00 2019-12-31 09:05:00+00:00
#
#         day_of_week  Time_series_DT
# 525256            0      2018-01-01
# 802228            0      2018-01-01
# 172063            0      2018-01-01
# 396677            6      2018-01-01
# 734410            0      2018-01-01
# ...             ...             ...
# 352449            0      2019-12-31
# 547008            1      2019-12-31
# 593185            1      2019-12-31
# 676792            1      2019-12-31
# 322111            1      2019-12-31
#
# [737967 rows x 32 columns]

# %%
# For all flights to and from SIN in 2018 & 2019
SIN_2019 = movements_SIN
SIN_2019_df = SIN_2019.copy()

SIN_2019_df['requested_utc_hour'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_hour)
SIN_2019_df['requested_utc_minute'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_minute)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc_hour'].apply(str) + SIN_2019_df['requested_utc_minute'].apply(str)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc'].astype(int)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name      Arr Airport Name ICAO AL  \
# 525256                             Chennai  Singapore Changi Apt     IGO
# 802228          Sydney Kingsford Smith Apt  Singapore Changi Apt     BAW
# 172063          Jakarta Soekarno-Hatta Apt  Singapore Changi Apt     BTK
# 396677                             Madurai  Singapore Changi Apt     AXB
# 734410                Singapore Changi Apt      Ho Chi Minh City     VJC
# ...                                    ...                   ...     ...
# 352449                Singapore Changi Apt         Denpasar-Bali     JSA
# 547008                       Denpasar-Bali  Singapore Changi Apt     SIA
# 593185       Los Angeles International Apt  Singapore Changi Apt     SIA
# 676792  Kuala Lumpur International Airport  Singapore Changi Apt     SLK
# 322111                   Melbourne Airport  Singapore Changi Apt     QFA
#
#        IATA AL  Flight No Carrier Code        Carrier Name  \
# 525256      6E         51           6E              IndiGo
# 802228      BA         16           BA     British Airways
# 172063      ID       7155           ID           Batik Air
# 396677      IX        684           IX   Air India Express
# 734410      VJ        814           VJ             Vietjet
# ...        ...        ...          ...                 ...
# 352449      3K        243           3K        Jetstar Asia
# 547008      SQ        939           SQ  Singapore Airlines
# 593185      SQ         37           SQ  Singapore Airlines
# 676792      MI        341           MI             SilkAir
# 322111      QF         35           QF      Qantas Airways
#
#        Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 525256                 India             Singapore          International
# 802228             Australia             Singapore          International
# 172063             Indonesia             Singapore          International
# 396677                 India             Singapore          International
# 734410             Singapore              Viet Nam          International
# ...                      ...                   ...                    ...
# 352449             Singapore             Indonesia          International
# 547008             Indonesia             Singapore          International
# 593185                   USA             Singapore          International
# 676792              Malaysia             Singapore          International
# 322111             Australia             Singapore          International
#
#         ...  Time_requested  Time_requested_format4 Time_requested_TS  \
# 525256  ...            1240                    1240   2018-01-01-1240
# 802228  ...            2130                    2130   2018-01-01-2130
# 172063  ...            1545                    1545   2018-01-01-1545
# 396677  ...             615                    0615   2018-01-01-0615
# 734410  ...            1655                    1655   2018-01-01-1655
# ...     ...             ...                     ...               ...
# 352449  ...             705                    0705   2019-12-31-0705
# 547008  ...            1455                    1455   2019-12-31-1455
# 593185  ...             815                    0815   2019-12-31-0815
# 676792  ...            2250                    2250   2019-12-31-2250
# 322111  ...            1705                    1705   2019-12-31-1705
#
#         TS_datetime_format        Time_requested_UTC  day_of_week  \
# 525256 2018-01-01 12:40:00 2018-01-01 04:40:00+00:00            0
# 802228 2018-01-01 21:30:00 2018-01-01 13:30:00+00:00            0
# 172063 2018-01-01 15:45:00 2018-01-01 07:45:00+00:00            0
# 396677 2018-01-01 06:15:00 2017-12-31 22:15:00+00:00            6
# 734410 2018-01-01 16:55:00 2018-01-01 08:55:00+00:00            0
# ...                    ...                       ...          ...
# 352449 2019-12-31 07:05:00 2019-12-30 23:05:00+00:00            0
# 547008 2019-12-31 14:55:00 2019-12-31 06:55:00+00:00            1
# 593185 2019-12-31 08:15:00 2019-12-31 00:15:00+00:00            1
# 676792 2019-12-31 22:50:00 2019-12-31 14:50:00+00:00            1
# 322111 2019-12-31 17:05:00 2019-12-31 09:05:00+00:00            1
#
#         Time_series_DT  requested_utc_hour  requested_utc_minute  \
# 525256      2018-01-01                   4                    40
# 802228      2018-01-01                  13                    30
# 172063      2018-01-01                   7                    45
# 396677      2018-01-01                  22                    15
# 734410      2018-01-01                   8                    55
# ...                ...                 ...                   ...
# 352449      2019-12-31                  23                     5
# 547008      2019-12-31                   6                    55
# 593185      2019-12-31                   0                    15
# 676792      2019-12-31                  14                    50
# 322111      2019-12-31                   9                     5
#
#         requested_utc
# 525256            440
# 802228           1330
# 172063            745
# 396677           2215
# 734410            855
# ...               ...
# 352449            235
# 547008            655
# 593185             15
# 676792           1450
# 322111             95
#
# [737967 rows x 35 columns]

# %%
time_slots = []
h = 0
m = 0
while h < 2400:
    while m < 60:
        time_slots.append(h + m)
        m = m + 5
    m = 0
    h = h + 100
    #print(i)
time_slots.append(2400)
print(len(time_slots))
time_slots
# Out:
# 289
# [0,
#  5,
#  10,
#  15,
#  20,
#  25,
#  30,
#  35,
#  40,
#  45,
#  50,
#  55,
#  100,
#  105,
#  110,
#  115,
#  120,
#  125,
#  130,
#  135,
#  140,
#  145,
#  150,
#  155,
#  200,
#  205,
#  210,
#  215,
#  220,
#  225,
#  230,
#  235,
#  240,
#  245,
#  250,
#  255,
#  300,
#  305,
#  310,
#  315,
#  320,
#  325,
#  330,
#  335,
#  340,
#  345,
#  350,
#  355,
#  400,
#  405,
#  410,
#  415,
#  420,
#  425,
#  430,
#  435,
#  440,
#  445,
#  450,
#  455,
#  500,
#  505,
#  510,
#  515,
#  520,
#  525,
#  530,
#  535,
#  540,
#  545,
#  550,
#  555,
#  600,
#  605,
#  610,
#  615,
#  620,
#  625,
#  630,
#  635,
#  640,
#  645,
#  650,
#  655,
#  700,
#  705,
#  710,
#  715,
#  720,
#  725,
#  730,
#  735,
#  740,
#  745,
#  750,
#  755,
#  800,
#  805,
#  810,
#  815,
#  820,
#  825,
#  830,
#  835,
#  840,
#  845,
#  850,
#  855,
#  900,
#  905,
#  910,
#  915,
#  920,
#  925,
#  930,
#  935,
#  940,
#  945,
#  950,
#  955,
#  1000,
#  1005,
#  1010,
#  1015,
#  1020,
#  1025,
#  1030,
#  1035,
#  1040,
#  1045,
#  1050,
#  1055,
#  1100,
#  1105,
#  1110,
#  1115,
#  1120,
#  1125,
#  1130,
#  1135,
#  1140,
#  1145,
#  1150,
#  1155,
#  1200,
#  1205,
#  1210,
#  1215,
#  1220,
#  1225,
#  1230,
#  1235,
#  1240,
#  1245,
#  1250,
#  1255,
#  1300,
#  1305,
#  1310,
#  1315,
#  1320,
#  1325,
#  1330,
#  1335,
#  1340,
#  1345,
#  1350,
#  1355,
#  1400,
#  1405,
#  1410,
#  1415,
#  1420,
#  1425,
#  1430,
#  1435,
#  1440,
#  1445,
#  1450,
#  1455,
#  1500,
#  1505,
#  1510,
#  1515,
#  1520,
#  1525,
#  1530,
#  1535,
#  1540,
#  1545,
#  1550,
#  1555,
#  1600,
#  1605,
#  1610,
#  1615,
#  1620,
#  1625,
#  1630,
#  1635,
#  1640,
#  1645,
#  1650,
#  1655,
#  1700,
#  1705,
#  1710,
#  1715,
#  1720,
#  1725,
#  1730,
#  1735,
#  1740,
#  1745,
#  1750,
#  1755,
#  1800,
#  1805,
#  1810,
#  1815,
#  1820,
#  1825,
#  1830,
#  1835,
#  1840,
#  1845,
#  1850,
#  1855,
#  1900,
#  1905,
#  1910,
#  1915,
#  1920,
#  1925,
#  1930,
#  1935,
#  1940,
#  1945,
#  1950,
#  1955,
#  2000,
#  2005,
#  2010,
#  2015,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2100,
#  2105,
#  2110,
#  2115,
#  2120,
#  2125,
#  2130,
#  2135,
#  2140,
#  2145,
#  2150,
#  2155,
#  2200,
#  2205,
#  2210,
#  2215,
#  2220,
#  2225,
#  2230,
#  2235,
#  2240,
#  2245,
#  2250,
#  2255,
#  2300,
#  2305,
#  2310,
#  2315,
#  2320,
#  2325,
#  2330,
#  2335,
#  2340,
#  2345,
#  2350,
#  2355,
#  2400]

# %%
SIN_2019_df['Time slot'] = pd.cut(SIN_2019_df['requested_utc'], time_slots)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name      Arr Airport Name ICAO AL  \
# 525256                             Chennai  Singapore Changi Apt     IGO
# 802228          Sydney Kingsford Smith Apt  Singapore Changi Apt     BAW
# 172063          Jakarta Soekarno-Hatta Apt  Singapore Changi Apt     BTK
# 396677                             Madurai  Singapore Changi Apt     AXB
# 734410                Singapore Changi Apt      Ho Chi Minh City     VJC
# ...                                    ...                   ...     ...
# 352449                Singapore Changi Apt         Denpasar-Bali     JSA
# 547008                       Denpasar-Bali  Singapore Changi Apt     SIA
# 593185       Los Angeles International Apt  Singapore Changi Apt     SIA
# 676792  Kuala Lumpur International Airport  Singapore Changi Apt     SLK
# 322111                   Melbourne Airport  Singapore Changi Apt     QFA
#
#        IATA AL  Flight No Carrier Code        Carrier Name  \
# 525256      6E         51           6E              IndiGo
# 802228      BA         16           BA     British Airways
# 172063      ID       7155           ID           Batik Air
# 396677      IX        684           IX   Air India Express
# 734410      VJ        814           VJ             Vietjet
# ...        ...        ...          ...                 ...
# 352449      3K        243           3K        Jetstar Asia
# 547008      SQ        939           SQ  Singapore Airlines
# 593185      SQ         37           SQ  Singapore Airlines
# 676792      MI        341           MI             SilkAir
# 322111      QF         35           QF      Qantas Airways
#
#        Dep IATA Country Name Arr IATA Country Name International/Domestic  \
# 525256                 India             Singapore          International
# 802228             Australia             Singapore          International
# 172063             Indonesia             Singapore          International
# 396677                 India             Singapore          International
# 734410             Singapore              Viet Nam          International
# ...                      ...                   ...                    ...
# 352449             Singapore             Indonesia          International
# 547008             Indonesia             Singapore          International
# 593185                   USA             Singapore          International
# 676792              Malaysia             Singapore          International
# 322111             Australia             Singapore          International
#
#         ...  Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 525256  ...                    1240    2018-01-01-1240 2018-01-01 12:40:00
# 802228  ...                    2130    2018-01-01-2130 2018-01-01 21:30:00
# 172063  ...                    1545    2018-01-01-1545 2018-01-01 15:45:00
# 396677  ...                    0615    2018-01-01-0615 2018-01-01 06:15:00
# 734410  ...                    1655    2018-01-01-1655 2018-01-01 16:55:00
# ...     ...                     ...                ...                 ...
# 352449  ...                    0705    2019-12-31-0705 2019-12-31 07:05:00
# 547008  ...                    1455    2019-12-31-1455 2019-12-31 14:55:00
# 593185  ...                    0815    2019-12-31-0815 2019-12-31 08:15:00
# 676792  ...                    2250    2019-12-31-2250 2019-12-31 22:50:00
# 322111  ...                    1705    2019-12-31-1705 2019-12-31 17:05:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 525256 2018-01-01 04:40:00+00:00            0      2018-01-01
# 802228 2018-01-01 13:30:00+00:00            0      2018-01-01
# 172063 2018-01-01 07:45:00+00:00            0      2018-01-01
# 396677 2017-12-31 22:15:00+00:00            6      2018-01-01
# 734410 2018-01-01 08:55:00+00:00            0      2018-01-01
# ...                          ...          ...             ...
# 352449 2019-12-30 23:05:00+00:00            0      2019-12-31
# 547008 2019-12-31 06:55:00+00:00            1      2019-12-31
# 593185 2019-12-31 00:15:00+00:00            1      2019-12-31
# 676792 2019-12-31 14:50:00+00:00            1      2019-12-31
# 322111 2019-12-31 09:05:00+00:00            1      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 525256                   4                    40            440    (435, 440]
# 802228                  13                    30           1330  (1325, 1330]
# 172063                   7                    45            745    (740, 745]
# 396677                  22                    15           2215  (2210, 2215]
# 734410                   8                    55            855    (850, 855]
# ...                    ...                   ...            ...           ...
# 352449                  23                     5            235    (230, 235]
# 547008                   6                    55            655    (650, 655]
# 593185                   0                    15             15      (10, 15]
# 676792                  14                    50           1450  (1445, 1450]
# 322111                   9                     5             95     (55, 100]
#
# [737967 rows x 36 columns]

# %%
SIN_2019_s = SIN_2019_df[SIN_2019_df['Time_requested_UTC'] < pd.Timestamp('2019-10-27', tz='UTC')]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_requested_UTC'] > pd.Timestamp('2019-3-30', tz='UTC')]

# %%
#SIN_2019_s = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2019,10,27)]
#SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_series_DT'] > pd.Timestamp(2019,3,30)]

# %%
SIN_2019_s
# Out:
#                              Dep Airport Name  \
# 121081                          San Francisco
# 831968                      Angeles/Mabalacat
# 750280                                 Jeddah
# 650692                               Surabaya
# 6942    Bangkok Don Mueang International Arpt
# ...                                       ...
# 421953            Hong Kong International Apt
# 650086                   Singapore Changi Apt
# 693461                   Singapore Changi Apt
# 820141                   Singapore Changi Apt
# 208704    Seoul Incheon International Airport
#
#                              Arr Airport Name ICAO AL IATA AL  Flight No  \
# 121081                   Singapore Changi Apt     SIA      SQ         31
# 831968                   Singapore Changi Apt     CEB      5J        537
# 750280                   Singapore Changi Apt     SVA      SV        836
# 650692                   Singapore Changi Apt     GIA      GA        854
# 6942                     Singapore Changi Apt     AIQ      FD        359
# ...                                       ...     ...     ...        ...
# 421953                   Singapore Changi Apt     CPA      CX        659
# 650086                                  Perth     SIA      SQ        213
# 693461                       Istanbul Airport     SIA      SQ        392
# 820141  Manila Ninoy Aquino International Apt     CEB      5J        804
# 208704                   Singapore Changi Apt     AAR      OZ        753
#
#        Carrier Code            Carrier Name  Dep IATA Country Name  \
# 121081           SQ      Singapore Airlines                    USA
# 831968           5J        Cebu Pacific Air            Philippines
# 750280           SV  Saudi Arabian Airlines           Saudi Arabia
# 650692           GA        Garuda Indonesia              Indonesia
# 6942             FD            Thai AirAsia               Thailand
# ...             ...                     ...                    ...
# 421953           CX  Cathay Pacific Airways  Hong Kong (sar) China
# 650086           SQ      Singapore Airlines              Singapore
# 693461           SQ      Singapore Airlines              Singapore
# 820141           5J        Cebu Pacific Air              Singapore
# 208704           OZ         Asiana Airlines      Korea Republic of
#
#        Arr IATA Country Name International/Domestic  ...  \
# 121081             Singapore          International  ...
# 831968             Singapore          International  ...
# 750280             Singapore          International  ...
# 650692             Singapore          International  ...
# 6942               Singapore          International  ...
# ...                      ...                    ...  ...
# 421953             Singapore          International  ...
# 650086             Australia          International  ...
# 693461                Turkey          International  ...
# 820141           Philippines          International  ...
# 208704             Singapore          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 121081                    1905    2019-03-30-1905 2019-03-30 19:05:00
# 831968                    1610    2019-03-30-1610 2019-03-30 16:10:00
# 750280                    1530    2019-03-30-1530 2019-03-30 15:30:00
# 650692                    1050    2019-03-30-1050 2019-03-30 10:50:00
# 6942                      1030    2019-03-30-1030 2019-03-30 10:30:00
# ...                        ...                ...                 ...
# 421953                    0540    2019-10-27-0540 2019-10-27 05:40:00
# 650086                    0740    2019-10-27-0740 2019-10-27 07:40:00
# 693461                    0150    2019-10-27-0150 2019-10-27 01:50:00
# 820141                    0115    2019-10-27-0115 2019-10-27 01:15:00
# 208704                    0025    2019-10-27-0025 2019-10-27 00:25:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 121081 2019-03-30 11:05:00+00:00            5      2019-03-30
# 831968 2019-03-30 08:10:00+00:00            5      2019-03-30
# 750280 2019-03-30 07:30:00+00:00            5      2019-03-30
# 650692 2019-03-30 02:50:00+00:00            5      2019-03-30
# 6942   2019-03-30 02:30:00+00:00            5      2019-03-30
# ...                          ...          ...             ...
# 421953 2019-10-26 21:40:00+00:00            5      2019-10-27
# 650086 2019-10-26 23:40:00+00:00            5      2019-10-27
# 693461 2019-10-26 17:50:00+00:00            5      2019-10-27
# 820141 2019-10-26 17:15:00+00:00            5      2019-10-27
# 208704 2019-10-26 16:25:00+00:00            5      2019-10-27
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 121081                  11                     5            115    (110, 115]
# 831968                   8                    10            810    (805, 810]
# 750280                   7                    30            730    (725, 730]
# 650692                   2                    50            250    (245, 250]
# 6942                     2                    30            230    (225, 230]
# ...                    ...                   ...            ...           ...
# 421953                  21                    40           2140  (2135, 2140]
# 650086                  23                    40           2340  (2335, 2340]
# 693461                  17                    50           1750  (1745, 1750]
# 820141                  17                    15           1715  (1710, 1715]
# 208704                  16                    25           1625  (1620, 1625]
#
# [209971 rows x 36 columns]

# %%
SIN_2019_s['Time_series_DT'].unique()[0:7]
# Out:
# array(['2019-03-30T00:00:00.000000000', '2019-03-31T00:00:00.000000000',
#        '2019-04-01T00:00:00.000000000', '2019-04-02T00:00:00.000000000',
#        '2019-04-03T00:00:00.000000000', '2019-04-04T00:00:00.000000000',
#        '2019-04-05T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# start here
first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
date = first_week[0]
SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
SIN_2019_s_d1
# Out:
#                              Dep Airport Name  \
# 121081                          San Francisco
# 831968                      Angeles/Mabalacat
# 750280                                 Jeddah
# 650692                               Surabaya
# 6942    Bangkok Don Mueang International Arpt
# ...                                       ...
# 449524                                 Cairns
# 838131                   Singapore Changi Apt
# 482902                              Kaohsiung
# 242153                   Singapore Changi Apt
# 545167                    London Heathrow Apt
#
#                         Arr Airport Name ICAO AL IATA AL  Flight No  \
# 121081              Singapore Changi Apt     SIA      SQ         31
# 831968              Singapore Changi Apt     CEB      5J        537
# 750280              Singapore Changi Apt     SVA      SV        836
# 650692              Singapore Changi Apt     GIA      GA        854
# 6942                Singapore Changi Apt     AIQ      FD        359
# ...                                  ...     ...     ...        ...
# 449524              Singapore Changi Apt     SLK      MI        812
# 838131  Hyderabad Rajiv Gandhi Intl Arpt     SLK      MI        472
# 482902              Singapore Changi Apt     CAL      CI        757
# 242153                          Hangzhou     TGW      TR        188
# 545167              Singapore Changi Apt     QFA      QF          2
#
#        Carrier Code            Carrier Name Dep IATA Country Name  \
# 121081           SQ      Singapore Airlines                   USA
# 831968           5J        Cebu Pacific Air           Philippines
# 750280           SV  Saudi Arabian Airlines          Saudi Arabia
# 650692           GA        Garuda Indonesia             Indonesia
# 6942             FD            Thai AirAsia              Thailand
# ...             ...                     ...                   ...
# 449524           MI                 SilkAir             Australia
# 838131           MI                 SilkAir             Singapore
# 482902           CI          China Airlines        Chinese Taipei
# 242153           TR                   Scoot             Singapore
# 545167           QF          Qantas Airways        United Kingdom
#
#        Arr IATA Country Name International/Domestic  ...  \
# 121081             Singapore          International  ...
# 831968             Singapore          International  ...
# 750280             Singapore          International  ...
# 650692             Singapore          International  ...
# 6942               Singapore          International  ...
# ...                      ...                    ...  ...
# 449524             Singapore          International  ...
# 838131                 India          International  ...
# 482902             Singapore          International  ...
# 242153                 China          International  ...
# 545167             Singapore          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 121081                    1905    2019-03-30-1905 2019-03-30 19:05:00
# 831968                    1610    2019-03-30-1610 2019-03-30 16:10:00
# 750280                    1530    2019-03-30-1530 2019-03-30 15:30:00
# 650692                    1050    2019-03-30-1050 2019-03-30 10:50:00
# 6942                      1030    2019-03-30-1030 2019-03-30 10:30:00
# ...                        ...                ...                 ...
# 449524                    1535    2019-03-30-1535 2019-03-30 15:35:00
# 838131                    2150    2019-03-30-2150 2019-03-30 21:50:00
# 482902                    1735    2019-03-30-1735 2019-03-30 17:35:00
# 242153                    1645    2019-03-30-1645 2019-03-30 16:45:00
# 545167                    1745    2019-03-30-1745 2019-03-30 17:45:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 121081 2019-03-30 11:05:00+00:00            5      2019-03-30
# 831968 2019-03-30 08:10:00+00:00            5      2019-03-30
# 750280 2019-03-30 07:30:00+00:00            5      2019-03-30
# 650692 2019-03-30 02:50:00+00:00            5      2019-03-30
# 6942   2019-03-30 02:30:00+00:00            5      2019-03-30
# ...                          ...          ...             ...
# 449524 2019-03-30 07:35:00+00:00            5      2019-03-30
# 838131 2019-03-30 13:50:00+00:00            5      2019-03-30
# 482902 2019-03-30 09:35:00+00:00            5      2019-03-30
# 242153 2019-03-30 08:45:00+00:00            5      2019-03-30
# 545167 2019-03-30 09:45:00+00:00            5      2019-03-30
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 121081                  11                     5            115    (110, 115]
# 831968                   8                    10            810    (805, 810]
# 750280                   7                    30            730    (725, 730]
# 650692                   2                    50            250    (245, 250]
# 6942                     2                    30            230    (225, 230]
# ...                    ...                   ...            ...           ...
# 449524                   7                    35            735    (730, 735]
# 838131                  13                    50           1350  (1345, 1350]
# 482902                   9                    35            935    (930, 935]
# 242153                   8                    45            845    (840, 845]
# 545167                   9                    45            945    (940, 945]
#
# [776 rows x 36 columns]

# %%
timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
timeslot_movements = timeslot_movements.to_frame()
timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
timeslot_movements = timeslot_movements.reset_index()
timeslot_movements
# Out:
#             index  Movements
# 0       (55, 100]         48
# 1      (125, 130]         14
# 2      (115, 120]         14
# 3        (50, 55]         11
# 4        (25, 30]         11
# ..            ...        ...
# 283  (1735, 1740]          0
# 284  (1730, 1735]          0
# 285  (1725, 1730]          0
# 286  (1720, 1725]          0
# 287  (1155, 1200]          0
#
# [288 rows x 2 columns]

# %%
# convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
start = 0
end = 5
interval = pd.Interval(left=start, right=end, closed='right')

# eg. (0, 5] -> slot 1
interval_slot_dict = {} 

for slot in range(1, 289, 1):
    interval_slot_dict[interval] = slot
    if (end % 100 == 55):
        start = interval.left + 5
        end = interval.right + 45
    elif (start % 100 == 55):
        start = interval.left + 45
        end = interval.right + 5
    else:
        start = interval.left + 5
        end = interval.right + 5
    
    interval = pd.Interval(left=start, right=end, closed='right')

# %%
timeslot_movements['Slot'] = ''
for index, row in timeslot_movements.iterrows():
    row['Slot'] = interval_slot_dict.get(row['index'])
    
timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)

# %%
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       (55, 100]         48    12
# 1      (125, 130]         14    18
# 2      (115, 120]         14    16
# 3        (50, 55]         11    11
# 4        (25, 30]         11     6
# ..            ...        ...   ...
# 283  (1735, 1740]          0   212
# 284  (1730, 1735]          0   211
# 285  (1725, 1730]          0   210
# 286  (1720, 1725]          0   209
# 287  (1155, 1200]          0   144
#
# [288 rows x 3 columns]

# %%
x = timeslot_movements['Slot']
y = timeslot_movements['Movements'] 

plt.figure(figsize=(10,6))
plt.bar(x, y, width=3.0) 
 
plt.xlabel('Timeslot') 
plt.ylabel('No. of movements') 

plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

plt.show()

# %%
def timeslot_to_index():
    # convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
    start = 0
    end = 5
    interval = pd.Interval(left=start, right=end, closed='right')

    # eg. (0, 5] -> slot 1
    interval_slot_dict = {} 

    for slot in range(1, 289, 1):
        interval_slot_dict[interval] = slot
        if (end % 100 == 55):
            start = interval.left + 5
            end = interval.right + 45
        elif (start % 100 == 55):
            start = interval.left + 45
            end = interval.right + 5
        else:
            start = interval.left + 5
            end = interval.right + 5
    
        interval = pd.Interval(left=start, right=end, closed='right')
        
    return interval_slot_dict

# %%
def get_first_week_dates(SIN_2019_s):
    first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
    return first_week # array with 1st week's dates

# %%
def get_first_week_df(SIN_2019_s, date): # date = first_week[0]
    # date = first_week[0]
    SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
    return SIN_2019_s_d1 # df of a particualr day of the 1st week

# %%
def mov_per_slot(SIN_2019_s_d1, interval_slot_dict):
    timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
    timeslot_movements = timeslot_movements.to_frame()
    timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
    timeslot_movements = timeslot_movements.reset_index()
    
    timeslot_movements['Slot'] = ''
    for index, row in timeslot_movements.iterrows():
        row['Slot'] = interval_slot_dict.get(row['index'])
    
    timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)
    return timeslot_movements

# %%
def get_date_plot(timeslot_movements, date):
    x = timeslot_movements['Slot']
    y = timeslot_movements['Movements'] 

    plt.figure(figsize=(10,6))
    plt.bar(x, y, width=3.0) 
 
    plt.xlabel('Timeslot') 
    plt.ylabel('No. of movements') 

    plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

    plt.show()

# %%
# 1st day - 2019 summer
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[0]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       (55, 100]         48    12
# 1      (125, 130]         14    18
# 2      (115, 120]         14    16
# 3        (50, 55]         11    11
# 4        (25, 30]         11     6
# ..            ...        ...   ...
# 283  (1735, 1740]          0   212
# 284  (1730, 1735]          0   211
# 285  (1725, 1730]          0   210
# 286  (1720, 1725]          0   209
# 287  (1155, 1200]          0   144
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[1]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1        (25, 30]         15    6.0
# 2         (5, 10]         11    2.0
# 3    (1110, 1115]         11  135.0
# 4      (115, 120]         10   16.0
# ..            ...        ...    ...
# 284  (2045, 2050]          0  250.0
# 285    (300, 305]          0   37.0
# 286    (255, 300]          0   36.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[2]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1         (5, 10]         12    2.0
# 2      (140, 145]         12   21.0
# 3        (10, 15]         12    3.0
# 4      (225, 230]         12   30.0
# ..            ...        ...    ...
# 284    (655, 700]          0   84.0
# 285    (700, 705]          0   85.0
# 286  (1805, 1810]          0  218.0
# 287  (1800, 1805]          0  217.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[3]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         49   12.0
# 1         (5, 10]         11    2.0
# 2        (25, 30]         11    6.0
# 3        (15, 20]         10    4.0
# 4      (155, 200]         10   24.0
# ..            ...        ...    ...
# 284  (1805, 1810]          0  218.0
# 285  (1800, 1805]          0  217.0
# 286    (555, 600]          0   72.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[4]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         47   12.0
# 1        (25, 30]         12    6.0
# 2      (225, 230]         11   30.0
# 3         (5, 10]         11    2.0
# 4      (140, 145]         11   21.0
# ..            ...        ...    ...
# 284  (1800, 1805]          0  217.0
# 285  (1755, 1800]          0  216.0
# 286    (555, 600]          0   72.0
# 287    (600, 605]          0   73.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[5]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1         (5, 10]         13    2.0
# 2        (25, 30]         12    6.0
# 3        (10, 15]         11    3.0
# 4        (15, 20]         11    4.0
# ..            ...        ...    ...
# 284    (455, 500]          0   60.0
# 285    (500, 505]          0   61.0
# 286  (1905, 1910]          0  230.0
# 287  (1900, 1905]          0  229.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[6]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         48   12.0
# 1        (25, 30]         15    6.0
# 2      (225, 230]         12   30.0
# 3      (140, 145]         11   21.0
# 4         (5, 10]         11    2.0
# ..            ...        ...    ...
# 284    (600, 605]          0   73.0
# 285  (1835, 1840]          0  224.0
# 286    (655, 700]          0   84.0
# 287    (700, 705]          0   85.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
#SIN_2019_w = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2020,3,29)]
#SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]
#SIN_2019_w

# %%
SIN_2018_w = SIN_2019_df[SIN_2019_df['Time_requested_UTC'] < pd.Timestamp('2019-3-31', tz='UTC')]
SIN_2018_w = SIN_2018_w[SIN_2018_w['Time_requested_UTC'] > pd.Timestamp('2018-10-27', tz='UTC')]
SIN_2018_w
# Out:
#                               Dep Airport Name  \
# 69117   Bangkok Suvarnabhumi International Apt
# 734312                    Singapore Changi Apt
# 732582                    Singapore Changi Apt
# 84668                                   Mumbai
# 509986      Kuala Lumpur International Airport
# ...                                        ...
# 249430                    Singapore Changi Apt
# 574674  Bangkok Suvarnabhumi International Apt
# 469236                    Singapore Changi Apt
# 231657                      Thiruvananthapuram
# 349686                    Singapore Changi Apt
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 69117                      Singapore Changi Apt     CPA      CX        717
# 734312      Seoul Incheon International Airport     AAR      OZ        752
# 732582                        Bandaranaike Intl     SLK      MI        428
# 84668                      Singapore Changi Apt     JAI      9W         10
# 509986                     Singapore Changi Apt     MAS      MH        613
# ...                                         ...     ...     ...        ...
# 249430                           Zurich Airport     SIA      SQ        346
# 574674                     Singapore Changi Apt     JSA      3K        514
# 469236                                   Yangon     SIA      SQ        998
# 231657                     Singapore Changi Apt     SLK      MI        491
# 349686  Taipei Taiwan Taoyuan International Apt     TGW      TR        892
#
#        Carrier Code             Carrier Name Dep IATA Country Name  \
# 69117            CX   Cathay Pacific Airways              Thailand
# 734312           OZ          Asiana Airlines             Singapore
# 732582           MI                  SilkAir             Singapore
# 84668            9W  Jet Airways (india) Ltd                 India
# 509986           MH        Malaysia Airlines              Malaysia
# ...             ...                      ...                   ...
# 249430           SQ       Singapore Airlines             Singapore
# 574674           3K             Jetstar Asia              Thailand
# 469236           SQ       Singapore Airlines             Singapore
# 231657           MI                  SilkAir                 India
# 349686           TR                    Scoot             Singapore
#
#        Arr IATA Country Name International/Domestic  ...  \
# 69117              Singapore          International  ...
# 734312     Korea Republic of          International  ...
# 732582             Sri Lanka          International  ...
# 84668              Singapore          International  ...
# 509986             Singapore          International  ...
# ...                      ...                    ...  ...
# 249430           Switzerland          International  ...
# 574674             Singapore          International  ...
# 469236               Myanmar          International  ...
# 231657             Singapore          International  ...
# 349686        Chinese Taipei          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 69117                     1525    2018-10-27-1525 2018-10-27 15:25:00
# 734312                    2240    2018-10-27-2240 2018-10-27 22:40:00
# 732582                    0850    2018-10-27-0850 2018-10-27 08:50:00
# 84668                     1800    2018-10-27-1800 2018-10-27 18:00:00
# 509986                    1825    2018-10-27-1825 2018-10-27 18:25:00
# ...                        ...                ...                 ...
# 249430                    0125    2019-03-31-0125 2019-03-31 01:25:00
# 574674                    0045    2019-03-31-0045 2019-03-31 00:45:00
# 469236                    0755    2019-03-31-0755 2019-03-31 07:55:00
# 231657                    0535    2019-03-31-0535 2019-03-31 05:35:00
# 349686                    0610    2019-03-31-0610 2019-03-31 06:10:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 69117  2018-10-27 07:25:00+00:00            5      2018-10-27
# 734312 2018-10-27 14:40:00+00:00            5      2018-10-27
# 732582 2018-10-27 00:50:00+00:00            5      2018-10-27
# 84668  2018-10-27 10:00:00+00:00            5      2018-10-27
# 509986 2018-10-27 10:25:00+00:00            5      2018-10-27
# ...                          ...          ...             ...
# 249430 2019-03-30 17:25:00+00:00            5      2019-03-31
# 574674 2019-03-30 16:45:00+00:00            5      2019-03-31
# 469236 2019-03-30 23:55:00+00:00            5      2019-03-31
# 231657 2019-03-30 21:35:00+00:00            5      2019-03-31
# 349686 2019-03-30 22:10:00+00:00            5      2019-03-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 69117                    7                    25            725    (720, 725]
# 734312                  14                    40           1440  (1435, 1440]
# 732582                   0                    50             50      (45, 50]
# 84668                   10                     0            100     (55, 100]
# 509986                  10                    25           1025  (1020, 1025]
# ...                    ...                   ...            ...           ...
# 249430                  17                    25           1725  (1720, 1725]
# 574674                  16                    45           1645  (1640, 1645]
# 469236                  23                    55           2355  (2350, 2355]
# 231657                  21                    35           2135  (2130, 2135]
# 349686                  22                    10           2210  (2205, 2210]
#
# [160077 rows x 36 columns]

# %%
# 1st day - 2018 winter
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[0]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       (55, 100]         40    12
# 1         (5, 10]         13     2
# 2        (25, 30]         13     6
# 3        (45, 50]         12    10
# 4      (105, 110]         11    14
# ..            ...        ...   ...
# 283  (1735, 1740]          0   212
# 284  (1730, 1735]          0   211
# 285  (1725, 1730]          0   210
# 286  (1720, 1725]          0   209
# 287  (1155, 1200]          0   144
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[1]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         49   12.0
# 1      (125, 130]         16   18.0
# 2      (115, 120]         16   16.0
# 3      (105, 110]         14   14.0
# 4      (225, 230]         12   30.0
# ..            ...        ...    ...
# 284    (800, 805]          0   97.0
# 285  (2045, 2050]          0  250.0
# 286    (755, 800]          0   96.0
# 287  (1845, 1850]          0  226.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[2]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         52   12.0
# 1      (115, 120]         17   16.0
# 2      (125, 130]         14   18.0
# 3      (155, 200]         13   24.0
# 4    (1550, 1555]         12  191.0
# ..            ...        ...    ...
# 284  (1845, 1850]          0  226.0
# 285    (800, 805]          0   97.0
# 286  (2030, 2035]          0  247.0
# 287    (455, 500]          0   60.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[3]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         46   12.0
# 1      (155, 200]         16   24.0
# 2      (115, 120]         14   16.0
# 3      (125, 130]         13   18.0
# 4         (5, 10]         12    2.0
# ..            ...        ...    ...
# 284    (555, 600]          0   72.0
# 285    (600, 605]          0   73.0
# 286  (1745, 1750]          0  214.0
# 287  (1735, 1740]          0  212.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[4]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         46   12.0
# 1      (115, 120]         17   16.0
# 2      (125, 130]         16   18.0
# 3    (1550, 1555]         13  191.0
# 4      (105, 110]         13   14.0
# ..            ...        ...    ...
# 284  (1830, 1835]          0  223.0
# 285    (655, 700]          0   84.0
# 286    (700, 705]          0   85.0
# 287  (1805, 1810]          0  218.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[5]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         51   12.0
# 1         (5, 10]         15    2.0
# 2      (125, 130]         15   18.0
# 3      (115, 120]         15   16.0
# 4        (25, 30]         14    6.0
# ..            ...        ...    ...
# 284  (1955, 2000]          0  240.0
# 285  (1950, 1955]          0  239.0
# 286  (1945, 1950]          0  238.0
# 287  (1940, 1945]          0  237.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[6]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements   Slot
# 0       (55, 100]         50   12.0
# 1      (115, 120]         18   16.0
# 2      (125, 130]         15   18.0
# 3      (215, 220]         13   28.0
# 4      (105, 110]         13   14.0
# ..            ...        ...    ...
# 284    (600, 605]          0   73.0
# 285  (1835, 1840]          0  224.0
# 286  (1830, 1835]          0  223.0
# 287    (655, 700]          0   84.0
# 288  (1200, 1205]          0  145.0
#
# [289 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)
