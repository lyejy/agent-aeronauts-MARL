# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder = "./ASEAN_2018D"
movements_2018_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jan_Mar_JobId2081527.csv", sep = ",", header = 0)
movements_2018_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Apr_Jun_JobId2081525.csv", sep = ",", header = 0)
movements_2018_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Jul_Sep_JobId2081528.csv", sep = ",", header = 0)
movements_2018_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2018D_Oct_Dec_JobId2081529.csv", sep = ",", header = 0)
movements_2018 = pd.concat([movements_2018_1, movements_2018_2, movements_2018_3, movements_2018_4])

# %%
folder = "./ASEAN_2019D"
movements_2019_1 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jan_Mar_JobId2082476.csv", sep = ",", header = 0)
movements_2019_2 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Apr_Jun_JobId2081531.csv", sep = ",", header = 0)
movements_2019_3 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Jul_Sep_JobId2081532.csv", sep = ",", header = 0)
movements_2019_4 = pd.read_csv(filepath_or_buffer = folder + "/ASEAN_2019D_Oct_Dec_JobId2082477.csv", sep = ",", header = 0)
movements_2019 = pd.concat([movements_2019_1, movements_2019_2, movements_2019_3, movements_2019_4])

# %%
movements_all = pd.concat([movements_2018, movements_2019])
movements_all
# Out:
#        Dep Airport Code                        Dep Airport Name  \
# 0                   ABU                                 Atambua
# 1                   ABU                                 Atambua
# 2                   ABU                                 Atambua
# 3                   ABU                                 Atambua
# 4                   ABU                                 Atambua
# ...                 ...                                     ...
# 920482              BKK  Bangkok Suvarnabhumi International Apt
# 920483              MNL   Manila Ninoy Aquino International Apt
# 920484              CEB                                    Cebu
# 920485              RGN                                  Yangon
# 920486              KCH                                 Kuching
#
#        Arr Airport Code                     Arr Airport Name ICAO AL IATA AL  \
# 0                   KOE                               Kupang     WON      IW
# 1                   KOE                               Kupang     WON      IW
# 2                   KOE                               Kupang     WON      IW
# 3                   KOE                               Kupang     WON      IW
# 4                   KOE                               Kupang     WON      IW
# ...                 ...                                  ...     ...     ...
# 920482              HKT                               Phuket     TVJ      VZ
# 920483              ICN  Seoul Incheon International Airport     KAL      KE
# 920484              CRK                    Angeles/Mabalacat     EZD      Z2
# 920485              KUL   Kuala Lumpur International Airport     MAS      MH
# 920486              KUL   Kuala Lumpur International Airport     AXM      AK
#
#         Flight No Carrier Code              Carrier Name  \
# 0            1932           IW                 Wings Air
# 1            1932           IW                 Wings Air
# 2            1932           IW                 Wings Air
# 3            1932           IW                 Wings Air
# 4            1932           IW                 Wings Air
# ...           ...          ...                       ...
# 920482        302           VZ          Thai Vietjet Air
# 920483        624           KE                Korean Air
# 920484        908           Z2  Philippines AirAsia Inc.
# 920485        743           MH         Malaysia Airlines
# 920486       5205           AK                   AirAsia
#
#        Dep IATA Country Name  ...    General Aircraft Name GCD (m)  Frequency  \
# 0                  Indonesia  ...              ATR42/ATR72     113          1
# 1                  Indonesia  ...              ATR42/ATR72     113          1
# 2                  Indonesia  ...              ATR42/ATR72     113          1
# 3                  Indonesia  ...              ATR42/ATR72     113          1
# 4                  Indonesia  ...              ATR42/ATR72     113          1
# ...                      ...  ...                      ...     ...        ...
# 920482              Thailand  ...  Airbus A318/319/320/321     419          1
# 920483           Philippines  ...     Boeing 777 Passenger    1620          1
# 920484           Philippines  ...  Airbus A318/319/320/321     408          1
# 920485               Myanmar  ...     Boeing 737 Passenger    1048          1
# 920486              Malaysia  ...  Airbus A318/319/320/321     602          1
#
#         Seats (Total)    ASMs     ATMs    ASKs     ATKs  FlyingTime (Minutes)  \
# 0                  70    7910    565.0   12740    910.0                    45
# 1                  70    7910    565.0   12740    910.0                    45
# 2                  70    7910    565.0   12740    910.0                    45
# 3                  70    7910    565.0   12740    910.0                    45
# 4                  70    7910    565.0   12740    910.0                    45
# ...               ...     ...      ...     ...      ...                   ...
# 920482            180   75420   3938.6  121320   6335.6                    90
# 920483            338  547560  49086.0  881166  78992.1                   240
# 920484            180   73440   1142.4  118260   1839.6                    85
# 920485            160  167680  18654.4  269920  30028.6                   165
# 920486            180  108360   5658.8  174420   9108.6                   110
#
#         Time series
# 0        2018-01-02
# 1        2018-01-22
# 2        2018-01-25
# 3        2018-01-28
# 4        2018-01-31
# ...             ...
# 920482   2019-12-06
# 920483   2019-11-16
# 920484   2019-10-25
# 920485   2019-10-03
# 920486   2019-10-13
#
# [7115292 rows x 25 columns]

# %%
movements_Dep_SIN = movements_all.loc[movements_all['Dep Airport Code'] == 'SIN']
movements_Arr_SIN = movements_all.loc[movements_all['Arr Airport Code'] == 'SIN']
movements_SIN = pd.concat([movements_Dep_SIN,movements_Arr_SIN])
movements_SIN
# Out:
#        Dep Airport Code                    Dep Airport Name Arr Airport Code  \
# 678011              SIN                Singapore Changi Apt              ADD
# 678012              SIN                Singapore Changi Apt              ADD
# 678013              SIN                Singapore Changi Apt              ADD
# 678014              SIN                Singapore Changi Apt              ADD
# 678015              SIN                Singapore Changi Apt              ADD
# ...                 ...                                 ...              ...
# 920353              KBV                               Krabi              SIN
# 920395              HKT                              Phuket              SIN
# 920404              HKG         Hong Kong International Apt              SIN
# 920430              KUL  Kuala Lumpur International Airport              SIN
# 920449              KUL  Kuala Lumpur International Airport              SIN
#
#             Arr Airport Name ICAO AL IATA AL  Flight No Carrier Code  \
# 678011           Addis Ababa     ETH      ET        639           ET
# 678012           Addis Ababa     ETH      ET        639           ET
# 678013           Addis Ababa     ETH      ET        639           ET
# 678014           Addis Ababa     ETH      ET        639           ET
# 678015           Addis Ababa     ETH      ET        639           ET
# ...                      ...     ...     ...        ...          ...
# 920353  Singapore Changi Apt     AIQ      FD        330           FD
# 920395  Singapore Changi Apt     TGW      TR        653           TR
# 920404  Singapore Changi Apt     CPA      CX        715           CX
# 920430  Singapore Changi Apt     AXM      AK        707           AK
# 920449  Singapore Changi Apt     AXM      AK        721           AK
#
#                   Carrier Name  Dep IATA Country Name  ...  \
# 678011      Ethiopian Airlines              Singapore  ...
# 678012      Ethiopian Airlines              Singapore  ...
# 678013      Ethiopian Airlines              Singapore  ...
# 678014      Ethiopian Airlines              Singapore  ...
# 678015      Ethiopian Airlines              Singapore  ...
# ...                        ...                    ...  ...
# 920353            Thai AirAsia               Thailand  ...
# 920395                   Scoot               Thailand  ...
# 920404  Cathay Pacific Airways  Hong Kong (sar) China  ...
# 920430                 AirAsia               Malaysia  ...
# 920449                 AirAsia               Malaysia  ...
#
#           General Aircraft Name GCD (m)  Frequency  Seats (Total)     ASMs  \
# 678011               Boeing 787    4509          1            270  1217430
# 678012               Boeing 787    4509          1            270  1217430
# 678013               Boeing 787    4509          1            270  1217430
# 678014               Boeing 787    4509          1            270  1217430
# 678015               Boeing 787    4509          1            270  1217430
# ...                         ...     ...        ...            ...      ...
# 920353  Airbus A318/319/320/321     578          1            180   104040
# 920395  Airbus A318/319/320/321     608          1            180   109440
# 920404     Boeing 777 Passenger    1592          1            368   585856
# 920430  Airbus A318/319/320/321     184          1            180    33120
# 920449  Airbus A318/319/320/321     184          1            180    33120
#
#             ATMs     ASKs      ATKs  FlyingTime (Minutes)  Time series
# 678011  181261.8  1959390  291731.4                   530   2018-03-27
# 678012  181261.8  1959390  291731.4                   530   2018-03-30
# 678013  181261.8  1959390  291731.4                   560   2018-01-03
# 678014  181261.8  1959390  291731.4                   560   2018-01-06
# 678015  181261.8  1959390  291731.4                   560   2018-01-09
# ...          ...      ...       ...                   ...          ...
# 920353    5433.2   167400    8742.0                   105   2019-11-28
# 920395     425.6   176040     684.6                   115   2019-10-04
# 920404   32954.4   942816   53033.4                   230   2019-10-10
# 920430    1729.6    53280    2782.4                    60   2019-11-06
# 920449    1729.6    53280    2782.4                    75   2019-11-06
#
# [737967 rows x 25 columns]

# %%
def dep_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0
    
def arr_value(s):
    if s == 'SIN':
        return 1
    else:
        return 0

# %%
movements_SIN['Dep'] = 0
movements_SIN['Arr'] = 0

movements_SIN['Dep'] = movements_SIN['Dep Airport Code'].apply(dep_value)
movements_SIN['Arr'] = movements_SIN['Arr Airport Code'].apply(arr_value)

# %%
def dep_or_arr_time(dep, dep_time, arr_time):
    if dep == 1:
        return dep_time
    else:
        return arr_time

# %%
movements_SIN['Time_requested'] = movements_SIN[['Dep', 'Local Dep Time', 'Local Arr Time']].apply(lambda x: dep_or_arr_time(*x), axis=1)

# %%
movements_SIN = movements_SIN.drop(['Dep Airport Code', 'Arr Airport Code'], 1)

# %%
def f(s):
    return "".join(["0"]*(4-len(s))) + s

f('0')
# Out:
# '0000'

# %%
movements_SIN['Time_requested_format4'] = movements_SIN['Time_requested'].astype(str).apply(f)
movements_SIN['Time_requested_TS'] = movements_SIN['Time series'] + '-' + movements_SIN['Time_requested_format4']
movements_SIN['TS_datetime_format'] = pd.to_datetime(movements_SIN['Time_requested_TS'], format = '%Y-%m-%d-%H%M')

# %%
from pytz import all_timezones
import pytz

def utc(datetime):
    local = pytz.timezone("Asia/Singapore")
    local_dt = local.localize(datetime, is_dst=None)
    return local_dt.astimezone(pytz.utc)

# %%
movements_SIN['Time_requested_UTC'] = movements_SIN['TS_datetime_format'].apply(utc)

# %%
def day_of_week(s):
    return s.weekday()

# %%
movements_SIN['day_of_week'] = movements_SIN['Time_requested_UTC'].apply(day_of_week)
movements_SIN['Time_series_DT'] = pd.to_datetime(movements_SIN['Time_requested_UTC']).dt.date

# %%
# sort by date
movements_SIN.sort_values(by=['Time_series_DT'], inplace=True)
movements_SIN
# Out:
#                           Dep Airport Name  \
# 755557                Singapore Changi Apt
# 763163                Singapore Changi Apt
# 719601                Singapore Changi Apt
# 189452                   Bandaranaike Intl
# 763324                Singapore Changi Apt
# ...                                    ...
# 199059                Singapore Changi Apt
# 32840                                Perth
# 320655                Singapore Changi Apt
# 19140   Kuala Lumpur International Airport
# 594465                Singapore Changi Apt
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 755557  Taipei Taiwan Taoyuan International Apt     TGW      TR        898
# 763163                           Zurich Airport     SIA      SQ        346
# 719601       Kuala Lumpur International Airport     SLK      MI        322
# 189452                     Singapore Changi Apt     ALK      UL        306
# 763324    Manila Ninoy Aquino International Apt     JSA      3K        763
# ...                                         ...     ...     ...        ...
# 199059    Manila Ninoy Aquino International Apt     CEB      5J        806
# 32840                      Singapore Changi Apt     SIA      SQ        214
# 320655              Hong Kong International Apt     SIA      SQ        856
# 19140                      Singapore Changi Apt     MXD      OD        801
# 594465      Seoul Incheon International Airport     SIA      SQ        600
#
#        Carrier Code        Carrier Name Dep IATA Country Name  \
# 755557           TR               Scoot             Singapore
# 763163           SQ  Singapore Airlines             Singapore
# 719601           MI             SilkAir             Singapore
# 189452           UL  Srilankan Airlines             Sri Lanka
# 763324           3K        Jetstar Asia             Singapore
# ...             ...                 ...                   ...
# 199059           5J    Cebu Pacific Air             Singapore
# 32840            SQ  Singapore Airlines             Australia
# 320655           SQ  Singapore Airlines             Singapore
# 19140            OD     Malindo Airways              Malaysia
# 594465           SQ  Singapore Airlines             Singapore
#
#         Arr IATA Country Name International/Domestic  ...  Time series  Dep  \
# 755557         Chinese Taipei          International  ...   2018-01-01    1
# 763163            Switzerland          International  ...   2018-01-01    1
# 719601               Malaysia          International  ...   2018-01-01    1
# 189452              Singapore          International  ...   2018-01-01    0
# 763324            Philippines          International  ...   2018-01-01    1
# ...                       ...                    ...  ...          ...  ...
# 199059            Philippines          International  ...   2019-12-31    1
# 32840               Singapore          International  ...   2019-12-31    0
# 320655  Hong Kong (sar) China          International  ...   2019-12-31    1
# 19140               Singapore          International  ...   2019-12-31    0
# 594465      Korea Republic of          International  ...   2019-12-31    1
#
#        Arr Time_requested  Time_requested_format4  Time_requested_TS  \
# 755557   0             55                    0055    2018-01-01-0055
# 763163   0            130                    0130    2018-01-01-0130
# 719601   0            710                    0710    2018-01-01-0710
# 189452   1            730                    0730    2018-01-01-0730
# 763324   0            220                    0220    2018-01-01-0220
# ...     ..            ...                     ...                ...
# 199059   0           1900                    1900    2019-12-31-1900
# 32840    1           2240                    2240    2019-12-31-2240
# 320655   0            955                    0955    2019-12-31-0955
# 19140    1            915                    0915    2019-12-31-0915
# 594465   0            805                    0805    2019-12-31-0805
#
#         TS_datetime_format        Time_requested_UTC  day_of_week  \
# 755557 2018-01-01 00:55:00 2017-12-31 16:55:00+00:00            6
# 763163 2018-01-01 01:30:00 2017-12-31 17:30:00+00:00            6
# 719601 2018-01-01 07:10:00 2017-12-31 23:10:00+00:00            6
# 189452 2018-01-01 07:30:00 2017-12-31 23:30:00+00:00            6
# 763324 2018-01-01 02:20:00 2017-12-31 18:20:00+00:00            6
# ...                    ...                       ...          ...
# 199059 2019-12-31 19:00:00 2019-12-31 11:00:00+00:00            1
# 32840  2019-12-31 22:40:00 2019-12-31 14:40:00+00:00            1
# 320655 2019-12-31 09:55:00 2019-12-31 01:55:00+00:00            1
# 19140  2019-12-31 09:15:00 2019-12-31 01:15:00+00:00            1
# 594465 2019-12-31 08:05:00 2019-12-31 00:05:00+00:00            1
#
#         Time_series_DT
# 755557      2017-12-31
# 763163      2017-12-31
# 719601      2017-12-31
# 189452      2017-12-31
# 763324      2017-12-31
# ...                ...
# 199059      2019-12-31
# 32840       2019-12-31
# 320655      2019-12-31
# 19140       2019-12-31
# 594465      2019-12-31
#
# [737967 rows x 32 columns]

# %%
movements_SIN['Time_series_DT'].min()
# Out:
# datetime.date(2017, 12, 31)

# %%
movements_SIN['Time_series_DT'].max()
# Out:
# datetime.date(2019, 12, 31)

# %%
SIN_2018_s = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2018,10,28)]
SIN_2018_s = SIN_2018_s[SIN_2018_s['Time_series_DT'] > pd.Timestamp(2018,3,31)]

SIN_2018_w = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2019,3,31)]
SIN_2018_w = SIN_2018_w[SIN_2018_w['Time_series_DT'] > pd.Timestamp(2018,10,27)]

SIN_2019_s = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2019,10,27)]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_series_DT'] > pd.Timestamp(2019,3,30)]

#SIN_2019_w = movements_SIN[movements_SIN['Time_series_DT'] < pd.Timestamp(2020,3,29)]
#SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]

# %%
def requested_utc_hour(s):
    return s.hour

def requested_utc_minute(s):
    if s.minute == 0:
        return "00"
    else:
        return s.minute

# %%
# For all flights to and from SIN in 2018 & 2019
SIN_2019 = movements_SIN
SIN_2019_df = SIN_2019.copy()

SIN_2019_df['requested_utc_hour'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_hour)
SIN_2019_df['requested_utc_minute'] = SIN_2019_df['Time_requested_UTC'].apply(requested_utc_minute)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc_hour'].apply(str) + SIN_2019_df['requested_utc_minute'].apply(str)
SIN_2019_df['requested_utc'] = SIN_2019_df['requested_utc'].astype(int)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name  \
# 755557                Singapore Changi Apt
# 763163                Singapore Changi Apt
# 719601                Singapore Changi Apt
# 189452                   Bandaranaike Intl
# 763324                Singapore Changi Apt
# ...                                    ...
# 199059                Singapore Changi Apt
# 32840                                Perth
# 320655                Singapore Changi Apt
# 19140   Kuala Lumpur International Airport
# 594465                Singapore Changi Apt
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 755557  Taipei Taiwan Taoyuan International Apt     TGW      TR        898
# 763163                           Zurich Airport     SIA      SQ        346
# 719601       Kuala Lumpur International Airport     SLK      MI        322
# 189452                     Singapore Changi Apt     ALK      UL        306
# 763324    Manila Ninoy Aquino International Apt     JSA      3K        763
# ...                                         ...     ...     ...        ...
# 199059    Manila Ninoy Aquino International Apt     CEB      5J        806
# 32840                      Singapore Changi Apt     SIA      SQ        214
# 320655              Hong Kong International Apt     SIA      SQ        856
# 19140                      Singapore Changi Apt     MXD      OD        801
# 594465      Seoul Incheon International Airport     SIA      SQ        600
#
#        Carrier Code        Carrier Name Dep IATA Country Name  \
# 755557           TR               Scoot             Singapore
# 763163           SQ  Singapore Airlines             Singapore
# 719601           MI             SilkAir             Singapore
# 189452           UL  Srilankan Airlines             Sri Lanka
# 763324           3K        Jetstar Asia             Singapore
# ...             ...                 ...                   ...
# 199059           5J    Cebu Pacific Air             Singapore
# 32840            SQ  Singapore Airlines             Australia
# 320655           SQ  Singapore Airlines             Singapore
# 19140            OD     Malindo Airways              Malaysia
# 594465           SQ  Singapore Airlines             Singapore
#
#         Arr IATA Country Name International/Domestic  ...  Time_requested  \
# 755557         Chinese Taipei          International  ...              55
# 763163            Switzerland          International  ...             130
# 719601               Malaysia          International  ...             710
# 189452              Singapore          International  ...             730
# 763324            Philippines          International  ...             220
# ...                       ...                    ...  ...             ...
# 199059            Philippines          International  ...            1900
# 32840               Singapore          International  ...            2240
# 320655  Hong Kong (sar) China          International  ...             955
# 19140               Singapore          International  ...             915
# 594465      Korea Republic of          International  ...             805
#
#         Time_requested_format4 Time_requested_TS  TS_datetime_format  \
# 755557                    0055   2018-01-01-0055 2018-01-01 00:55:00
# 763163                    0130   2018-01-01-0130 2018-01-01 01:30:00
# 719601                    0710   2018-01-01-0710 2018-01-01 07:10:00
# 189452                    0730   2018-01-01-0730 2018-01-01 07:30:00
# 763324                    0220   2018-01-01-0220 2018-01-01 02:20:00
# ...                        ...               ...                 ...
# 199059                    1900   2019-12-31-1900 2019-12-31 19:00:00
# 32840                     2240   2019-12-31-2240 2019-12-31 22:40:00
# 320655                    0955   2019-12-31-0955 2019-12-31 09:55:00
# 19140                     0915   2019-12-31-0915 2019-12-31 09:15:00
# 594465                    0805   2019-12-31-0805 2019-12-31 08:05:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 755557 2017-12-31 16:55:00+00:00            6      2017-12-31
# 763163 2017-12-31 17:30:00+00:00            6      2017-12-31
# 719601 2017-12-31 23:10:00+00:00            6      2017-12-31
# 189452 2017-12-31 23:30:00+00:00            6      2017-12-31
# 763324 2017-12-31 18:20:00+00:00            6      2017-12-31
# ...                          ...          ...             ...
# 199059 2019-12-31 11:00:00+00:00            1      2019-12-31
# 32840  2019-12-31 14:40:00+00:00            1      2019-12-31
# 320655 2019-12-31 01:55:00+00:00            1      2019-12-31
# 19140  2019-12-31 01:15:00+00:00            1      2019-12-31
# 594465 2019-12-31 00:05:00+00:00            1      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc
# 755557                  16                    55           1655
# 763163                  17                    30           1730
# 719601                  23                    10           2310
# 189452                  23                    30           2330
# 763324                  18                    20           1820
# ...                    ...                   ...            ...
# 199059                  11                    00           1100
# 32840                   14                    40           1440
# 320655                   1                    55            155
# 19140                    1                    15            115
# 594465                   0                     5              5
#
# [737967 rows x 35 columns]

# %%
time_slots = []
h = 0
m = 0
while h < 2400:
    while m < 60:
        time_slots.append(h + m)
        m = m + 5
    m = 0
    h = h + 100
    #print(i)
time_slots.append(2400)
print(len(time_slots))
time_slots
# Out:
# 289
# [0,
#  5,
#  10,
#  15,
#  20,
#  25,
#  30,
#  35,
#  40,
#  45,
#  50,
#  55,
#  100,
#  105,
#  110,
#  115,
#  120,
#  125,
#  130,
#  135,
#  140,
#  145,
#  150,
#  155,
#  200,
#  205,
#  210,
#  215,
#  220,
#  225,
#  230,
#  235,
#  240,
#  245,
#  250,
#  255,
#  300,
#  305,
#  310,
#  315,
#  320,
#  325,
#  330,
#  335,
#  340,
#  345,
#  350,
#  355,
#  400,
#  405,
#  410,
#  415,
#  420,
#  425,
#  430,
#  435,
#  440,
#  445,
#  450,
#  455,
#  500,
#  505,
#  510,
#  515,
#  520,
#  525,
#  530,
#  535,
#  540,
#  545,
#  550,
#  555,
#  600,
#  605,
#  610,
#  615,
#  620,
#  625,
#  630,
#  635,
#  640,
#  645,
#  650,
#  655,
#  700,
#  705,
#  710,
#  715,
#  720,
#  725,
#  730,
#  735,
#  740,
#  745,
#  750,
#  755,
#  800,
#  805,
#  810,
#  815,
#  820,
#  825,
#  830,
#  835,
#  840,
#  845,
#  850,
#  855,
#  900,
#  905,
#  910,
#  915,
#  920,
#  925,
#  930,
#  935,
#  940,
#  945,
#  950,
#  955,
#  1000,
#  1005,
#  1010,
#  1015,
#  1020,
#  1025,
#  1030,
#  1035,
#  1040,
#  1045,
#  1050,
#  1055,
#  1100,
#  1105,
#  1110,
#  1115,
#  1120,
#  1125,
#  1130,
#  1135,
#  1140,
#  1145,
#  1150,
#  1155,
#  1200,
#  1205,
#  1210,
#  1215,
#  1220,
#  1225,
#  1230,
#  1235,
#  1240,
#  1245,
#  1250,
#  1255,
#  1300,
#  1305,
#  1310,
#  1315,
#  1320,
#  1325,
#  1330,
#  1335,
#  1340,
#  1345,
#  1350,
#  1355,
#  1400,
#  1405,
#  1410,
#  1415,
#  1420,
#  1425,
#  1430,
#  1435,
#  1440,
#  1445,
#  1450,
#  1455,
#  1500,
#  1505,
#  1510,
#  1515,
#  1520,
#  1525,
#  1530,
#  1535,
#  1540,
#  1545,
#  1550,
#  1555,
#  1600,
#  1605,
#  1610,
#  1615,
#  1620,
#  1625,
#  1630,
#  1635,
#  1640,
#  1645,
#  1650,
#  1655,
#  1700,
#  1705,
#  1710,
#  1715,
#  1720,
#  1725,
#  1730,
#  1735,
#  1740,
#  1745,
#  1750,
#  1755,
#  1800,
#  1805,
#  1810,
#  1815,
#  1820,
#  1825,
#  1830,
#  1835,
#  1840,
#  1845,
#  1850,
#  1855,
#  1900,
#  1905,
#  1910,
#  1915,
#  1920,
#  1925,
#  1930,
#  1935,
#  1940,
#  1945,
#  1950,
#  1955,
#  2000,
#  2005,
#  2010,
#  2015,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2100,
#  2105,
#  2110,
#  2115,
#  2120,
#  2125,
#  2130,
#  2135,
#  2140,
#  2145,
#  2150,
#  2155,
#  2200,
#  2205,
#  2210,
#  2215,
#  2220,
#  2225,
#  2230,
#  2235,
#  2240,
#  2245,
#  2250,
#  2255,
#  2300,
#  2305,
#  2310,
#  2315,
#  2320,
#  2325,
#  2330,
#  2335,
#  2340,
#  2345,
#  2350,
#  2355,
#  2400]

# %%
SIN_2019_df['Time slot'] = pd.cut(SIN_2019_df['requested_utc'], time_slots, right=False)

# %%
SIN_2019_df
# Out:
#                           Dep Airport Name  \
# 755557                Singapore Changi Apt
# 763163                Singapore Changi Apt
# 719601                Singapore Changi Apt
# 189452                   Bandaranaike Intl
# 763324                Singapore Changi Apt
# ...                                    ...
# 199059                Singapore Changi Apt
# 32840                                Perth
# 320655                Singapore Changi Apt
# 19140   Kuala Lumpur International Airport
# 594465                Singapore Changi Apt
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 755557  Taipei Taiwan Taoyuan International Apt     TGW      TR        898
# 763163                           Zurich Airport     SIA      SQ        346
# 719601       Kuala Lumpur International Airport     SLK      MI        322
# 189452                     Singapore Changi Apt     ALK      UL        306
# 763324    Manila Ninoy Aquino International Apt     JSA      3K        763
# ...                                         ...     ...     ...        ...
# 199059    Manila Ninoy Aquino International Apt     CEB      5J        806
# 32840                      Singapore Changi Apt     SIA      SQ        214
# 320655              Hong Kong International Apt     SIA      SQ        856
# 19140                      Singapore Changi Apt     MXD      OD        801
# 594465      Seoul Incheon International Airport     SIA      SQ        600
#
#        Carrier Code        Carrier Name Dep IATA Country Name  \
# 755557           TR               Scoot             Singapore
# 763163           SQ  Singapore Airlines             Singapore
# 719601           MI             SilkAir             Singapore
# 189452           UL  Srilankan Airlines             Sri Lanka
# 763324           3K        Jetstar Asia             Singapore
# ...             ...                 ...                   ...
# 199059           5J    Cebu Pacific Air             Singapore
# 32840            SQ  Singapore Airlines             Australia
# 320655           SQ  Singapore Airlines             Singapore
# 19140            OD     Malindo Airways              Malaysia
# 594465           SQ  Singapore Airlines             Singapore
#
#         Arr IATA Country Name International/Domestic  ...  \
# 755557         Chinese Taipei          International  ...
# 763163            Switzerland          International  ...
# 719601               Malaysia          International  ...
# 189452              Singapore          International  ...
# 763324            Philippines          International  ...
# ...                       ...                    ...  ...
# 199059            Philippines          International  ...
# 32840               Singapore          International  ...
# 320655  Hong Kong (sar) China          International  ...
# 19140               Singapore          International  ...
# 594465      Korea Republic of          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 755557                    0055    2018-01-01-0055 2018-01-01 00:55:00
# 763163                    0130    2018-01-01-0130 2018-01-01 01:30:00
# 719601                    0710    2018-01-01-0710 2018-01-01 07:10:00
# 189452                    0730    2018-01-01-0730 2018-01-01 07:30:00
# 763324                    0220    2018-01-01-0220 2018-01-01 02:20:00
# ...                        ...                ...                 ...
# 199059                    1900    2019-12-31-1900 2019-12-31 19:00:00
# 32840                     2240    2019-12-31-2240 2019-12-31 22:40:00
# 320655                    0955    2019-12-31-0955 2019-12-31 09:55:00
# 19140                     0915    2019-12-31-0915 2019-12-31 09:15:00
# 594465                    0805    2019-12-31-0805 2019-12-31 08:05:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 755557 2017-12-31 16:55:00+00:00            6      2017-12-31
# 763163 2017-12-31 17:30:00+00:00            6      2017-12-31
# 719601 2017-12-31 23:10:00+00:00            6      2017-12-31
# 189452 2017-12-31 23:30:00+00:00            6      2017-12-31
# 763324 2017-12-31 18:20:00+00:00            6      2017-12-31
# ...                          ...          ...             ...
# 199059 2019-12-31 11:00:00+00:00            1      2019-12-31
# 32840  2019-12-31 14:40:00+00:00            1      2019-12-31
# 320655 2019-12-31 01:55:00+00:00            1      2019-12-31
# 19140  2019-12-31 01:15:00+00:00            1      2019-12-31
# 594465 2019-12-31 00:05:00+00:00            1      2019-12-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 755557                  16                    55           1655  [1655, 1700)
# 763163                  17                    30           1730  [1730, 1735)
# 719601                  23                    10           2310  [2310, 2315)
# 189452                  23                    30           2330  [2330, 2335)
# 763324                  18                    20           1820  [1820, 1825)
# ...                    ...                   ...            ...           ...
# 199059                  11                    00           1100  [1100, 1105)
# 32840                   14                    40           1440  [1440, 1445)
# 320655                   1                    55            155    [155, 200)
# 19140                    1                    15            115    [115, 120)
# 594465                   0                     5              5       [5, 10)
#
# [737967 rows x 36 columns]

# %%
SIN_2019_s = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2019,10,27)]
SIN_2019_s = SIN_2019_s[SIN_2019_s['Time_series_DT'] > pd.Timestamp(2019,3,30)]

# %%
SIN_2019_s
# Out:
#                                Dep Airport Name  \
# 792973                     Singapore Changi Apt
# 706716                     Singapore Changi Apt
# 257499                     Singapore Changi Apt
# 638322  Taipei Taiwan Taoyuan International Apt
# 122118               Jakarta Soekarno-Hatta Apt
# ...                                         ...
# 355151                                 Brisbane
# 708709                                  Bandung
# 750273                     Singapore Changi Apt
# 680901                     Singapore Changi Apt
# 89712                          Istanbul Airport
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 792973       Osaka Kansai International Airport     SIA      SQ        622
# 706716  Nagoya Chubu Centrair International Apt     SIA      SQ        672
# 257499                                 Ko Samui     SLK      MI        774
# 638322                     Singapore Changi Apt     JSA      3K        724
# 122118                     Singapore Changi Apt     LNI      JT        156
# ...                                         ...     ...     ...        ...
# 355151                     Singapore Changi Apt     SIA      SQ        246
# 708709                     Singapore Changi Apt     AWQ      QZ        365
# 750273                         Ho Chi Minh City     JSA      3K        555
# 680901                               Kochi (IN)     SLK      MI        468
# 89712                      Singapore Changi Apt     THY      TK         54
#
#        Carrier Code        Carrier Name Dep IATA Country Name  \
# 792973           SQ  Singapore Airlines             Singapore
# 706716           SQ  Singapore Airlines             Singapore
# 257499           MI             SilkAir             Singapore
# 638322           3K        Jetstar Asia        Chinese Taipei
# 122118           JT            Lion Air             Indonesia
# ...             ...                 ...                   ...
# 355151           SQ  Singapore Airlines             Australia
# 708709           QZ   Indonesia AirAsia             Indonesia
# 750273           3K        Jetstar Asia             Singapore
# 680901           MI             SilkAir             Singapore
# 89712            TK    Turkish Airlines                Turkey
#
#        Arr IATA Country Name International/Domestic  ...  \
# 792973                 Japan          International  ...
# 706716                 Japan          International  ...
# 257499              Thailand          International  ...
# 638322             Singapore          International  ...
# 122118             Singapore          International  ...
# ...                      ...                    ...  ...
# 355151             Singapore          International  ...
# 708709             Singapore          International  ...
# 750273              Viet Nam          International  ...
# 680901                 India          International  ...
# 89712              Singapore          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 792973                    1355    2019-03-31-1355 2019-03-31 13:55:00
# 706716                    0120    2019-04-01-0120 2019-04-01 01:20:00
# 257499                    1025    2019-03-31-1025 2019-03-31 10:25:00
# 638322                    2015    2019-03-31-2015 2019-03-31 20:15:00
# 122118                    1900    2019-03-31-1900 2019-03-31 19:00:00
# ...                        ...                ...                 ...
# 355151                    0430    2019-10-27-0430 2019-10-27 04:30:00
# 708709                    1530    2019-10-26-1530 2019-10-26 15:30:00
# 750273                    0710    2019-10-27-0710 2019-10-27 07:10:00
# 680901                    2000    2019-10-26-2000 2019-10-26 20:00:00
# 89712                     1750    2019-10-26-1750 2019-10-26 17:50:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 792973 2019-03-31 05:55:00+00:00            6      2019-03-31
# 706716 2019-03-31 17:20:00+00:00            6      2019-03-31
# 257499 2019-03-31 02:25:00+00:00            6      2019-03-31
# 638322 2019-03-31 12:15:00+00:00            6      2019-03-31
# 122118 2019-03-31 11:00:00+00:00            6      2019-03-31
# ...                          ...          ...             ...
# 355151 2019-10-26 20:30:00+00:00            5      2019-10-26
# 708709 2019-10-26 07:30:00+00:00            5      2019-10-26
# 750273 2019-10-26 23:10:00+00:00            5      2019-10-26
# 680901 2019-10-26 12:00:00+00:00            5      2019-10-26
# 89712  2019-10-26 09:50:00+00:00            5      2019-10-26
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 792973                   5                    55            555    [555, 600)
# 706716                  17                    20           1720  [1720, 1725)
# 257499                   2                    25            225    [225, 230)
# 638322                  12                    15           1215  [1215, 1220)
# 122118                  11                    00           1100  [1100, 1105)
# ...                    ...                   ...            ...           ...
# 355151                  20                    30           2030  [2030, 2035)
# 708709                   7                    30            730    [730, 735)
# 750273                  23                    10           2310  [2310, 2315)
# 680901                  12                    00           1200  [1200, 1205)
# 89712                    9                    50            950    [950, 955)
#
# [208994 rows x 36 columns]

# %%
SIN_2019_s['Time_series_DT'].unique()[0:7]
# Out:
# array([datetime.date(2019, 3, 31), datetime.date(2019, 4, 1),
#        datetime.date(2019, 4, 2), datetime.date(2019, 4, 3),
#        datetime.date(2019, 4, 4), datetime.date(2019, 4, 5),
#        datetime.date(2019, 4, 6)], dtype=object)

# %%
# start here
first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
date = first_week[0]
SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
SIN_2019_s_d1
# Out:
#                                Dep Airport Name  \
# 792973                     Singapore Changi Apt
# 706716                     Singapore Changi Apt
# 257499                     Singapore Changi Apt
# 638322  Taipei Taiwan Taoyuan International Apt
# 122118               Jakarta Soekarno-Hatta Apt
# ...                                         ...
# 431791   Bangkok Suvarnabhumi International Apt
# 30053                      Singapore Changi Apt
# 498502                     Singapore Changi Apt
# 73934                      Singapore Changi Apt
# 438425                                  Chennai
#
#                                Arr Airport Name ICAO AL IATA AL  Flight No  \
# 792973       Osaka Kansai International Airport     SIA      SQ        622
# 706716  Nagoya Chubu Centrair International Apt     SIA      SQ        672
# 257499                                 Ko Samui     SLK      MI        774
# 638322                     Singapore Changi Apt     JSA      3K        724
# 122118                     Singapore Changi Apt     LNI      JT        156
# ...                                         ...     ...     ...        ...
# 431791                     Singapore Changi Apt     SIA      SQ        977
# 30053                                    Penang     AXM      AK       1730
# 498502                      Tokyo Intl (Haneda)     ANA      NH        842
# 73934                                    Phuket     JSA      3K        537
# 438425                     Singapore Changi Apt     SLK      MI        435
#
#        Carrier Code        Carrier Name Dep IATA Country Name  \
# 792973           SQ  Singapore Airlines             Singapore
# 706716           SQ  Singapore Airlines             Singapore
# 257499           MI             SilkAir             Singapore
# 638322           3K        Jetstar Asia        Chinese Taipei
# 122118           JT            Lion Air             Indonesia
# ...             ...                 ...                   ...
# 431791           SQ  Singapore Airlines              Thailand
# 30053            AK             AirAsia             Singapore
# 498502           NH  All Nippon Airways             Singapore
# 73934            3K        Jetstar Asia             Singapore
# 438425           MI             SilkAir                 India
#
#        Arr IATA Country Name International/Domestic  ...  \
# 792973                 Japan          International  ...
# 706716                 Japan          International  ...
# 257499              Thailand          International  ...
# 638322             Singapore          International  ...
# 122118             Singapore          International  ...
# ...                      ...                    ...  ...
# 431791             Singapore          International  ...
# 30053               Malaysia          International  ...
# 498502                 Japan          International  ...
# 73934               Thailand          International  ...
# 438425             Singapore          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 792973                    1355    2019-03-31-1355 2019-03-31 13:55:00
# 706716                    0120    2019-04-01-0120 2019-04-01 01:20:00
# 257499                    1025    2019-03-31-1025 2019-03-31 10:25:00
# 638322                    2015    2019-03-31-2015 2019-03-31 20:15:00
# 122118                    1900    2019-03-31-1900 2019-03-31 19:00:00
# ...                        ...                ...                 ...
# 431791                    1855    2019-03-31-1855 2019-03-31 18:55:00
# 30053                     2140    2019-03-31-2140 2019-03-31 21:40:00
# 498502                    1100    2019-03-31-1100 2019-03-31 11:00:00
# 73934                     2030    2019-03-31-2030 2019-03-31 20:30:00
# 438425                    1720    2019-03-31-1720 2019-03-31 17:20:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 792973 2019-03-31 05:55:00+00:00            6      2019-03-31
# 706716 2019-03-31 17:20:00+00:00            6      2019-03-31
# 257499 2019-03-31 02:25:00+00:00            6      2019-03-31
# 638322 2019-03-31 12:15:00+00:00            6      2019-03-31
# 122118 2019-03-31 11:00:00+00:00            6      2019-03-31
# ...                          ...          ...             ...
# 431791 2019-03-31 10:55:00+00:00            6      2019-03-31
# 30053  2019-03-31 13:40:00+00:00            6      2019-03-31
# 498502 2019-03-31 03:00:00+00:00            6      2019-03-31
# 73934  2019-03-31 12:30:00+00:00            6      2019-03-31
# 438425 2019-03-31 09:20:00+00:00            6      2019-03-31
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 792973                   5                    55            555    [555, 600)
# 706716                  17                    20           1720  [1720, 1725)
# 257499                   2                    25            225    [225, 230)
# 638322                  12                    15           1215  [1215, 1220)
# 122118                  11                    00           1100  [1100, 1105)
# ...                    ...                   ...            ...           ...
# 431791                  10                    55           1055  [1055, 1100)
# 30053                   13                    40           1340  [1340, 1345)
# 498502                   3                    00            300    [300, 305)
# 73934                   12                    30           1230  [1230, 1235)
# 438425                   9                    20            920    [920, 925)
#
# [1057 rows x 36 columns]

# %%
timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
timeslot_movements = timeslot_movements.to_frame()
timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
timeslot_movements = timeslot_movements.reset_index()
timeslot_movements
# Out:
#             index  Movements
# 0       [55, 100)         27
# 1      [155, 200)         12
# 2    [1115, 1120)         11
# 3      [145, 150)         10
# 4      [850, 855)          9
# ..            ...        ...
# 283    [605, 610)          0
# 284  [1930, 1935)          0
# 285  [1915, 1920)          0
# 286  [1910, 1915)          0
# 287  [1925, 1930)          0
#
# [288 rows x 2 columns]

# %%
# convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
start = 0
end = 5
interval = pd.Interval(left=start, right=end, closed='left')

# eg. (0, 5] -> slot 1
interval_slot_dict = {} 

for slot in range(1, 289, 1):
    interval_slot_dict[interval] = slot
    if (end % 100 == 55):
        start = interval.left + 5
        end = interval.right + 45
    elif (start % 100 == 55):
        start = interval.left + 45
        end = interval.right + 5
    else:
        start = interval.left + 5
        end = interval.right + 5
    
    interval = pd.Interval(left=start, right=end, closed='left')

# %%
timeslot_movements['Slot'] = ''
for index, row in timeslot_movements.iterrows():
    row['Slot'] = interval_slot_dict.get(row['index'])
    
timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)

# %%
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         27    12
# 1      [155, 200)         12    24
# 2    [1115, 1120)         11   136
# 3      [145, 150)         10    22
# 4      [850, 855)          9   107
# ..            ...        ...   ...
# 283    [605, 610)          0    74
# 284  [1930, 1935)          0   235
# 285  [1915, 1920)          0   232
# 286  [1910, 1915)          0   231
# 287  [1925, 1930)          0   234
#
# [288 rows x 3 columns]

# %%
x = timeslot_movements['Slot']
y = timeslot_movements['Movements'] 

plt.figure(figsize=(10,6))
plt.bar(x, y, width=3.0) 
 
plt.xlabel('Timeslot') 
plt.ylabel('No. of movements') 

plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

plt.show()

# %%
def get_first_100_dates(SIN_2019_s):
    first_100_dates = SIN_2019_s['Time_series_DT'].unique()[0:100]
    return first_100_dates # array with 1st 100 days dates

# %%
get_first_100_dates(SIN_2019_s)[0]
# Out:
# datetime.date(2019, 3, 31)

# %%
# added
def get_first_week_dates(SIN_2019_s):
    first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
    return first_week # array with 1st week's dates

# %%
get_first_week_dates(SIN_2019_s)[0]
# Out:
# datetime.date(2019, 3, 31)

# %%
def timeslot_to_index():
    # convert requested timeslot to index timeslot (eg. (0, 5] is slot 1)
    start = 0
    end = 5
    interval = pd.Interval(left=start, right=end, closed='left')

    # eg. (0, 5] -> slot 1
    interval_slot_dict = {} 

    for slot in range(1, 289, 1):
        interval_slot_dict[interval] = slot
        if (end % 100 == 55):
            start = interval.left + 5
            end = interval.right + 45
        elif (start % 100 == 55):
            start = interval.left + 45
            end = interval.right + 5
        else:
            start = interval.left + 5
            end = interval.right + 5
    
        interval = pd.Interval(left=start, right=end, closed='left')
        
    return interval_slot_dict

# %%
def get_first_week_dates(SIN_2019_s):
    first_week = SIN_2019_s['Time_series_DT'].unique()[0:7]
    return first_week # array with 1st week's dates

# %%
def get_first_week_df(SIN_2019_s, date): # date = first_week[0]
    # date = first_week[0]
    SIN_2019_s_d1 = SIN_2019_s.loc[SIN_2019_s['Time_series_DT'] == date]
    return SIN_2019_s_d1 # df of a particualr day of the 1st week

# %%
def mov_per_slot(SIN_2019_s_d1, interval_slot_dict):
    timeslot_movements = SIN_2019_s_d1['Time slot'].value_counts(dropna=False)
    timeslot_movements = timeslot_movements.to_frame()
    timeslot_movements = timeslot_movements.rename({'Time slot': 'Movements'}, axis = 1)
    timeslot_movements = timeslot_movements.reset_index()
    
    timeslot_movements['Slot'] = ''
    for index, row in timeslot_movements.iterrows():
        row['Slot'] = interval_slot_dict.get(row['index'])
    
    timeslot_movements['Slot'] = timeslot_movements.apply(lambda row: interval_slot_dict.get(row['index']), axis=1)
    return timeslot_movements

# %%
def get_date_plot(timeslot_movements, date):
    x = timeslot_movements['Slot']
    y = timeslot_movements['Movements'] 

    plt.figure(figsize=(10,6))
    plt.bar(x, y, width=3.0) 
 
    plt.xlabel('Timeslot') 
    plt.ylabel('No. of movements') 

    plt.title('No. of movements by timeslot in ' + str(pd.to_datetime(date))[0:10]) 

    plt.show()

# %%
# 1st day - 2019 summer
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[0]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         27    12
# 1      [155, 200)         12    24
# 2    [1115, 1120)         11   136
# 3      [145, 150)         10    22
# 4      [850, 855)          9   107
# ..            ...        ...   ...
# 283    [605, 610)          0    74
# 284  [1930, 1935)          0   235
# 285  [1915, 1920)          0   232
# 286  [1910, 1915)          0   231
# 287  [1925, 1930)          0   234
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[1]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         24    12
# 1      [145, 150)         12    22
# 2        [15, 20)         12     4
# 3      [155, 200)         12    24
# 4    [1000, 1005)         10   121
# ..            ...        ...   ...
# 283  [2150, 2155)          0   263
# 284  [1850, 1855)          0   227
# 285    [805, 810)          0    98
# 286    [240, 245)          0    33
# 287  [1405, 1410)          0   170
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[2]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         24    12
# 1      [155, 200)         13    24
# 2    [1115, 1120)         10   136
# 3      [145, 150)         10    22
# 4        [15, 20)          9     4
# ..            ...        ...   ...
# 283  [1915, 1920)          0   232
# 284  [2135, 2140)          0   260
# 285    [305, 310)          0    38
# 286  [1105, 1110)          0   134
# 287  [1940, 1945)          0   237
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[3]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         25    12
# 1      [155, 200)         14    24
# 2      [145, 150)         11    22
# 3    [1115, 1120)          9   136
# 4    [1030, 1035)          9   127
# ..            ...        ...   ...
# 283  [1600, 1605)          0   193
# 284    [405, 410)          0    50
# 285  [2105, 2110)          0   254
# 286  [2110, 2115)          0   255
# 287  [1105, 1110)          0   134
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[4]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         26    12
# 1      [155, 200)         13    24
# 2        [15, 20)         11     4
# 3    [1000, 1005)         10   121
# 4      [100, 105)         10    13
# ..            ...        ...   ...
# 283  [1005, 1010)          0   122
# 284  [2120, 2125)          0   257
# 285    [305, 310)          0    38
# 286    [240, 245)          0    33
# 287  [1930, 1935)          0   235
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[5]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         25    12
# 1      [155, 200)         15    24
# 2        [15, 20)         11     4
# 3      [145, 150)         11    22
# 4      [125, 130)         10    18
# ..            ...        ...   ...
# 283  [1920, 1925)          0   233
# 284  [2120, 2125)          0   257
# 285    [305, 310)          0    38
# 286    [240, 245)          0    33
# 287  [1335, 1340)          0   164
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2019_s)
date = first_week[6]
SIN_2019_s_d1 = get_first_week_df(SIN_2019_s, date)
timeslot_movements = mov_per_slot(SIN_2019_s_d1, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         22    12
# 1      [155, 200)         13    24
# 2      [100, 105)         10    13
# 3    [1000, 1005)         10   121
# 4        [15, 20)         10     4
# ..            ...        ...   ...
# 283  [2105, 2110)          0   254
# 284  [2110, 2115)          0   255
# 285  [1605, 1610)          0   194
# 286  [2120, 2125)          0   257
# 287    [205, 210)          0    26
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
#SIN_2019_w = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2020,3,29)]
#SIN_2019_w = SIN_2019_w[SIN_2019_w['Time_series_DT'] > pd.Timestamp(2019,10,26)]
#SIN_2019_w

# %%
SIN_2018_w = SIN_2019_df[SIN_2019_df['Time_series_DT'] < pd.Timestamp(2019,3,31)]
SIN_2018_w = SIN_2018_w[SIN_2018_w['Time_series_DT'] > pd.Timestamp(2018,10,27)]
SIN_2018_w
# Out:
#                                Dep Airport Name  \
# 296181                            Denpasar-Bali
# 115236                                Guangzhou
# 296206                            Denpasar-Bali
# 113893                                Guangzhou
# 726361                     Singapore Changi Apt
# ...                                         ...
# 327622                     Singapore Changi Apt
# 63092   Taipei Taiwan Taoyuan International Apt
# 16001                Sydney Kingsford Smith Apt
# 868842                                   Yangon
# 314640                     Singapore Changi Apt
#
#                           Arr Airport Name ICAO AL IATA AL  Flight No  \
# 296181                Singapore Changi Apt     JSA      3K        244
# 115236                Singapore Changi Apt     CSN      CZ        351
# 296206                Singapore Changi Apt     JST      JQ        116
# 113893                Singapore Changi Apt     SIA      SQ        851
# 726361                                Cebu     EZD      Z2       7237
# ...                                    ...     ...     ...        ...
# 327622  Kuala Lumpur International Airport     AXM      AK        710
# 63092                 Singapore Changi Apt     CAL      CI        753
# 16001                 Singapore Changi Apt     TGW      TR          3
# 868842                Singapore Changi Apt     SIA      SQ        997
# 314640                              Phuket     JSA      3K        533
#
#        Carrier Code              Carrier Name Dep IATA Country Name  \
# 296181           3K              Jetstar Asia             Indonesia
# 115236           CZ   China Southern Airlines                 China
# 296206           JQ           Jetstar Airways             Indonesia
# 113893           SQ        Singapore Airlines                 China
# 726361           Z2  Philippines AirAsia Inc.             Singapore
# ...             ...                       ...                   ...
# 327622           AK                   AirAsia             Singapore
# 63092            CI            China Airlines        Chinese Taipei
# 16001            TR                     Scoot             Australia
# 868842           SQ        Singapore Airlines               Myanmar
# 314640           3K              Jetstar Asia             Singapore
#
#        Arr IATA Country Name International/Domestic  ...  \
# 296181             Singapore          International  ...
# 115236             Singapore          International  ...
# 296206             Singapore          International  ...
# 113893             Singapore          International  ...
# 726361           Philippines          International  ...
# ...                      ...                    ...  ...
# 327622              Malaysia          International  ...
# 63092              Singapore          International  ...
# 16001              Singapore          International  ...
# 868842             Singapore          International  ...
# 314640              Thailand          International  ...
#
#         Time_requested_format4  Time_requested_TS  TS_datetime_format  \
# 296181                    1325    2018-10-28-1325 2018-10-28 13:25:00
# 115236                    2235    2018-10-28-2235 2018-10-28 22:35:00
# 296206                    0125    2018-10-29-0125 2018-10-29 01:25:00
# 113893                    1740    2018-10-28-1740 2018-10-28 17:40:00
# 726361                    2110    2018-10-28-2110 2018-10-28 21:10:00
# ...                        ...                ...                 ...
# 327622                    1405    2019-03-30-1405 2019-03-30 14:05:00
# 63092                     1305    2019-03-30-1305 2019-03-30 13:05:00
# 16001                     1855    2019-03-30-1855 2019-03-30 18:55:00
# 868842                    1510    2019-03-30-1510 2019-03-30 15:10:00
# 314640                    0755    2019-03-31-0755 2019-03-31 07:55:00
#
#               Time_requested_UTC  day_of_week  Time_series_DT  \
# 296181 2018-10-28 05:25:00+00:00            6      2018-10-28
# 115236 2018-10-28 14:35:00+00:00            6      2018-10-28
# 296206 2018-10-28 17:25:00+00:00            6      2018-10-28
# 113893 2018-10-28 09:40:00+00:00            6      2018-10-28
# 726361 2018-10-28 13:10:00+00:00            6      2018-10-28
# ...                          ...          ...             ...
# 327622 2019-03-30 06:05:00+00:00            5      2019-03-30
# 63092  2019-03-30 05:05:00+00:00            5      2019-03-30
# 16001  2019-03-30 10:55:00+00:00            5      2019-03-30
# 868842 2019-03-30 07:10:00+00:00            5      2019-03-30
# 314640 2019-03-30 23:55:00+00:00            5      2019-03-30
#
#         requested_utc_hour  requested_utc_minute  requested_utc     Time slot
# 296181                   5                    25            525    [525, 530)
# 115236                  14                    35           1435  [1435, 1440)
# 296206                  17                    25           1725  [1725, 1730)
# 113893                   9                    40            940    [940, 945)
# 726361                  13                    10           1310  [1310, 1315)
# ...                    ...                   ...            ...           ...
# 327622                   6                     5             65     [55, 100)
# 63092                    5                     5             55     [55, 100)
# 16001                   10                    55           1055  [1055, 1100)
# 868842                   7                    10            710    [710, 715)
# 314640                  23                    55           2355  [2355, 2400)
#
# [159069 rows x 36 columns]

# %%
# 1st day - 2018 winter
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[0]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         26    12
# 1      [155, 200)         20    24
# 2    [1130, 1135)         10   139
# 3    [1555, 1600)         10   192
# 4      [320, 325)         10    41
# ..            ...        ...   ...
# 283  [1905, 1910)          0   230
# 284  [1900, 1905)          0   229
# 285  [1855, 1900)          0   228
# 286    [705, 710)          0    86
# 287    [505, 510)          0    62
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 2nd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[1]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         29    12
# 1      [155, 200)         16    24
# 2    [1555, 1600)         12   192
# 3      [145, 150)         10    22
# 4      [855, 900)          9   108
# ..            ...        ...   ...
# 283  [1740, 1745)          0   213
# 284    [605, 610)          0    74
# 285  [1305, 1310)          0   158
# 286  [2220, 2225)          0   269
# 287    [805, 810)          0    98
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 3rd day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[2]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         27    12
# 1      [155, 200)         16    24
# 2    [1555, 1600)         11   192
# 3        [45, 50)         10    10
# 4      [930, 935)          9   115
# ..            ...        ...   ...
# 283    [505, 510)          0    62
# 284  [2020, 2025)          0   245
# 285  [1750, 1755)          0   215
# 286    [535, 540)          0    68
# 287    [705, 710)          0    86
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 4th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[3]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         25    12
# 1      [155, 200)         17    24
# 2    [1555, 1600)         13   192
# 3      [320, 325)          9    41
# 4    [1300, 1305)          9   157
# ..            ...        ...   ...
# 283  [1955, 2000)          0   240
# 284  [1605, 1610)          0   194
# 285    [805, 810)          0    98
# 286  [1945, 1950)          0   238
# 287  [1950, 1955)          0   239
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 5th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[4]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         28    12
# 1      [155, 200)         20    24
# 2    [1555, 1600)         12   192
# 3        [45, 50)         10    10
# 4      [930, 935)          9   115
# ..            ...        ...   ...
# 283  [1705, 1710)          0   206
# 284  [1005, 1010)          0   122
# 285  [1700, 1705)          0   205
# 286    [305, 310)          0    38
# 287  [1905, 1910)          0   230
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 6th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[5]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         29    12
# 1      [155, 200)         20    24
# 2    [1555, 1600)         11   192
# 3      [145, 150)         10    22
# 4    [1200, 1205)          9   145
# ..            ...        ...   ...
# 283    [605, 610)          0    74
# 284  [1925, 1930)          0   234
# 285  [1920, 1925)          0   233
# 286  [1915, 1920)          0   232
# 287    [905, 910)          0   110
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)

# %%
# 7th day
interval_slot_dict = timeslot_to_index()
first_week = get_first_week_dates(SIN_2018_w)
date = first_week[6]
SIN_2018_w_1d = get_first_week_df(SIN_2018_w, date)
timeslot_movements = mov_per_slot(SIN_2018_w_1d, interval_slot_dict)
timeslot_movements
# Out:
#             index  Movements  Slot
# 0       [55, 100)         27    12
# 1      [155, 200)         18    24
# 2    [1555, 1600)         11   192
# 3      [320, 325)         11    41
# 4    [1000, 1005)         10   121
# ..            ...        ...   ...
# 283    [605, 610)          0    74
# 284  [1925, 1930)          0   234
# 285  [1920, 1925)          0   233
# 286  [2005, 2010)          0   242
# 287  [1815, 1820)          0   220
#
# [288 rows x 3 columns]

# %%
get_date_plot(timeslot_movements, date)
